# %% [markdown]
# # Import Libraries

# %%
import os
import requests
import json
import sys
import pandas as pd
from datetime import datetime
from pathlib import Path
import weaviate
from langchain_community.vectorstores import Weaviate
from langchain.chains import RetrievalQA
from langchain.retrievers.self_query.base import SelfQueryRetriever
from langchain_openai import ChatOpenAI
from langchain.schema import Document
from langchain_community.embeddings import OpenAIEmbeddings
from langchain.prompts import PromptTemplate
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex, Settings, StorageContext
from weaviate.classes.config import Configure, Property, DataType, Tokenization, VectorDistances
import weaviate.classes as wvc
from weaviate.classes.query import MetadataQuery
import weaviate.classes.query as wq
from langchain_community.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.output_parsers import StructuredOutputParser
from langchain.output_parsers import ResponseSchema
from weaviate.classes.init import Auth
from llama_index.core.llms import ChatMessage
from llama_index.core.node_parser import LangchainNodeParser
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.llms.openai_like import OpenAILike
from llama_index.core.schema import TextNode
from llama_index.vector_stores.weaviate import WeaviateVectorStore
import numpy as np

# %%
client = weaviate.connect_to_weaviate_cloud(
    cluster_url="url",  # Replace with your Weaviate Cloud URL
    auth_credentials=Auth.api_key("key")
)

# %% [markdown]
# # Upload Nodes Directly with No Chunking

# %%
OPENAI_API_KEY = 'api_key'
#GENERATOR_MODEL_NAME = "Mistral-7B-Instruct-v0.3"
GENERATOR_MODEL_NAME = "Meta-Llama-3.1-8B-Instruct"
GENERATOR_BASE_URL = "https://kscope.vectorinstitute.ai/v1"
EMBEDDING_MODEL_NAME = "BAAI/bge-base-en-v1.5"

llm = OpenAILike(
    model=GENERATOR_MODEL_NAME,
    is_chat_model=True,
    temperature=0,
    max_tokens=None,
    api_base=GENERATOR_BASE_URL,
    api_key=OPENAI_API_KEY
)
message = [
    ChatMessage(
        role="user",
        content="whats up?"
    )
]
try:
    result = llm.chat(message)
    print(f"Result: \n\n{result}")
except Exception as err:
    if "Error code: 503" in err.message:
        print(f"The model {GENERATOR_MODEL_NAME} is not ready yet.")
    else:
        raise
# Out:
# Result:
#
# assistant: Not much! I'm just a language model, I don't have feelings or emotions like humans do, but I'm here to help you with any questions or topics you'd like to discuss. How about you? How's your day going?

# %% [markdown]
# # Creates Nodes

# %%
import pandas as pd
from llama_index.core.schema import TextNode

df = pd.read_csv("/projects/RAG2/cibc-2/Bootcamp_Dataset_CIBC2.csv")

# Specify metadata fields to include
metadata_fields = ["datePublished", "rating", "topic", "headline","sentiment"]  # Manually specify which columns to use as metadata

# Ensure NaN values are replaced with None
df = df.where(pd.notna(df), None)

# Convert DataFrame to list of TextNodes
nodes = [
    TextNode(
        text=row["reviewBody"],
        metadata={
            key: value for key, value in row.items() if key in metadata_fields and value is not None and value != ""
        }
    )
    for _, row in df.iterrows()
]

# Output example
for node in nodes:
    print(node)
# Out:
# Node ID: 21bf506b-a789-47a7-b80a-34e3e820b5b3
# Text: ... this so called bank is a joke... customer service is
# nonexistent  when trying to get answers they simply disappear... just
# let me close my account!...thumbs down...
# Node ID: d07c1f62-899a-4d99-b498-51461fe51686
# Text: is a toy bank.Its not a serious institution in any way. You can
# keep there a couple hundred dollars on groceries but thats about it.
# For starters, limit 500 per transaction. I went to pay for my
# insurance and it just refused to work because the bill was about 1000.
# Quite inconvenient.Even worse, there is 200 daily withdrawal limit
# with no possib...
# Node ID: 3bf123cb-333a-48fb-a6df-be75a8f62034
# Text: made a large payment on my  account to   credit card. Over 2000.
# The web server was slow and the payment timed out saying incomplete
# transaction try again later. I dis so and payment transacted as
# normal. But the first payment was also credited resulting in my
# account being in the red. Phone  they showed me how to reverse one
# payment. Did that f...
# Node ID: 756859a8-f9d4-4911-94c0-a475ca4a5acf
# Text: is the worst bank I have ever experienced and I do NOT recommend
# it. I have just opened both my chequing and savings account this
# month, August 15, 2019 and I am closing it. It is one problem after
# another and I felt trapped, could not get my money out to do etransfer
# for rent because either the online banking is on maintenance or the
# registrati...
# Node ID: 82c1b7f4-34fd-48c4-8e7e-34bc848799a1
# Text: has been absolutely amazing with our new mortgage. Ive used them
# since they opened and our most recent experience with mortgage
# specialist  has been seamless from start to finish. He was responsive
# to all our questions and worked very late on a Friday evening to
# ensure we met the conditions of our close. Absolutely recommend  for
# all banking needs!
# Node ID: bf4ea6ec-c001-49e5-a49a-23f1b3328f51
# Text: is a criminal organization They are not a member of the  and
# they have no intention of dealing with any actual customer service
# issues their clients have. They deal with people who open accounts
# with them like prey. They are predators who take and give nothing in
# return
# Node ID: 61c9c5f5-7461-40fd-b9d6-2c34a835f984
# Text: is the worst bank to deal with. There customer service is
# horrible, they are rude and frankly they dont know much what happening
# there. after several bad call experiences I decided to close my
# account so on friday 9 octobre 2020 at 14h24 I called  and tlked to a
# manager whose name was  , firstly he wasnt a helpful person, secondly
# after asking m...
# Node ID: d65f3670-d0e7-4ecd-b874-913a43a91852
# Text: was very informative, and patient. He made the process as stress
# free as possible. I have been with  for 30 years and I have been
# pleased with the service.
# Node ID: 51f3f243-04e6-43fa-b0a0-8b6fdd9cd3d0
# Text: locked my debit card two weeks ago as fraud prevention. Their
# verification text message sent to my phone kept responding with
# information to my numerous attempts to respond. I have now been on
# hold for over seven hours waiting to speak to fraud prevention!!! No
# one ever answers my Calls !!!!! The customer service at  has gotten
# horrible. Take y...
# Node ID: 62a6dbc6-ac87-4215-8a5a-ccc40899f4a2
# Text: Avoid at all Costs !! Terrible Banking ! The Absolute
# Worst!!They Closed my checking account and other accounts because of
# too many email transfers, deposits and withdrawals. On top of that
# they are still holding my direct deposit for over 5500 for over a week
# now and also holding a direct deposit email transfer. I can not get a
# hold of anyone a...
# Node ID: 7ea98338-7648-44b2-9431-4332e31ce2b8
# Text: is a great asset to . Very helpful and empathic while
# maintaining his professionalism. helped me not once but twice in one
# month to change my mortgage.He was always available to listen and if
# he was not available right away he always called me back the same day.
# Great experience with !!! Thank you !! Also, it has been a very good
# experience with...
# Node ID: 5be0e13d-2000-4117-ac96-0b7f88cdf53e
# Text: support specialist from  financial helped me in changing the
# Title transfer of my home, though it took more time than anticipated
# to get documents in place  is patient and timely followed up with me
# in regards to documents required for them to complete the process. I
# recommend  finance to my family and friends when needed.
# Node ID: 3f0dd425-a5cb-405d-801d-6dd71c994671
# Text: was extremely helpful in getting my secured line of credit set
# up. I have been a  customer for several years and would recommend the
# bank and services they offer to anyone
# Node ID: 27650c63-5ee2-46d4-8c12-d41f8f83e18f
# Text: has gone down the drain since it was rebranded from . The
# website and app are constantly broken and I can never get my banking
# done in the time frame that I need. Tried to call them today about an
# issue on  etransfers and I was hung up on. Im transferring my money
# and moving elsewhere. Absolutely ridiculous. Just because you are low
# fees doesnt ...
# Node ID: ba921537-9eda-4db5-93a2-35e2c0e64490
# Text: is not responsible for fraudsThey wont transfer you to fraud
# quickly people are not trained. Once you get someone after 1 hour ,
# they will tell you what you want to hear and then change their mind,
# at the end of the day, the loss will be yours 100 except on credit
# cards since they can reverse it lets be fair unlike them, they will
# never take res...
# Node ID: 7b0b2a12-6321-47fb-a679-738d74f07e36
# Text: is the worst bank to deal with. There customer service is
# horrible, they are rude and frankly they dont know what the hell there
# doing there. I highly recommend going else where just so you dont get
# screwed over like I did.
# Node ID: 5b4f6ac2-7c9d-4d17-8f36-0d241873c640
# Text: representative was clear in her instructions to help us move our
# mortgage, she was quick to respond to any questions we had and we are
# very happy with the service she provided... we would be happy to
# recommend simplii as a banking alternative
# Node ID: 12588a84-e2dd-4c67-a6e5-6f47fa3541d0
# Text: was very helpful with our concerns. He contacted me very quickly
# after I left a message and everything was clearly explained and
# courteously taken care of. I am more than happy with his service and
# help.
# Node ID: c1b67e53-d3f4-4764-88a7-6f10c5b14982
# Text: was excellent she answered all my questions and was very
# pleasant. Thank you
# Node ID: 05bd11ea-f43e-436c-8e54-580a1b994518
# Text: ABSOLUTELY HORRIBLE PRODUCT ! THEY SENT THE GIFT CARD WITHOUT
# AND  AND THE PERSON CANNOT VIEW AND RECEIVE IT !!!! AFTER CALLING TO
# CUSTOMER SERVICE AND TALKING FOR 30 MINS NO HELP PROVIDED !!!!!!
# PROMISED TO PROVIDE THE HELP WITHIN 48 HOURS !!!! ABSOLUTELY
# DISGUSTING !
# Node ID: 6360441d-fa5d-44e5-adb8-3e211092e98f
# Text: advertised an attractive 6  interest rate for 150 days, so I
# opened an account. I had to wait for them to send a card, then a paper
# to sign and for a chance to call them. Finally all was set up to
# transfer funds from another bank, but it was 32 days from first
# contact, and promo interest was now NOT available!!  reconsidered,
# then said NO. HUGE ...
# Node ID: 813196ce-f8c1-4806-9326-753b6fbe9c35
# Text: and  working together, so even your Mortgage is with  the bank
# in behind is , spending million in advertising, but for missing 4.13
# they charge you twice for .  45.00 and  again.In that case I can only
# say we need much more Covid19, maybe we cab stop the greediness.So if
# you like to get your Mortgage go better to  or , but not by that
# organizati...
# Node ID: ac72cc10-11ee-46dc-9345-15ffbd3b7908
# Text: bank in the world. I have had so many problems with this bank..
# trust me the no banking fees are not worth it.
# Node ID: 6371c9b7-3812-4764-aa3d-94d9be2d4f29
# Text: bank to deal with. They froze my bank account  each day is
# another excuse why I cant have my funds back. Higher management doesnt
# care about customers. They lie everyday with more excuses!!. Theyre
# unprofessional. Dont tell the truth about anything I ask them. Dont
# return phone calls. Ive been waiting for paperwork from them for 6
# weeks to get m...
# Node ID: c2db2065-296a-4bfe-91d4-f48bb1b312bd
# Text: bank, I was try to apply a new account, it then asked me to
# email two IDs photos in email. I did, then they sent me another email
# asked to email back 3 IDs, what a jokeDate of Birth on ID doesnt match
# application information Please provide all three acceptable IDs.This
# is unacceptable and very unprofessional, so everyone please be aware .
# Node ID: de71b572-8c60-4692-8e67-4fbe3422d494
# Text: bank. 1 month hold on cheques from major US company. 1 month.
# Just not like the other major banks. Its inconvenient dealing with
# them tbh. I will be closing all accounts etc.
# Node ID: fe338197-4bfe-4ad5-bf29-476103c75e45
# Text: bank. Have had so many issues with them from not being able to
# use my card, spend my money, my account was overdrawn for a week. Got
# paid today Thursday since tomorrow is the holiday and couldnt e
# transfer or use my funds at all. Called and they blocked ny account
# since it was overdrawn for a week. They didnt call me or email me at
# all to discus...
# Node ID: 69325c9f-6a0a-47df-928b-219270a786e1
# Text: customer service
# Node ID: 3c0f21b9-2413-4ed5-a1e9-3a2135e4c066
# Text: ever, will not recommend this bank to anyone especially
# international students. They have an international student line to
# help students with their  accounts but I have been calling on this
# line multiple it keeps on disconnecting. And when the line connects
# the representative on the other side are so unprofessional, she kept
# me on hold and then ...
# Node ID: 7804f9b8-3b59-42e1-87a8-bebf0fd4fa76
# Text: ever.They tell me a cheque that I deposited in my account was
# counterfeit but they wont show me a copy of cheque.The company the
# cheque was from has been in business for 18 years and has never had a
# problem like this before.Then they closed my account keeping the 2,200
# cheque.
# Node ID: d1658334-12ff-4bb1-9f3a-8a676183a1e8
# Text: financial is a great bank if your on a low income bracket like
# myself. Its free of charge and they give you free cheques. Today I was
# charged a  fee of 45 for accidentally not having enough money in my
# account. I called an explained my situation and they reversed the fees
# with no issues. I highly recommend them, great bank.
# Node ID: 3aa179bf-a1b2-40c1-8f91-da2754bbda94
# Text: financial is probably the worst bank in Canada. On January 10th
# someone took 1000 from my account and than on January 20th they took
# 500 . I called simplii and reported it for fraud, Today February 4th
# they called me and said there will be no refund for the money that was
# taken. They told me there is nothing they can do and I should just
# open an...
# Node ID: 06967144-2c2c-404b-9b62-8bcae10cd4a4
# Text: got simplii cuz of their 2 interest rate. Once the month is over
# I will still get .01  upon calling they told me 2 interest will be
# given once the promotion is over after 4 months. of this information
# given prior signing up.Very disappointed folks
# Node ID: e1bd19fe-3d1e-4659-a4a4-9df178692142
# Text: has been having technical issues with my online banking for the
# past 6 days . At least to my knowledge. I have been chasing them for
# the past 4 days to correct my online banking, and I have gotten no
# where other than we are looking into this. I even let them know that I
# am worried as their whole system was hacked not too long ago, and my
# card wa...
# Node ID: 1497b868-429e-4bd5-8ecd-af329564cdb6
# Text: has screwed me over for so many time since I opened an account
# with them. First they sold my personal information to a third party
# called fairstone lending company. I can confirmed that it is really
# them because I used my maiden name on all my bank accounts records and
# all the billings except for when I opened my account in simplii, I
# used my ma...
# Node ID: cda634ce-7c14-48dc-b3f7-4b5e99ba9dc1
# Text: have been with PC banking  Simplii for approximately 23 yrs. I
# have never experienced any problems with this bank. Agents are polite
# and very helpful. I highly recommend. No fees. If you use checks there
# is no charge for them. They do charge  fees but none other that Ive
# experienced.
# Node ID: 52c1d55a-61d9-4ed8-8998-e8fd248d89b2
# Text: have lost their minds coming out with a horrible fluorescent
# pink and green site and card and new motos that make no sense. After
# more than 15 years of banking with them I no longer trust this bank
# and working to close my account ASAP.
# Node ID: 843c246a-8d42-43b5-bfdb-3a9c57ecffe2
# Text: is a great asset to  team He was very helpful being prompt,
# courteous and willing and able to answer all our questions. I just
# want to congrulate once again for the terrific job, we are forever
# humble and grateful for his service! We will certainly recommend you
# guys to anyone I know in the market for a mortgage.. Thank You soo
# much once again f...
# Node ID: ee58b878-2acf-4174-a865-c2ce0d8a7a43
# Text: is a joke Had to make 3 calls and each one gives a different
# answer. Consistently on hold, talk for 30 secs than 10 min hold I
# canceled
# Node ID: c254ae26-8096-41cc-b073-68949980676a
# Text: is a shi.t bank. To get someone on the phone it takes more than
# 50 minutes. Waste pf time. Hopeless customer services. PC financial
# was way better than this shit bank .
# Node ID: 7cdb02d8-8a0d-44a6-b234-f34ff0ee60a6
# Text: is awesome,from the very start till we finished the
# transaction,and all paper works,and got approve,tnx..
# Node ID: 00b0b690-693a-4432-b90f-60fcc048ece7
# Text: IS SHI.T , its not actually simplii, its shittiiii, worst bank
# ever and never answers phones
# Node ID: 8c4fe40e-1fe2-447e-be1d-4503752d246d
# Text: is the best than ever from your bank so really to her and want
# raise his rank and salary because she is exellent in understanding and
# describing everything.
# Node ID: e6f6331b-b7bf-415f-a4d1-8589bc6d5d19
# Text: is very Nice and Friendly, Polite and explained clearly,
# Node ID: eb72e850-866e-45bf-af7b-80da864b3acc
# Text: made it fast and easy to renew our mortgage rate in order to
# beat the BOCs hike on March 2nd. The service was fast, prompt, and
# clear.Thank you so much for all your help!
# Node ID: 2339c7c8-9186-4ffd-b7b5-7e59f75447c7
# Text: should be a synonym for the worst customer service in the world.
# Their employee do not know what and how to write an email. They will
# write the same thing whether your query is  or XYZ. They make fake
# promises to the customers that the issue will be resolved and then
# they do nothing for 10 days, even after followups.
# Node ID: 602169c8-b698-4dc5-90ca-e6ad153ca4c2
# Text: Terribly long wait times for anything. All banking issues  have
# to be dealt with through the phone and they  dont pick up.  terrible.
# I am writing as many bad reviews as I can find places to put them
# while I wait for them to answer the phone. If I cant give them heck
# for making me wait for hours, Ill let them know this way. Dont bother.
# Find a b...
# Node ID: 8b74fd1a-7449-43f5-a41a-cc8a06e2e942
# Text: walked me through the mortgage process and was in constant
# contact during that time. If she could not immediately answer my
# questions, she quickly researched and got back to me within 24 hours.
# Amazing service!!! Thanks !
# Node ID: 3926f1da-8f13-4f1e-9df5-d1bf6bed4f48
# Text: was very helpful,respectful,and very professional.He provided
# all the information I needed ,thank you
# Node ID: 43216f87-a630-4f10-a19d-bedae6f31f58
# Text: was very polite, dealr efficiently with my issueThanks
# Node ID: 4f6347de-c1fe-4664-a3ea-e057e7929810
# Text: , the 400 bonus dont count for  payrolls but they wont tell you
# about this. Customer service is hard to reach.
# Node ID: 34e6cf77-abd3-445d-be36-bc49ff4df500
# Text: . Theyre incompetent and they take forever to give you an
# answer. Nobody is able to do anything. Because of these guys Im about
# to lose the money for a down payment just for a simple fix that I did
# with another bank in less than 5 mins.Once I get my draft, Ill close
# my account with  for good.
# Node ID: a0d5b7bc-4c1a-45bf-97e2-98be158168b1
# Text: ecently got a mortgage with  and  went above and beyond multiple
# times to help me through the transaction. She proactively and
# effectively communicated and worked tirelessly to complete my mortgage
# in time. If you need an exceptional , call  x8907
# Node ID: 38b4cb09-2874-4239-854e-7377a14d984f
# Text: mply took my government check for 47,000 dollars and wont cash
# it or send it back. I have a large amount collecting interest on their
# line of credit while they hold me hostage. This is the most corrupt
# institution I have ever dealt with. Avoid them at all costs. There are
# real banks out there who will be happy to have your business. Try .
# Its a ...
# Node ID: b2a8a59f-96f1-4437-9ed5-973bd0cfc5e4
# Text: 1 is the lowest rating I could give here unfortunately.
# Absolutely pathetic service. I signed up and never received a card. I
# phone them twice any card and everytime they told me the card is on
# the way. Its been 3 months and havent received anything yet.
# Node ID: 2da499fe-d5a6-4beb-b2b4-68f5910e9156
# Text: 1 person can make a big difference in navigating all things
# mortgages and moving!  is my rep and he is excellent at what he does,
# personable, accountable and goes over and above to ensure you
# understand whats needed, whats happening and even after the fact
# checking in to ensure all went as planned. Cant go wrong with !
# Node ID: bc594f4a-94fa-4bdd-b088-ac1b852dcd91
# Text: 15 Days ago I deposited my work cheque with  without being told
# I would have to undergo some extensive verifications to access my
# money, let me open the account and then froze my money instantly by
# locking all means of moving my funds, now telling me I need 2
# government photo ids to verify, but the government of Canada says I
# only need 1! Guess ...
# Node ID: f6e5255d-19c1-4c98-be35-453977c175ce
# Text: 5 stars for . Very professional , knowledgeable and extreemly
# helpful. I did not have to ask for anything and she provided an
# amazing client experience and truly made my day. You should have more
# like her 100 ...thank you much for all your help and offering such
# amazing service. Above and beyond in my book
# Node ID: f925fb94-e9fc-4ef0-826a-6d96db7cb554
# Text: 500 in  FEES IN 1 WEEK.Sorry, I meant 16 weeks. During a
# pandemic and I have been with them for six years. Wont be seven. Lol
# Node ID: 5f338048-23bf-4158-8214-791cc9bf9f2f
# Text: 6 you cant go wrong. costumer service was good. I didnt use a
# promo code and missed out on the free 50.Dont forget to join with a
# link to get the bonus 50.  6Dfjmv
# Node ID: 17a5a0f7-d8c2-4a56-85f0-2b9f12c4fead
# Text: A bank rep mistakenly filed the wrong form or checked the wrong
# item on the form, which resulted in me paying roughly 36 000 in taxes
# I wasnt supposed to pay. Its been 5 months and nothing is done to fix
# that. I cannot contact the   they seem to be closed for quarantine.
# Interestingly, the bank itself doesnt seem to have a web page for
# complaints.
# Node ID: 761e86e4-7b16-4ff4-8cea-dc6d6aca5b03
# Text: A followup call to their customer care center regarding a bank
# draft I ordered turned into being transferred to a  who was hesitant
# to issue the draft based on a large cheque deposit from approximately
# a week or more ago. The cheque had passed the usual clearinghold time
# and it was from a reputable large company, not at all a personal
# cheque or ...
# Node ID: 4c735bba-35a2-4f16-b7c1-8f2746c6608b
# Text: A lowlife, deceitful organization that does not care about
# facts. They cater to their low needs and disguise it as
# professionalism. Definitely see a more reputable bank, , maybe.
# Node ID: b8eaa4f4-9a7a-4e55-9a52-40d60f38b813
# Text: A terrible bank, I had to change my phone number. They made me
# return to the branch 20 minutes from home. The next day my card would
# not return from the atm. Another hour on the phone. They are a awful
# bank.
# Node ID: 9ee8a6e0-ae0d-44db-8c0b-0276334fb8a2
# Text: Absolute bullsht bank. Been trying for 3 weeks to open their
# high interest savings account and to put money into it. There is
# always some kind of screw up. Its impossible to navigate this cluster
# of an institutionbut they do have the coolest looking debit cards I
# have ever seen
# Node ID: f42f62ac-b286-4410-b406-0467dfe355e4
# Text: Absolute garbage, applied for a debit card got approved and they
# said they were sending it out over a week ago. Tried to get in touch
# with the customer support, they dont let you talk to a real rep
# without a debit or credit card number. What if I lost my card how
# would this work? Way worse than cibc garbage interface
# Node ID: 7b59a050-d100-47db-b128-faae5efd32c8
# Text: Absolute incompetence, incapable of providing any customer
# service at all and nothing but excuses after excuses !! you are better
# off dealing with anyone else then these people !! Complete waste of
# time !!
# Node ID: 6273d332-c1f4-4524-bdb2-56630050b438
# Text: Absolute nonsense. Better off keeping your money in a piggy
# bank! I just opened a new account and as per their policy, I have a
# daily withdrawal limit of 200 for the first SIX MONTHS!! Even after
# that the  withdrawal is 1000 a day. They  is just trying to make as
# much money off of your money as humanly possible. I do not recommend
# this financial...
# Node ID: 26741975-8da8-4304-876c-9e527d11f418
# Text: Absolute worst bank I have ever dealt with. I have been banking
# with  since the switch over from  but my experiences over the past
# year with this bank have been terrible. Extremely long hold times,
# very poor customer service, a terrible system all around. Too many
# problems with them to get into on this review but felt the need to
# warn anyone thi...
# Node ID: 7b35aa3f-7cbc-4c50-a881-79ea33a5a636
# Text: absolute WORST bank you could choose. they have what seems to be
# students working the phones and customer service and know absolutely
# nothing about the company or how to help. they sent me broken debit
# cards that dont work and refused to even be slightly helpful and said
# it must be my pin. ive done all they said and still nothing so at this
# poin...
# Node ID: 425f7daf-c90c-4e20-91ea-c914b894f799
# Text: Absolutely atrocious!!!!!!!!!!Do not ever go with this bank
# their customer service is the worst out there I am appalled, waited 8
# days for a cheque to clear from work countless hours on the phone and
# then passed yet again to another department. Dont sign up no matter
# what!!!!!!
# Node ID: d82a0148-256d-4683-a463-eebc6d3a14d3
# Text: Absolutely awful service. I sent a money transfer 10 days ago
# and havent gotten anything. On top of that they have no idea where my
# money is. Says I will have to wait upto 21 days to get an answer,
# which is absolutely ridiculous. Will be switching banks as this is
# unacceptable service.
# Node ID: 39cc478b-632e-4c1f-add2-ee252496ff03
# Text: Absolutely brutal customer service.They will NOT listen.I was a
# good customer for years, but when my wife deposited a baby bonus
# cheque endorsed to her by my son,  locked up my bank accounts for 2
# weeks and counting! My son cannot buy food for his children. Avoid
# this bank like this plague.
# Node ID: ac80f72d-1fde-4fa1-aaa1-93c2566bb05c
# Text: Absolutely fantastic service. Had a cheque issue and they fixed
# in a timely manner. Thanks !
# Node ID: 84188973-97cc-48dd-9d40-d5fe97c565b5
# Text: Absolutely horrible! Do not bank with them. They held my check
# back, would not clear it even though it was exactly the same as other
# checks I was depositing twice a month for the past 10 months and had
# no issues with any of them. They did not call or email me, or notify
# me in anyway that they were holding my check hostage. When my mortgage
# came ...
# Node ID: c2d4685b-fb4c-4cc5-8fe4-1cde7b0e3bea
# Text: Absolutely infuriating company. If you ever need to do things
# quickly, dont use this company. If you are ever looking to make big
# purchases home etc or anything professional do not use. NOW on top of
# how big of a headache this company has been without forewarning they
# have frozen ALL my funds, bc i was putting money into my account from
# . So now...
# Node ID: 1a585309-d5cb-433e-aeff-0357a86606a9
# Text: Absolutely terrible and incompetent service. Had a basic account
# there for over 15 years. Applied for a credit card since they kept
# sending me promotions. I have A1 credit and earn close to 140k. I was
# willing to close one of my higher interest cards for . eceived
# approval, but no information on limit. After waiting on the phone and
# being transf...
# Node ID: 33c71c1c-6e96-45c1-b1a4-e9ea84eb1108
# Text: Absolutely terrible customer service. I was directed to a
# manager who would not let me speak and was incredibly unprofessional.
# Ultimately I closed my accounts with them. I would not recommend this
# bank whatsoever.  in general is going downhill significantly.
# Node ID: 7ec46349-24e8-4c96-9879-d6318eaccc1c
# Text: Absolutely terrible process!! Big mistake to be their customer.
# I wanted to create joint account for husband. A month later still back
# and forth correspondence and phone call. Please do yourself a favour
# stay away!!
# Node ID: 738f5cda-2c29-408d-b3f1-e96e8cd58e92
# Text: Absolutely terrible, make the mistake of opening an account with
# them, sent money to the account, just for them so say I didnt qualify,
# told me I need to close my account that still had the money I sent to
# it in it.. said it would be 7 days for the account to close and money
# would return to account it was sent from.. literally gonna be waiting
# f...
# Node ID: 08dc997c-0ed9-48a5-8f59-9e2d4d3f4aa0
# Text: Absolutely terrible. Advertises itself as a no fee chequing
# account with unlimited e transfers. Had my account closed on me for
# doing too many e transfers
# Node ID: 96accc3d-8841-4b50-8b25-4c0ba4553ff9
# Text: Absolutely terrible. Between the amount of work that goes into
# simply opening a bank account, to finally telling them to leave me
# alone and the fact that Im still receiving emails week after week.
# Even though i spoke to a customer agent including a manager who all
# promised me that the emails would stop, yet they continue. Ugh!!!! Go
# away and lea...
# Node ID: 6671ea8d-b41b-49f9-850d-67dd54364d39
# Text: Actually  has provided good friendly service to me for years,
# except today. I got email to call  relating to a problem l had with
# transfers. Spoke to  who was the worst customer service personnel
# ever. He was cold, no enthusiasm, poor attitude, and even hung up on
# me. I hope management can listen to the recording and judge
# accordingly. After bei...
# Node ID: 6955ad0e-8957-47a1-aafb-c2a9162a3ec8
# Text: After over a decade with  which switched to , this month has me
# looking for a new bank. They suspended all my accounts...twice,
# because I owed them a penny from interest that wasnt paid in four
# months. Between the two episodes of freezing of my accounts, the penny
# had been paid. What a messed up, poor customer relations that have far
# reaching re...
# Node ID: 5b7b7ede-3e56-40ba-94d0-080391bbbe2f
# Text: After the tedious effort to refinance to reduce fortnightly
# mortgage repayments, I was very disappointed with the outcome.I was
# quoted by  as saving over 80 fortnightly, better in my pocket than the
# banks! When settlement happened, it turned out to be20. Not worth the
# time or effort!!!
# Node ID: f5a1acbd-107b-431a-b473-5ffcc3b81278
# Text: All my finances including my mortgage are with simplii. The
# mortgage part was taking unauthorized extra payments. I called  had
# the ususal on hold wait time or 30 minutes to talk to someone to have
# them stop taking additional payments. Two weeks later they took out
# more than I owed again. They charge me interrest to borrow money  if I
# didnt have...
# Node ID: f8d7a446-6a60-48af-abb9-a76a65539e7e
# Text: All of a sudden I have all these u known charges on my acct that
# are fraud charges I never had this problem before I used this bank tge
# 1st time I didnt notice the charge in time to do anything the 2nd time
# they fixed ut and put money back in 2 secs 3rd time I have to wait 90
# days Im pinching pennies as it is already kow I have to wait 3 months
# ...
# Node ID: 839fde49-f3c4-4d31-8681-a8d5c7c7c3f4
# Text: All of a sudden they froze my account...i couldnt access any of
# my money, couldnt get bills paid, the automatic withdrawals for my
# mortgage and condo fees were held making me have to pay fees to these
# companies. Trying to get information...on hold for 20 minutes or more,
# being sent to different agents and having to explain over and over.
# There i...
# Node ID: 8b8570a6-0ef8-4809-b70b-4351d6cb1279
# Text: Although my log on to my online account is still outstanding
# issue, i would like to say my appreciation to , the manager of . She
# has spent a lot of time over the phone with me to figure out the
# issue. She sounds professional and responsible. Thank you, .
# Node ID: cd946eef-b75a-4c2d-a83a-8107f28c9955
# Text: Apparently if you try to e transfer the  amount 3000 they lock
# your account under possible fraud? This is a joke. Spent last two days
# trying to unlock it just to send money back to my other REAL bank.
# Customer service is not rude but also not the most helpful or informed
# with proper info. Over a 2 hour wait on the fraud line. Unfortunately
# tied ...
# Node ID: 669d97f7-ef05-4174-a710-8a9854b24b9a
# Text: Are they actually a bank? The service was terrible. I never
# write reviews but the girl was rude on the phone and I never got help
# with what I was looking for they just made a ticket and will email me.
# Node ID: 6071a1ba-1c8e-47d2-937d-ed4934bfa564
# Text: AVOID! been with  since it was .its gone downhill as  has
# clearly tried to milk all the money out of it without putting anything
# back in.Low rates. Noncompetitive accounts. Features regularly removed
# from the app forcing you into  branches which dont want to help you
# because youre not . Not all banking features can be done with They
# have spent m...
# Node ID: 7cf88833-1ae8-4a48-8745-38bf529670c4
# Text: Awesome experience,  was amazing
# Node ID: 24439712-1514-41d5-827e-67e98bf5bcf3
# Text: Awful bank. They dont have any upfront fees but will scam you
# out of money at every opportunity they can and will do nothing to fix
# it. Stay FAR FAR away from this scam of a bank
# Node ID: 32f2caea-8692-4fa4-b085-0be482e1b5d4
# Text: Awful experience with this bank. Ive been with them a long time
# and then suddenly they froze my accounts, claiming Im not me. They
# have my ID and all my statements and cant change this til the first of
# the month when everything is due out of my account and will bounce
# because nothing will be able to come into the account. They are
# terrible!!!!!!
# Node ID: 6bed1325-48b9-4998-9d4d-d6a4a7fd1869
# Text: Back in September of last year, my  financial account was hacked
# and someone stole 6,000 from my savings. After being on hold for over
# 2 hours,  financial didnt lift a finger to try and help get back what
# was stolen from me. I am struggling financially to this day because of
# them. DO NOT trust these horrible people with your money. You will
# only...
# Node ID: 66e8b4e9-64ed-4934-919c-fdbe9bda5abd
# Text: Banked with them for 15 years, as far back as them being  and
# today I closed my account. The customer service received was
# disgraceful and the stole 180 from me in bogus  fees, telling me they
# were warranted. I will NEVER bank with them again, and you shouldnt
# either.
# Node ID: 3d78f07e-aa9b-4e2c-aba4-3f83cdd4bc90
# Text: Banking online is ok as long as you do not have problems. If you
# do, good luck trying to get it resolved by the staff or even manager.
# Even for simple request like removing the tap for debit card for my
# wife. They treat you like a criminal or fraudster for simple request
# that pose no security risk like that. Staff n manager dont use good
# judgmen...
# Node ID: dac0522a-dc34-456a-aefb-2289b4feb253
# Text: Banking side of it is fine, their credit card gives great
# cashback on bars and restaurants.The issue that is increasingly
# annoying me is the 2FA on the web version of their site. There is no
# way to mark your device as trusted or anything...you have to get sent
# a text message EVERY SINGLE TIME and this is putting me off using them
# more
# Node ID: 2bb8d767-b918-46fd-940d-8083df1e982f
# Text: Basically, there is no customer service at all. I had questions
# about my account. Called them a few times recently, the waiting time
# for each is between 45 minutes to an hour, and nobody can help. I wish
# I could give this bank negative star if I could.
# Node ID: f710b557-b5c4-44eb-b946-9eec1eabd21b
# Text: Be Careful on Wiring Into .I tried making a wire transfer out of
# my business account destined for my personal account at on June 8th,
# 2023, and finally on July 6th, 2023, almost 1 month later, managed to
# recall back into my account most of the funds the original amount less
# the deductions by intermediary banks involved in handling transfers on
# b...
# Node ID: ee0ded9a-3a3a-4b04-8a43-17fe97f322d7
# Text: Be careful simplii doesnt inform you about security issues on
# your accounts, very poor customer service
# Node ID: dfdc5a85-69a8-4843-9898-a5a7f5ce74b6
# Text: Been a client for many years with  President  very good. Always
# a knowledgeable person in the grocery store to help with everything.
# Then in comes , out goes , in comes, , results disaster. No person to
# talk too just 1 888 to ignore clients. Move funds between 2 accounts
# took 2 months. I changed home address OK, however  been trying to
# change my...
# Node ID: 8fddcee0-7380-473b-b4ba-5e88ab16436e
# Text: Been with  which then turned to simplii financial for over 10
# years, never had an issue. Customer support is always pleasant and
# helpful love simplii financial
# Node ID: 44d3efde-e19d-474f-88a2-03f8aa79e3e1
# Text: Between two calls today I have spent over two and a half hours
# trying to registered for secure messaging so I can get forms I need to
# set up  Acct to allow me to transfer funds between my  chqing acct and
# my Simplii A. Each time I try to register it keeps asking me for my
# Password that I have created after I confirm my password and wont let
# me g...
# Node ID: eb06cd18-64c7-4952-ab2b-50b36d1c60be
# Text: BEWARE .... Simplii bonus interest is not paid until 30 days
# after promotion ends!! Its a clawback!!
# Node ID: a0ff2661-c6f5-4481-bc78-f2ea6a106381
# Text: Beware of Simplii ! ! I deposited 2 checks , and they hold them
# for 3 weeks ! I called them several times, they refused to release my
# money! And till now its still not available to withdraw! I dont know
# how long do I have to wait . I NEVER EVER use Simplii again ! ! !
# Node ID: 60a981f2-8658-49cd-a91e-182d135fbeed
# Text: BEWARE!! Do not sent any global money transfers through simplii
# finincial, their fransfer rate is robbery, i thought id give them a
# try as my bank and they say 1 to 3 business days, its now going on 3
# weeks since i transferred money to the philippines, and if i did not
# follow up everyday, they simplii finincial will not follow up with
# you. this ...
# Node ID: fbcc9077-6aee-4ce6-9cee-c6fbf404407c
# Text: Bro... this piece of sh!t bank has fuced me over COUNTLESS
# times... customer service is dog sh!t and requesting the supervisor
# isnt worth sh!t because fucing retrds cant help you any more than the
# minimum wage workers can.. E teansfers are a fucing  because every 3rd
# transfer takes 3 fucing days and gets sent back to your account with a
# 3.50 cha...
# Node ID: cb767ed2-0234-406b-b4d5-e33f0a206c8d
# Text: BRUTAL...been a few problems but heres my tipping point. I
# called to have my daily limit increased from 200. Rep said only 500,
# for my own protection, really? Then said, I can change it for one time
# if you need it today but you only have to hours to get to a machine
# and get it. Meanwhile, my pay goes to this account. Also, once my
# account had an...
# Node ID: 04b0ec74-5061-44b4-a7dd-0911eaf9066f
# Text: By far the worst bank I have dealt with. Liers, incompetent and
# deceiving. Thats all I can say. I am removing all the direct payments
# from there, and will close my account. Use  or EQ. Way simpler to deal
# with.
# Node ID: b848ba27-ea5b-406b-be3a-f4f8212dd920
# Text: By far the worst bank I have ever banked with. I just opened an
# account 2 months ago and since then my card has been randomly locked
# and shut down, leading to multiple embarassing circumstances of my
# card declining in public. Further, my cards are currently shut down
# because I never signed a paper they  TOLD ME TO SIGN and now I cannot
# go to the...
# Node ID: fbe17bf7-766b-41ec-b12f-491b1b3a10a8
# Text: Call summary You do not have a right to close your accounts or
# understand why you are not able to close your accounts, and we are
# unable to verify you over the phone. You have to physically travel to
# to verify youre you. Initial reason for call I called to cancel a
# credit card because it didnt work. Apparently making a purchase with
# your credit...
# Node ID: 57ab5fbe-7bad-4241-bcfc-82e6f4e95d43
# Text: Completely atrocious service. Long wait times, and incompetent
# agents.  doesnt work properly 20 percent of the time. Save yourselves
# the hassle and go to another bank.
# Node ID: d180801b-53a1-4bb2-93ea-29c33affeecd
# Text: Couldnt even get an account or anything actually its a waste of
# your time dont bother junk bank
# Node ID: 37857f1f-964d-417b-a2c2-826ed5e9af86
# Text: Couldnt even get through to activate my card.After waiting on
# hold for over 20 minutes on three separate occasions to just activate
# my card  I gave up. All that waiting on hold unfortunately gave me the
# chance to see if this was a common problem, and judging by the reviews
# here ... yes! Customer service is a problem. If this is how they treat
# a ...
# Node ID: 3b1f2551-53c8-4c59-9d59-4560c387ea85
# Text: Customer service on the phone is terrible. The wait time
# generally is close to one hour.
# Node ID: a1a4625b-c1c2-4986-ab98-fdd952e34a6d
# Text: Dealing with this so called bank is a true nightmare. Lack of
# knowledge and customer service, from lower tiers to upper management
# is atrocious.Not only is it difficult to get in touch with anyone, but
# the chat service is absolutely useless. Responses to email take eons,
# escalating matters to management is an utter joke and a complete waste
# of t...
# Node ID: b9024916-48f9-4416-9ed0-f470f2befb28
# Text: Deceiving lies. Applied for a no fee checking account with
# overdraft protection and was approved, got my card and pin today,
# logged in and couldnt find my overdraft limit. I called and they said
# I dont have a overdraft I wasnt approved. Thanks lying scumbags hope
# the worst for your buisness and everyone who works there. And Ill be
# leaving  soon,...
# Node ID: 305530e8-a923-4b82-8472-0bfe6a5d51e7
# Text: deceptive marketing, cumbersome web page very 1990s design too,
# other online banking services are smother and more straightforward.
# Also I had to call many times to get my promotional credit. Difficult
# customer service with long waits and they give you the run around to
# make it even more burdensome. I went back to my old bank, the orange
# one. Th...
# Node ID: 9f536125-e84a-4715-b4d3-e41518c66c81
# Text: Did a hard credit checkequifax to apply for a debit account
# Node ID: 3c5aacfa-9e85-40e1-945d-e243f2298885
# Text: Disgrace of a company, surprised that they are still allowed to
# operate. Do not give them your business they should not be
# trusted.Would like to give 0 stars.
# Node ID: d8788343-3277-40aa-b695-c14063e07409
# Text: Do not bank here!!!!!! They are crooks, there are no branches so
# they hide behind their phones. This bank and  should not be in
# business but they are getting rich off keeping poor peoples money.
# Node ID: c4d4ff06-09e9-462a-ba36-eaec605e5566
# Text: do not ever go to this bank, im a brand new customer , trying to
# etransfer funds to my other account and ive been on hold waiting for
# customer service for 9 12 hours in the last 3 days, no exageration.
# Node ID: 0cd1d6ad-a438-4de6-a1e3-3097adb486fa
# Text: Do not trust the promotional offers advertised by . I moved a
# large amount of money expecting to get 2.7 from April to June 30,
# 2022. Before I transferred the money I phoned and the agent assured me
# I was eligible to receive the interest rate.For some reason,  dont pay
# the interest until the end of July which is annoying, but at that time
# I noti...
# Node ID: 72765222-b281-4061-93f8-9adedd301971
# Text: Do not trust this bank.  interpret favorable with bank not
# client.
# Node ID: 8ccd2e32-ad41-4a0f-95b4-ae9e9d85ba78
# Text: Do not use this bank for investment purposes! You never get the
# same information twice from customer service. Part of a divorce
# settlement was receiving RRSPs. The bank told me it would be 12 to 15
# days for it to show in account. 15 days past...nothing. so I called
# back to customer service I was then told No NO....it is 15 to 21 days.
# THEN, I ne...
# Node ID: f5a9100c-54d5-46c5-80ba-08a9a45d4af0
# Text: Dont Bank with these sharks....i have never had a problem
# banking with mplii Financial IS HORRIFIC.....They DO WHAT THEY
# WANT....THERE ARE NO RULES...you may as well deal with the local pawn
# shops.....they decide when they are going to up your LOAN AMTS....with
# excuses that we are so sorry that you were told that but they were
# wrong so now your ...
# Node ID: 3008d8e3-69c6-49d3-a56b-5ed65436ba2d
# Text: Dont believe the sales pitch, full of lies!I had over 400k with
# this bank with a promo rate of 2.75 for 3 months. Once the 3 months
# were up, I called them to see what had happened because the interest
# wasntin my account. I was assured that the interest would be deposited
# into my account sometime at the end of July. So I waited and didnt see
# anyt...
# Node ID: 65d43037-2170-41ef-b32f-81b1f613b17d
# Text: Dont change your phone number, as they are useless, they want to
# send a verification code to your old number. UM did you just hear what
# I said? oh no you have to drive to town to a  bank, make a transaction
# and print out the receipt call back, wait online for 45 min to speak
# to a Manager and start again. Unbelieveable!
# Node ID: 9683dc94-e24d-443c-b90c-e67280139198
# Text: DONT do it! Takes up to 6 days to process certified cheque
# deposits, 35 days to process online payments, card not accepted at
# MOST US hotels or restaurants, 200 limit on out of country withdraws,
# no CRV code on card means its useless for most direct pay apps like
# and . Though I had 250k in my account, I ended up stranded in the US
# and sleeping ...
# Node ID: ede2472d-f58f-469a-b2c2-f2c6113ac1fa
# Text: Dont do it, There not as good as they say. Wait times on the
# phone can be up to 4 hours there stuff have no idea what they are
# doing and they freeze my money all the time just because they can but
# they say it was just a silly error that happens sometimes which is a
# lie because it happens almost every other Month. This month they are
# legit tellin...
# Node ID: 52106324-f004-4a40-b3a1-bf795b044bfd
# Text: Dont ever trust this bank when it comes to promotional offers as
# you will get robbed from them. It doesnt matter if you call someone to
# send you an eligible offer because once that offer ends they tell you
# to read the fine print yet why didnt they tell you about it in the
# first place? Total waste of time, the account may be free but they try
# ver...
# Node ID: a61a4163-54e9-460e-9d4f-06d91b67bdbe
# Text: Dont expect  to call you if there is a problem with your
# account. Apart from closing my account for being overdrawn they
# actually closed the account without notifying me. In fact the account
# was not overdrawn, the balance was in the name of someone I had added
# to my account and someone I thought I had removed. The result was all
# my pensions were...
# Node ID: 03f61707-e32d-4f9d-957c-2e2fd090dc8a
# Text: Dont trust this bank. In starting they will tell you something
# and afterward they are telling its our fault. I am totally
# dissatisfied with the service. They always gives the wrong information
# and if you tell them your executive told me like this. Then they will
# give another reason to put blame on customer. Its a fraud.
# Node ID: dbbfa570-57d0-46ac-ac8f-695ece88ea41
# Text: Dont waste your time with . Grandmother applied for a chequings
# account online. She was approved and was sent a card which she had to
# call in to activate. She doesnt speak English very well so she asked
# me to help her translate if she didnt understand something they asked
# her. When I called in I explained this to them and that we were on
# speaker...
# Node ID: cee65dbb-98dd-4c3c-8d34-37d5223d1e07
# Text: Dont waste your time with this bankI set up the account on
# October 17 and its now Nov 1. Spoke with 3 agents and finally a
# manager. They all have different ways and excuses. Very
# unprofessional. This bank will waste your time. They hold up my 3000
# for these days and benefitted from it, Im not talking about just my
# money, but look at the number o...
# Node ID: 51c5b79e-56ee-4fbb-9b22-397126e19c39
# Text: Earlier I was disappointed but when  handled my issue, it became
# so easy as she eased the process and took care of my concerns. Thank
# you  for being so kind
# Node ID: d36da19c-c862-42c8-86bd-e4a4120b7415
# Text: Easily the worst experience I have had with perhaps any company
# in 45 years. My accounts after 4 weeks and over 9 hours on the phone
# are still not set up properly. I was given 100 for my time wasted.
# Total incompetence and a nightmare to deal with.Go to . They know how
# to do it right.
# Node ID: 81ecf354-ce04-4707-98e4-dcd4da0181cb
# Text: Easy to use and reliable app. Good call service staff. No fee
# for all my banking needs.
# Node ID: ce33a1fb-84f8-4ab4-9361-562a986dc453
# Text: Etransfer service down on the first of the month, all day. No
# communication. Seriously long wait times on phone and chat. They say
# on twitter that the issue is resolved, but it isnt! They dont care if
# your payments are late because of them. Zero stars. You can not trust
# them. SLIME!
# Node ID: e18f564e-34ec-4865-aafb-d4468a54d91c
# Text: Ever since  changed to this new look I have not been able to
# sign on using either one of my computer systems  and Windows.
# Fortunately, was able to download the app to the phone, and now that
# is the only way I can bank. Spoke to a useless person there, who told
# me the problem had to be with my computers. Thats funny, in all of the
# previous 15 ye...
# Node ID: e147c43e-0353-4125-b065-38f03406eb81
# Text: Everything goes wrong whenever I call them and wait an hour to
# speak with a rep. Most recently I had an unauthorized transaction and
# its going to take 90 days to investigate. Save yourself the stress,
# just suck up the 15 monthly fees with a proper institution. How these
# clowns are legally allowed to operate shocks me.
# Node ID: f0d1ee29-4756-431e-9b75-6f81faf3e07c
# Text: Excellent experience!I had an excellent experience obtaining
# payout statements for a mortgage with a  that I was having difficulty
# with.  went out of his way to assist in a timely manner!
# Node ID: 42a10057-c588-4b13-8da8-99227037b457
# Text: Extremely poor customer service and outdated policies that are
# not wellunderstood by frontline workers. Speaking on the phone and via
# email with male agents  condescension and misinformation. There are
# plenty of other online banking options with better interest rates to
# choose from.
# Node ID: 461dcf1f-4bd9-4df4-a4ff-1171b5c98f9d
# Text: Extremely poor customer service. I started with them when they
# were PC financial and was always happy but not now. After making a
# global money transfer from Canada to the USA everything went wrong.
# Right away I realized there was an error and could not find any way to
# correct it.  I spent hours on hold trying to talk to someone but no
# one answer...
# Node ID: 542e9e20-e083-4c68-9c29-a0bfcc53130e
# Text: Extremely quick call back service.  was extremely helpful and
# able to answer all of my questions and make all of the required
# changes to my mortgage. Well deserving of 5 stars!
# Node ID: e3053377-f816-4f22-aadb-90d72cf19bad
# Text: Fire,  right away, he is a narcissistic jerk, who does not care
# about loyal customers at all,  off to , he was extremely helpful.
# both, Managers at simplii financial,  made me feel like unwanted,
# trash. and I wanted to close my account, I have had for almost 20
# years while  was super helpful and deserves a promotion,
# Node ID: 41f3ccfa-be04-4708-94d5-f93b570c0452
# Text: first my gic funds took days to transfer and I had to make
# multiple phone calls for it. Then my account was blocked, and I wasnt
# even informed I just found out because my card declined. The customer
# helpline people dont even pick up or they transfer you to another
# agent and it takes so long like even an hour or two for them to pick.
# ...
# Text: was referenced in , and decided to sign up for a basic bank acct
# for my son. bottom line, be prepared to have a few hours to deal with
# their incompetency, and thats only from the phone conversation side.
# in addition, be prepared to have to call back again the 2nd time just
# to follow up after a week and a half of no update with regards to the
# acc...
# Node ID: 84d64e74-947a-4f52-a0b1-d03bc53ab6b1
# Text: Was with  for years without any issues. With Simplii they
# decided to freeze my accounts for no good reason. Every time I called
# these fools I got put on hold for an eternity. They forced me to
# present myself at  and scan a barcode and show my ID. It took them
# more than 6 hours to deign to send me the stupid code. By then it was
# after closing tim...
# Node ID: 730c2745-0e2e-4fea-9c92-557112c19a0c
# Text: Waste of time. Took the time to fill in application only to get
# a web error. , Im a software dev and you literally just lost a
# customer because you couldnt test your registration workflow. Shows
# lack of professionalism and attention to detail.
# Node ID: 28649601-4a18-4a09-b6a4-641278748728
# Text: We are trying desperately to get away from this disgusting
# example of a company. Theyve locked down our money to the point of
# going on 2 MONTHS now since we started the process of switching banks!
# 2 MONTHS! With no access too the account! We almost got evicted for
# Christ sakes! And the bank thats trying to get our account away from
# these thieves...
# Node ID: a5e76be2-1bb0-4a72-b8eb-5017a2ae0aca
# Text: We have been blessed with  mortgage for past 15 years and every
# time we get below average interest rates and above average help. Thank
# you
# Node ID: fc065a73-cf4e-4214-92ee-aa39be89bd20
# Text: We have dealt with this institute for over two decades. For the
# past two months, they have blocked our account for no apparent reason.
# After numerous attempts to talk to someone to ask why this action was
# taken, an agent finally stated that our account was one penny
# outstanding, which anyone with a sound mind would say, this is
# Ludicrous! We hav...
# Node ID: 1d68e0d4-4a43-4e38-8011-78546c16a329
# Text: We havent had problems with any bank like we have with simplii.
# They have gone in and out a good on a lot lot of money. We have called
# and called and called some more and every time it gets worse.  can
# help. I still have money going into account from work. We do this in
# hopes they dont steal our money. With no bank to walk into and see a
# real pe...
# Node ID: efd3104f-2621-4e20-a6a8-8d74e7da4fad
# Text: We just renewed our mortgage and refinanced. We have been with
# for over 20 years and have never had issues until now. Our rep
# dropped the ball at every turn and the amount of back and forth to get
# the paperwork done in time due to the mishaps was unbelievable. The
# last straw was our goodwill gesture of 100 to cover interest they
# messed up on b...
# Node ID: 57b87f64-621b-4504-986d-c215c0325de7
# Text: We moved our banking accounts to  when they began.. I was just
# so frustrated with our banks endless fees and poor customer
# appreciation and service. When it changed to  I found things actually
# got better and I was already happy with . We still had our mortgage at
# our old bank and it was renewal time and I was not at all happy with
# the service I ...
# Node ID: 960c2e76-2ed8-4057-97da-8a4946211af0
# Text: We needed money out for a deposit on a home, Wow you would think
# that instead of me and my spouse, They had earned all that money and
# were trying to keep us away from it at all costs. After several hours
# on the phone my brother stepped in with a bank draft for our deposit
# and paid the realtor. We were left on the phone again arguing to stop
# the ...
# Node ID: 68f8aae8-d08f-4f66-937d-47b21e85836c
# Text: We paid out our mortgage on January 1, 2021. Our house was sold
# and the proceeds are being held IN TUST until  provides the discharge
# papers. It is now April 7, 2021 and we have yet to receive the
# discharge documents from them. They blame , but after the second time
# I blame them. They are totally unhelpful and act as though it is my
# fault that t...
# Node ID: 7d9c09e1-bcd3-44ac-871f-2685b34d8b9e
# Text: Well stared the process of trying to open an account 3 weeks
# ago. Because I was a PC financial client on the past with a 2 cent
# balance on a dead account, they barely know how to handle it. People
# have been good, finally got my debit card for my new account that
# supposedly was cleaned up and now they tell me again there is an error
# with the new ...
# Node ID: 3016029e-e7ad-40c1-8c6a-b7f654503b3a
# Text: Well, I am now certain I made a mistake going with simplii for
# my mortgage. I received a call today asking why I havent paid my
# mortgage for the last 4 months. I check my banking while I was on the
# phone with them and every payment has come out of my account. I spent
# over half an hour on the phone with the representative who wouldnt
# even give me...
# Node ID: 72c65d0c-8fe3-442d-8a55-e3e746ce482d
# Text: What a joke. Went through verification sent a debit card went to
# deposit a couple of checks told me not verified. Wondering what they
# are doing with all my personal information.
# Node ID: d25b16c1-53b9-48a4-909f-596028792d3e
# Text: When a representative finally answers the call 30 minute on
# hold, you would expect them to have all of the basic knowledge to
# basic banking transactions. All we wanted to do is get direction on
# how to redeem . We were referred to the supervisor who knew very
# little more than the initial rep.not to mention he didnt sound like he
# was much older th...
# Node ID: 4ed52ca1-32fd-491d-a0e8-59712710230b
# Text: When I lost my wallet they asked me for my drivers license
# number and which of course I didnt know off the top of my head my
# wallet was missing!!! After not being able to answer that they sent my
# on a 35 business day wait after having to spend a few hours that I did
# not have gathering documents to provide for security. What bothered my
# most was ...
# Node ID: ea9b018b-63be-4ad6-ad23-c327c3024d98
# Text: When signing up for their services back in July, I signed up for
# an offer for  400. The stipulations of the offer were that of  an
# eligible direct deposit of at least 100 a month for 3 straight months.
# similar to the one that is currently being offered. Fom what I
# believe, I saw  and thought that any form of  would work so I set up
# our  with it ...
# Node ID: 9fff5264-bc66-4274-a509-2682f1f68c2f
# Text: Where should I start. Well to begin with there was a welcome
# bonus which I had to fight tooth and nail to get because they put it
# into someone elses account.Secondly there was some kind of issue with
# one of my accounts and Simply went ahead of doing something to it
# without my knowledge. I am not impressed with this institution and I
# highly recom...
# Node ID: 628d3250-8e30-430b-91c4-42cc98ad1224
# Text: While attempting to refinance, and renew my mortgage with
# financial, I was asked questions that were very personal that did not
# pertain to anything financial. Not to mention I submitted document
# after document after document, and was still asked for more and more
# and more I have good credit no debt, and I was still not approved for
# the mortgage...
# Node ID: 214f820c-b315-4757-9212-c870b92d321b
# Text: Why you guys dont put your acts together, too many complains.
# You dont have any  and we rely on COBC . I deposited cash and the
# machine had jammed. I dont have my money in my account and after a
# week they say still under investigation. It will take up to 12
# business days. Why? Why? in this area that the matter can be solved by
# a telephone call, ...
# Node ID: 52924432-1232-4e7d-be51-ee3e1e92cb36
# Text: Wish I could give zero stars. They keep screwing up my account,
# calling me to tell me I missed a loan payment when the payments are
# automatic. I have no control over them  so THEY screwed up and didnt
# take the payment but they call to harass me and claim that I missed a
# payment. And this is just the latest in a long, long line of issues.
# They ha...
# Node ID: b1205f17-c2f1-4892-9e7d-c8ddf49ef7bd
# Text: With held my check for 12 days after dealing with them from
# first day they switched from President . Total garbage bank.
# Node ID: b48039e0-03e1-4248-b219-57dc36a2d601
# Text: Worse bank ever! You put your money there and the give you tons
# of trouble to withdraw your own money! Like you have to wait 6 months
# on increase your 200 withdrawal limit. They suggested me to E transfer
# to someone else so they can withdraw the funds for me !! What kind if
# bank this is ?Would not recommend at all.
# Node ID: 4170c9c0-502a-47a3-b6a2-456c675bb822
# Text: Worst bank ever
# Node ID: 50529e51-1c48-4275-9c04-8ed5d1c4f760
# Text: Worst bank ever they held my work cheque and told me sucks you
# have to wait 8 business days to get access to it and didnt even give
# me the 100 access youre supposed to have.
# Node ID: b60fe18f-26eb-4014-96b8-a7b73ff45a38
# Text: Worst bank EVER!! Long storyshort This bank closed my autistic
# sons bank account without warning!!! Discrimination against special
# meeds customers that are on ODSP. After waiting all month for his ODSP
# income the bank waits for his cheque to be deposited them decides to
# close his account leaving him with no money, when I called the bank
# they sai...
# Node ID: f2a54525-35fd-47a9-baff-a18889ac5d62
# Text: Worst bank ever!!! I deposited a check with my married name on
# it but my account is under my maiden name. They requested I change my
# name which I then provided all the info and changed it so they could
# release the cheque I deposited then only to be told later once the
# name change was done that my certified check will be hold for another
# 13 busin...
# Node ID: 542a91fb-6e46-4fde-94f9-533e52ba0d46
# Text: Worst bank EVER. Been banking with themFor 8  years, decided to
# hold a cheque and have been fighting with them for 7 days now  they
# also helpMy  FOR NO REASON
# Node ID: 90a13524-88d8-407f-924c-b749d1260303
# Text: worst banking experience ever!
# Node ID: 541cc863-f44e-483b-b173-9990b39c111a
# Text: Worst banking experience of my lifeIt took me 4 weeks to get my
# account set up. The people working at the phone are very bad at their
# job and cant assists you at all. I got the Mail of account
# verification 3 ! times. Each time 5  7 days in between. They ask you
# to upload a selfie, but the whole software doesnt work.
# Node ID: ed355010-51a5-4f1e-af14-5f6395986b88
# Text: Worst banking experience. I tried to contact the centre to ask
# for assistance but they instead freeze the account. They informed me
# that I am not authorized to use the account because this is only for
# my wifes single account. We already applied for the joint account 2
# years ago and had some transactions for the past months using this
# account tha...
# Node ID: 15109844-d1e3-45b5-8ad5-7c154d3f5dad
# Text: WORST CUSTOMER SERVICE IN THE WORLD  I HAVE BEEN TRYING TO
# CONTACT THEM FOR A MONTH VIA PHONE AND IT MAKES NO DIFFERENCE WHAT
# TIME OF THE DAY OR NIGHT YOU CALL, YOU GET THE SAME MESSAGE THAT THEY
# ARE EXPERIENCING A HEAVIER THAN USUAL CALL VOLUME  THE RECORDING SAYS
# THAT YOUR CALL IS IMPORTANT BUT THE FACT THAT NO ONE EVER ANSWERS
# ILLUSTRATES THE...
# Node ID: 5416fc86-bd1f-47fd-96b1-841ef0564c3e
# Text: worst experience ever. Closed all my accounts the minute I
# could. Stay away!!
# Node ID: 6d311935-a2a6-4e40-b508-371b585d4418
# Text: Worst experience I applied for credit card and it has been 2
# month still when I called, I got the answer it is under the process.
# Node ID: aacdbfaa-1051-4382-bc3d-2aa8c061984e
# Text: Worst experience I was waiting on call for almost an hour no one
# connected and there are so many duplicate amount deductions on visa
# card if simplii financial account.and no agent will connect on call to
# communicate about it.please kindly dont take simplii financial from my
# account 150 cad has been deducted from my account in the name of insta
# c...
# Node ID: 657ee49a-5ca1-49bb-adff-cc37db643669
# Text: Worst service possible. Do not use , I opened my  account with ,
# I received my Debit card in a month after landing in Canada, its the
# third month and I am still waiting for my  card. No responses to
# emails and an hour long waiting if you want to talk to the customer
# representative. It is tough when you rely only on  money to survive
# and you do n...
# Node ID: 330aa194-43b8-4f9d-93a2-4c3a39ca70c0
# Text: Worst service. Never use  for . They will take ages to resolve a
# issue.
# Node ID: 02b3429c-1f17-4e6c-a687-4d80cf3ef0b1
# Text: Would give a minus 5 if I could worst customer service
# experience and truly a  started on Thanksgiving day when I called to
# increase  withdrawal limit to get some urgently needed cash.They found
# that my husbands previous place of work had used a part of his name we
# have long names for automatic payroll deposits. By the way it had
# happened for 12...
# Node ID: 4be33ec5-45d2-4a32-8161-85ea54799f50
# Text: Would give zero stars if I could. I was ripped off 80 at an .
# The machine gave a 20 instead of the 100 it was supposed to.
# Immediately contacted  and have been waiting over 4 months for a
# resolution. At this point, it borders theft. It appears that they are
# prolonging this in hopes that I just give up and eat the 80 loss.
# Node ID: 161a4bd6-da16-4648-b8ee-152209e78aa3
# Text: Wouldve given more stars than three. But they fall short in some
# sectors of their services. There general line for clients to call with
# general banking questions is always a joy with short wait times and
# friendly customer service representatives to help you out.
# Unfortunately, during a recent communication with there   card Dispute
# department, w...
# Node ID: 6c8b6d0d-6c64-41ad-b0bf-5c3097ad7c20
# Text: Wow, not understanding all the negative reviews. We have been
# customers since it was , for over 20 years now. We have bank accounts,
# line of credit, and credit cards with them. We do not have a mortgage
# so I cannot comment on that product.I do not understand all the
# comments about fraudulent activity surely they are regulated like
# every other b...
# Node ID: 7c195231-32aa-47b6-9412-717b0c02fda1
# Text: Wrote a note on my account banning me from their products with
# no explanation... its a bank, you really shouldnt be able to ban
# someone with no explanation.
# Node ID: 26544ee5-429d-4642-9f79-b16d512990fc
# Text: You cant deposit foreign cheques through the  or edeposit. You
# have to pay to mail it to them then they take up to eight business
# days to deposit it into your account BUT then it takes a month and a
# half for  to release the funds. Im waiting nearly two month for a 95
# cheque, pathetic
# Node ID: 8463e31b-3fb0-4512-95f0-9eb9de28b7ff
# Text: You get what you pay for. And hopefully you never have to
# utilize their customer service. There security questions are very hard
# to answer, and when you fail to answer them correctly they place you
# on hold multiple times while you wait to speak with a supervisor, who
# then asks you more difficult questions. And after you fail those they
# require y...
# Node ID: 6746b214-8c99-4a38-ae77-2d59127e831e
# Text: You get what you pay for. Long story short one day, the bank
# started to ask me security questions from  5yearold information about
# my closed account, which I could not recall. I did have my online
# banking password, phone password on file, my secret code word, and I
# was calling from a registered phone number on file. I ended up failing
# my securit...
# Node ID: b5c08d0a-8972-42d6-8ce2-1317fdd9223e
# Text: You have to wait on the line like forever for calling customer
# service, theres an unusual transaction that took 391 from my
# account.The blocked my debit card and gave me a new one, i thought
# they will put it back to my account the money but no they didnt.Life
# now a days is so hard, for me that amount is big enough to do an
# investigation but they...
# Node ID: a1291edd-7454-420b-a846-767be24b1cd6
# Text: Zero stars! Customer service is atrocious. Incompetence at all
# levels. Called repeatedly to clear up a problem related to the opening
# of a basic account. Spent hours on hold. Problem still not resolved
# weeks later. Stay away from this company.
# Node ID: 81653d15-2261-4e9e-bc83-1cb1c9fa7c03
# Text: zero stars!!

# %%
print(f"Setting up the embeddings model...")
embeddings = HuggingFaceEmbedding(
    model_name=EMBEDDING_MODEL_NAME,
    device='cuda',
    trust_remote_code=True,
)
# Out:
# Setting up the embeddings model...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/94.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/777 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
Settings.llm = llm
Settings.embed_model = embeddings

# %%
vector_store = WeaviateVectorStore(
    weaviate_client=client, index_name="Reviews_Llamaindex", text_key="text"
)
storage_context = StorageContext.from_defaults(vector_store=vector_store)
index = VectorStoreIndex(nodes, storage_context=storage_context)

# %%
vector_store_query_mode="hybrid"vector_store_query_mode="hybrid",retriever = index.as_retriever(similarity_top_k=6)

# Retrieve the most relevant context from the vector store based on the query
retrieved_docs = retriever.retrieve("Tell me about the worst reviews")
retrieved_docs
# Out:
# [NodeWithScore(node=TextNode(id_='7b0b2a12-6321-47fb-a679-738d74f07e36', embedding=[-0.0004456334572751075, -0.012357603758573532, 0.0186807531863451, -0.011129416525363922, 0.02621369995176792, 0.038296207785606384, -0.010588061064481735, 0.053543154150247574, 0.01688372902572155, 0.0023078236263245344, -0.005728745833039284, 0.031153835356235504, -0.05284224450588226, 0.027112219482660294, 0.0031023197807371616, 0.0266299806535244, 0.03124970942735672, 0.0144833168014884, 0.03676591068506241, -0.006164774764329195, 0.015934402123093605, 0.01159452460706234, 0.013986392877995968, -0.0016500272322446108, 0.06267523020505905, -0.01604161597788334, 0.002054613083600998, 0.020609481260180473, -0.08007912337779999, -0.03550311550498009, 0.057696059346199036, 0.020932376384735107, -0.017023591324687004, 0.04083847999572754, 0.04202541336417198, 0.004663525149226189, -0.03401796147227287, 0.03028033673763275, -0.0013789284275844693, -0.0014255524147301912, -0.038892894983291626, -0.02689976803958416, -0.018939703702926636, 0.03813442215323448, -0.07951066642999649, 0.041554082185029984, 0.012589491903781891, 0.01206226646900177, -0.06567355990409851, -0.028336016461253166, -0.0499354787170887, 0.08458725363016129, 0.038136932998895645, -0.01109771803021431, -0.015542248263955116, 0.0016157665522769094, -0.0071460409089922905, -0.04395529255270958, -0.01272561401128769, -0.049888093024492264, 0.04774317890405655, 0.028182856738567352, 0.04267508536577225, 0.007725422736257315, 0.06615614891052246, -0.005269049201160669, 0.025740323588252068, 0.030632667243480682, -0.05798008292913437, -0.009944984689354897, -0.03199312463402748, -0.010169807821512222, -0.0049850731156766415, 0.012981992214918137, 0.001967360032722354, -0.0750064104795456, -0.018793288618326187, 0.036133695393800735, 0.025843573734164238, 0.05316177010536194, 0.008746371604502201, 0.02610071375966072, 0.0587313175201416, 0.04251044988632202, -0.018517037853598595, -0.03336075320839882, 0.013718155212700367, -0.025376351550221443, -0.014051544480025768, 0.04230336472392082, 0.029421644285321236, -0.02072196826338768, 0.05159703269600868, 0.040096722543239594, -0.00814271904528141, -0.05192163586616516, 0.030118582770228386, 0.013527218252420425, 0.021554667502641678, 0.02010580524802208, -0.022305410355329514, -0.045311544090509415, 0.006149791181087494, 0.02980005368590355, -0.04721731320023537, -0.010820513591170311, 0.05737648904323578, -0.01873396895825863, 0.014354539103806019, 0.00285044452175498, -0.07708650082349777, 0.046100471168756485, 0.005981148686259985, 0.022631658241152763, -0.05537771061062813, 0.015867073088884354, -0.02107904851436615, -0.028274068608880043, -0.0616244338452816, -0.030802546069025993, 0.09287989884614944, -0.017192527651786804, -0.018038341775536537, 0.044600117951631546, -0.0025025077629834414, 0.03475157916545868, -0.01097220741212368, 0.015113025903701782, -0.017387323081493378, -0.05716146528720856, 0.004397904966026545, 0.02407277561724186, -0.08204616606235504, 0.05111363157629967, -0.05218188464641571, 0.0037001159507781267, 0.006053624674677849, -0.06663578003644943, 0.03588943928480148, -0.005883857607841492, 0.029399218037724495, -0.011442148126661777, -0.041709791868925095, 0.02004551887512207, 0.044167883694171906, -0.024595489725470543, 0.01787129044532776, -0.028055857867002487, 0.01214174646884203, -0.028577834367752075, 0.0004330995725467801, -0.006268329452723265, -0.020867561921477318, -0.048782411962747574, -0.0005460258689709008, 0.03037121519446373, 0.007100475020706654, -0.003877434879541397, -0.03857630491256714, 0.051613982766866684, 0.03953094407916069, -0.02176499180495739, 0.01346553023904562, 0.027677025645971298, 0.050526924431324005, -0.03125353157520294, 0.008480330929160118, 0.0032512652687728405, -0.0388333834707737, 0.01256996113806963, -0.05841147154569626, -0.03996976464986801, 0.039478205144405365, -0.01503822859376669, -0.013131750747561455, 0.02264026552438736, 0.027966998517513275, 0.0194780956 ...
#  NodeWithScore(node=TextNode(id_='5416fc86-bd1f-47fd-96b1-841ef0564c3e', embedding=[0.012043117545545101, 0.030025510117411613, 0.05171741917729378, -0.02331816405057907, 0.04312510788440704, 0.04981707036495209, 0.03120601177215576, 0.042135197669267654, 0.010659565217792988, -0.0033366249408572912, 0.001049795770086348, -0.005867097061127424, -0.0648256167769432, 0.021517548710107803, 0.020977158099412918, 0.03768618404865265, 0.0025038132444024086, -0.0034890342503786087, 0.029439272359013557, -0.005188139621168375, 0.013790130615234375, -0.012522774748504162, 0.005950114224106073, 0.002259304514154792, 0.04983541741967201, 0.00033720885403454304, 0.02141703851521015, 0.02020248956978321, -0.07180847972631454, -0.03867197409272194, 0.0433555506169796, 0.02676314115524292, -0.0025647615548223257, 0.005728182848542929, 0.037021391093730927, 0.029559703543782234, -0.03677146136760712, 0.026651564985513687, -0.004962113220244646, 0.029644615948200226, -0.03357561677694321, -0.027804112061858177, -0.008443973027169704, 0.022960301488637924, -0.045909907668828964, 0.038672562688589096, 0.01070898212492466, 0.001320171752013266, -0.02585260197520256, -0.019658023491501808, -0.07562804222106934, 0.05029575154185295, 0.061759043484926224, 0.0027908855117857456, -0.00011848886788357049, 0.02804955095052719, 0.013676237314939499, -0.07418242841959, -0.0082581527531147, -0.049199480563402176, 0.044016242027282715, 0.04112774878740311, 0.04526907205581665, 0.007726718671619892, 0.008699153549969196, -0.02266448177397251, 0.044746801257133484, 0.02167474292218685, -0.03955443948507309, -0.00974354799836874, -0.016329476609826088, 0.0019272748613730073, 0.0052033644169569016, 0.01297694444656372, -0.00886549986898899, -0.07843352109193802, 0.005402192007750273, 0.039807673543691635, 0.056626349687576294, 0.05905214697122574, 0.004581613466143608, 0.014725122600793839, 0.07614190131425858, 0.01240178756415844, -0.007050673011690378, -0.0519612617790699, 0.0062485747039318085, -0.03462675213813782, -0.037904832512140274, 0.04255123808979988, 0.006193580571562052, -0.03570539131760597, 0.06607454270124435, 0.041951704770326614, -0.01972760073840618, -0.04961002990603447, 0.034823331981897354, -0.017890317365527153, -0.0012725403066724539, 0.0006186339305713773, -0.014725233428180218, -0.027458660304546356, -0.017383333295583725, 0.04343084618449211, -0.0654146820306778, 0.020143279805779457, 0.05982336774468422, 0.030447116121649742, 0.016459785401821136, -0.005437216255813837, -0.06583460420370102, 0.045925505459308624, 0.029469264671206474, -0.006844524294137955, -0.06603755056858063, 0.03104247897863388, -0.020488381385803223, -0.002626208122819662, -0.022496188059449196, -0.0422695130109787, 0.062181927263736725, -0.01225681696087122, -0.019570903852581978, 0.042267512530088425, 0.0064084590412676334, 0.0473417267203331, -0.0061529516242444515, -0.008016862906515598, -0.008465887978672981, -0.022915026172995567, 0.005066650919616222, 0.03047342598438263, -0.06114749610424042, 0.06519261747598648, -0.0017187308985739946, 0.01330540981143713, 0.010576531291007996, -0.023544155061244965, 0.03095257095992565, 0.014431506395339966, 0.02780226059257984, -0.041297998279333115, -0.05696279928088188, 0.020169680938124657, 0.035230886191129684, 0.0029116917867213488, 0.013792530633509159, 0.0261165052652359, -0.016349269077181816, -0.02210305631160736, 0.026155173778533936, -0.018397560343146324, -0.024333635345101357, -0.06591019034385681, 3.262825703131966e-05, 0.04383270442485809, 0.020805947482585907, -0.034097589552402496, -0.02019023708999157, 0.04622631520032883, 0.06798892468214035, 0.0026373022701591253, -0.020013805478811264, 0.033445246517658234, 0.051806021481752396, -0.018390683457255363, -0.027856772765517235, 0.010184883140027523, -0.03525528684258461, -0.0029958148952573538, -0.05978410691022873, -0.008979748003184795, 0.017112046480178833, -0.024150630459189415, -0.031218746677041054, 0.04538261517882347, 0.05039156228303909, 0.01 ...
#  NodeWithScore(node=TextNode(id_='7fa4e20c-cb75-41b8-b7ad-350765490f4f', embedding=[0.005974261090159416, 0.013083071447908878, 0.04004817083477974, -0.02444765530526638, 0.034139521420001984, 0.011268454603850842, -0.01183596346527338, 0.03475799411535263, 0.027198540046811104, 0.011773302219808102, -0.025248751044273376, 0.013616414740681648, -0.05993162468075752, 0.02350771613419056, 0.01667143404483795, 0.044213008135557175, 0.036774925887584686, 0.00925669725984335, 0.039589934051036835, -0.013903995975852013, 0.008305813185870647, 0.0123550770804286, 0.016965387389063835, -0.0076214768923819065, 0.03327963128685951, 0.02009524032473564, 0.0033785104751586914, -0.009289457462728024, -0.0746239572763443, -0.03635844588279724, 0.07510198652744293, 0.0032116887159645557, -0.01144120842218399, 0.004074785392731428, 0.0534244179725647, -0.021263018250465393, -0.01407642848789692, 0.034931764006614685, -0.0064038848504424095, 0.014563831500709057, -0.025788994506001472, -0.0135759636759758, -0.022138364613056183, 0.030894121155142784, -0.05144263803958893, 0.03287230432033539, 0.0028346902690827847, -0.006074790842831135, -0.04331856593489647, -0.03636876493692398, -0.08102072030305862, 0.044289860874414444, 0.05701082572340965, -0.024186760187149048, 0.02497022971510887, 0.025886300951242447, 0.0007402457995340228, -0.057143427431583405, -0.04005884751677513, -0.004651482682675123, 0.006743369158357382, 0.02624529041349888, 0.022200671955943108, -0.01072473730891943, 0.01118810847401619, -0.03543100133538246, 0.03418164700269699, 0.04434913024306297, -0.05945153161883354, -0.013042883947491646, 0.006184282246977091, -0.023814953863620758, 0.007296733092516661, -0.01516034733504057, 0.019623156636953354, -0.051389727741479874, 0.02096736803650856, 0.0636429712176323, 0.03652562201023102, 0.058688849210739136, 0.010945679619908333, 0.02702527679502964, 0.05492051690816879, 0.048838190734386444, -0.005003414116799831, -0.010498353280127048, 0.0328085832297802, -0.05167087912559509, 0.0037767814937978983, 0.04735952615737915, -0.006974167190492153, -0.04206632450222969, 0.06405055522918701, 0.03453171253204346, -0.0010162213584408164, -0.06118692830204964, 0.03663945198059082, 0.0159311443567276, 0.01762370765209198, 0.013375072740018368, -0.05553022399544716, -0.024982566013932228, 0.004615830257534981, -0.001836279290728271, -0.008780911564826965, -0.004818604327738285, 0.05450538918375969, -0.01233593188226223, 0.018439114093780518, -0.017095714807510376, -0.05322584882378578, 0.049081962555646896, -0.005786998197436333, -0.0023946056608110666, -0.06840623915195465, 0.033739279955625534, -0.025530073791742325, -0.02258181944489479, -0.01713898591697216, -0.023619068786501884, 0.0784117579460144, 0.01896611414849758, -0.020479870960116386, 0.06344055384397507, 0.02746504172682762, 0.04974527284502983, 0.020871154963970184, 0.004419106524437666, 0.007660981267690659, -0.057328980416059494, 0.03302576020359993, 0.06038123741745949, -0.049386631697416306, 0.0578913539648056, -0.02834337018430233, 0.01892622373998165, -0.0052131726406514645, -0.03306116536259651, 0.061117466539144516, -0.005788526963442564, 0.031782448291778564, -0.012895365245640278, -0.043077826499938965, 0.016507089138031006, 0.020852768793702126, -0.02762955240905285, -0.01619841158390045, -0.03520778566598892, -0.014959126710891724, -0.022738628089427948, -0.012660015374422073, -0.002325929468497634, -0.005359278526157141, -0.0729854479432106, 0.0008230596431531012, 0.018841153010725975, 0.0295261163264513, -0.017589669674634933, -0.06328989565372467, -0.004530412144958973, 0.04914052411913872, -0.020123543217778206, 0.027346743270754814, 0.035947058349847794, 0.07647829502820969, -0.030764387920498848, 0.03114628605544567, 0.0054874601773917675, -0.01081104576587677, 0.028942765668034554, -0.05625195801258087, -0.002142009325325489, 0.03385534510016441, -0.04690947011113167, -0.005910164676606655, 0.044376060366630554, 0.060176391154527664, 0.00940085668116808 ...
#  NodeWithScore(node=TextNode(id_='d3361dbb-3514-4956-98e8-ce74f401c2ae', embedding=[0.006953213829547167, -0.0016595066990703344, 0.017411887645721436, -0.013903841376304626, 0.045558907091617584, 0.06652890145778656, 0.00561219546943903, 0.06748635321855545, 0.007684642449021339, 0.008138571865856647, -0.01155470684170723, 0.010496370494365692, -0.07330813258886337, 0.03715633973479271, 0.00045250719995237887, 0.021889451891183853, 0.02982228994369507, 0.01762373559176922, 0.017061561346054077, -0.02661094069480896, 0.03867090865969658, 0.018685007467865944, 0.03878738731145859, 0.019198758527636528, 0.037399183958768845, 0.011981045827269554, 0.0266829002648592, 0.004812138620764017, -0.07561174035072327, -0.03540255129337311, 0.06184270977973938, 0.015745315700769424, -0.000779606110882014, 0.02308778464794159, 0.03749080374836922, 0.0025364726316183805, -0.016860151663422585, 0.008177017793059349, -0.006062881555408239, 0.0015855279052630067, -0.04825485125184059, -0.00728339608758688, -0.023258645087480545, 0.05687201768159866, -0.07854436337947845, 0.03684264421463013, 0.027575356885790825, 0.0007042522192932665, -0.0487586185336113, 0.002757713897153735, -0.044600315392017365, 0.05896930769085884, 0.034687288105487823, -0.02026469260454178, -0.024043874815106392, 0.022768115624785423, -0.007852070033550262, -0.07771510630846024, 0.007498330902308226, -0.03979998454451561, 0.0330655500292778, 0.03401879221200943, 0.034521058201789856, 0.023596305400133133, 0.017035678029060364, -0.009975605644285679, 0.023895738646388054, 0.03592805936932564, -0.05495831370353699, 0.013519768603146076, -0.019506873562932014, 0.0045967698097229, 0.009227883070707321, 0.010654708370566368, 0.020228330045938492, -0.07170404493808746, -0.024600137025117874, 0.04629542678594589, 0.05499047040939331, 0.055961769074201584, 0.0008121384889818728, 0.010923857800662518, 0.057348188012838364, 0.045560937374830246, -0.0177727360278368, -0.03862882778048515, -0.0046062772162258625, -0.04070717468857765, -0.023933131247758865, 0.05845806002616882, 0.029373805969953537, -0.027697796002030373, 0.02977488748729229, 0.04105660319328308, -0.03857441991567612, -0.05528436228632927, -0.003040788695216179, -0.015607788227498531, 0.026173565536737442, 0.028552113100886345, -0.034947458654642105, -0.03885240480303764, 0.01599203795194626, 0.062085624784231186, -0.05737883970141411, 0.02050764486193657, 0.021844416856765747, 0.0031072695273905993, 0.022155843675136566, -0.005459339823573828, -0.059492602944374084, 0.030429700389504433, 0.004875893704593182, -3.317050141049549e-05, -0.04712050408124924, 0.02466491423547268, -0.013204996474087238, -0.04240240901708603, -0.045356523245573044, -0.02594558149576187, 0.05884984880685806, -0.02382882498204708, -0.013230575248599052, 0.03900238126516342, 0.013601403683423996, 0.03834112361073494, 0.010238470509648323, 0.015585673041641712, -0.026076236739754677, -0.04964607208967209, -0.015772515907883644, 0.033524952828884125, -0.07961729913949966, 0.0797855481505394, -0.018323086202144623, -0.007297849748283625, -0.009491979144513607, -0.03848540410399437, 0.024863572791218758, 0.025236375629901886, 0.04106197506189346, -0.015819527208805084, -0.0452725775539875, 0.033822525292634964, 0.045339226722717285, -0.0216462854295969, 0.017278160899877548, 0.0005131774232722819, -0.020315175876021385, -0.011368758976459503, 0.0009305107523687184, -0.007502765394747257, -0.013799922540783882, -0.0322771817445755, 0.015201094560325146, 0.045488521456718445, 0.018795376643538475, -0.011771485209465027, -0.03860027343034744, 0.04675201326608658, 0.023840073496103287, 0.011518418788909912, 0.024967577308416367, 0.0391988605260849, 0.02706516534090042, -0.026499753817915916, -0.010459903627634048, 2.7106461857329123e-05, -0.04040637984871864, 0.01692105457186699, -0.041109755635261536, -0.05383925512433052, 0.03083207830786705, -0.02846320904791355, -0.04587715491652489, 0.019330225884914398, 0.04153069108724594, 0.0261819995939731 ...
#  NodeWithScore(node=TextNode(id_='61c9c5f5-7461-40fd-b9d6-2c34a835f984', embedding=[0.0009712059400044382, -0.010014353320002556, 0.02719578705728054, -0.007296404801309109, 0.030837111175060272, 0.0333070270717144, 0.0038960424717515707, 0.03270397335290909, 0.006622040644288063, 0.0016021007904782891, 0.026965510100126266, 0.039913468062877655, -0.0518641360104084, 0.031533461064100266, -0.0010858732275664806, 0.0354541540145874, 0.02309533953666687, 0.015689942985773087, 0.04907841980457306, -0.005650708917528391, -0.004642770159989595, 0.010561831295490265, 0.021052634343504906, -0.004299498163163662, 0.02938954345881939, 0.017054354771971703, -0.01065030973404646, 0.010602915659546852, -0.0711166113615036, -0.060334306210279465, 0.0803484171628952, -0.005302204750478268, -0.013003330677747726, 0.03896859288215637, 0.03310885652899742, -0.010663091205060482, -0.025439737364649773, 0.027548983693122864, -0.018884332850575447, 0.01378953643143177, -0.04223373904824257, 0.007230148185044527, -0.03994908556342125, 0.039373308420181274, -0.04931081458926201, 0.034095317125320435, 0.008830813691020012, -0.017775509506464005, -0.032581627368927, -0.0638798177242279, -0.0503215566277504, 0.06922470033168793, 0.01736069656908512, -0.004004762973636389, 0.015255231410264969, 0.005239921621978283, -0.009093581698834896, -0.0700894445180893, -0.0008034545462578535, -0.024183576926589012, 0.03627004101872444, 0.01141733955591917, 0.02344064600765705, 0.01590406335890293, 0.02964690513908863, -0.019947409629821777, 0.023188691586256027, 0.02904294617474079, -0.04523972421884537, -0.0017854764591902494, -0.017459969967603683, -0.017366308718919754, -0.0045284186489880085, -0.004098930396139622, -0.008062330074608326, -0.07092134654521942, 0.007351284846663475, 0.04520660266280174, 0.02911454811692238, 0.05674849823117256, 0.01480046659708023, 0.02077656053006649, 0.037077706307172775, 0.02365574613213539, -0.018204452469944954, -0.04686782509088516, 0.007523400709033012, -0.008065161295235157, -0.012789330445230007, 0.03539249300956726, 0.020138481631875038, -0.03087667189538479, 0.03766040503978729, 0.030903713777661324, -0.013818490318953991, -0.06369224935770035, 0.03733629733324051, 0.0001642848801566288, 0.023146672174334526, 0.026204913854599, -0.029298914596438408, -0.04623524844646454, -0.0029809216503053904, 0.012962411157786846, -0.03343852609395981, 0.0049194167368113995, 0.04403489828109741, 0.019071215763688087, 0.02342177741229534, 0.0066681052558124065, -0.07815642654895782, 0.04936680942773819, 0.01667257584631443, -0.0011137083638459444, -0.05965312942862511, 0.015220028348267078, -0.021865487098693848, -0.018063489347696304, -0.05312453210353851, -0.041662607342004776, 0.07999803125858307, 0.0009416083921678364, -0.027577942237257957, 0.04903929680585861, 0.02474726177752018, 0.02454542927443981, 0.003678225912153721, 0.018989775329828262, -0.016700325533747673, -0.047603484243154526, 0.009692215360701084, 0.03029738925397396, -0.051940228790044785, 0.0471448116004467, -0.01450346503406763, -0.002369749126955867, -0.028125600889325142, -0.05192607641220093, 0.0403197817504406, -0.005095432046800852, 0.03200630471110344, -0.012695490382611752, -0.02660234272480011, 0.017273450270295143, 0.04469391703605652, 0.0011015381896868348, 0.004825470969080925, -0.006781171075999737, 0.012353550642728806, -0.03544133901596069, -0.001508034998551011, -0.0031344974413514137, -0.027375521138310432, -0.048870112746953964, -0.0039042863063514233, 0.03867163881659508, 0.019081423059105873, -0.01603587344288826, -0.03472011908888817, 0.041864026337862015, 0.051680464297533035, -0.00706549221649766, 0.01572132296860218, 0.029826456680893898, 0.06274265050888062, -0.013971534557640553, -0.0035088653676211834, 0.020591512322425842, -0.051266323775053024, 0.017772793769836426, -0.07447855174541473, -0.007595101837068796, 0.05161554366350174, -0.017525257542729378, -0.03819132596254349, 0.056046776473522186, 0.04742013290524483, 0.01795433834 ...
#  NodeWithScore(node=TextNode(id_='330aa194-43b8-4f9d-93a2-4c3a39ca70c0', embedding=[0.014565564692020416, 0.006388216745108366, 0.029721634462475777, -0.020422087982296944, 0.03557102754712105, 0.06898078322410583, 0.013985199853777885, 0.044519148766994476, 0.005705683957785368, -0.006111131515353918, -0.008887680247426033, 0.025251490995287895, -0.07384400814771652, 0.026556726545095444, -0.002555959392338991, 0.04050299897789955, 0.022376911714673042, 0.03844323754310608, 0.018947331234812737, 0.00010651476623024791, 0.03265557810664177, -0.012360433116555214, 0.0003687548451125622, -0.0016312707448378205, 0.06252827495336533, -0.003577391617000103, 0.0012797520030289888, 0.03396138176321983, -0.09149694442749023, -0.016545766964554787, 0.0621236190199852, 0.023438164964318275, -0.009271371178328991, 0.009028815664350986, 0.045658212155103683, 0.013632611371576786, -0.0370100662112236, 0.013909063301980495, 0.015803828835487366, 0.015829967334866524, -0.02447522059082985, -0.045366495847702026, -0.016375049948692322, -0.008884000591933727, -0.05734226480126381, 0.0268546175211668, -0.00823995005339384, -0.003843836020678282, -0.05219493433833122, -0.019652782008051872, -0.1085212305188179, 0.054291028529405594, 0.04275243729352951, 0.04093145951628685, -0.019822876900434494, 0.008234857581555843, 0.024754701182246208, -0.04047050699591637, -0.010492237284779549, -0.051499947905540466, 0.03309660404920578, 0.004908187780529261, 0.05283023789525032, -0.008825072087347507, 0.0348796546459198, -0.002389931119978428, 0.026725664734840393, 0.027262387797236443, -0.046318646520376205, -0.010363934561610222, -0.020307466387748718, -0.0033292921725660563, 0.0004143321712035686, 0.02242353744804859, -0.011426099576056004, -0.05509345233440399, -0.027793606743216515, 0.04668116942048073, 0.03766384720802307, 0.03967951238155365, -0.027681028470396996, 0.03552236780524254, 0.04025866463780403, 0.04089099168777466, -0.010517895221710205, -0.021073579788208008, -0.017826426774263382, -0.020719822496175766, -0.016717683523893356, 0.023604096844792366, 0.05896175652742386, -0.039116375148296356, 0.0758470743894577, 0.036185942590236664, -0.006286520045250654, -0.029956810176372528, 0.022705866023898125, 0.02429482713341713, -0.0032963291741907597, 0.00799011904746294, -0.010789323598146439, -0.014635201543569565, 0.021111533045768738, 0.04745200648903847, -0.043679650872945786, -0.025416526943445206, 0.04255349934101105, 0.008177709765732288, 0.028222549706697464, -0.01602952741086483, -0.040232449769973755, 0.04848159849643707, 0.02366717718541622, 0.010917352512478828, -0.07735645771026611, 0.036374323070049286, -0.027119861915707588, -0.024292802438139915, -0.018280083313584328, -0.02513127028942108, 0.058935414999723434, -0.018370889127254486, -0.03024235926568508, 0.03461386263370514, -0.00598886189982295, 0.04858184978365898, 0.005986922420561314, -0.0011161775328218937, -0.026692014187574387, -0.03834766149520874, 0.0017714060377329588, 0.008498549461364746, -0.05227078124880791, 0.031572386622428894, -0.004753711633384228, 0.0027719223871827126, 0.025524752214550972, -0.022808747366070747, 0.028164014220237732, -0.0022956423927098513, 0.010401624254882336, -0.012636199593544006, -0.03826649859547615, 0.025378601625561714, 0.05613065883517265, -0.0053528184071183205, 0.025140652433037758, -0.029956983402371407, 0.003059105249121785, -0.01721874065697193, 0.010509864427149296, -0.0006186681566759944, -0.0088227903470397, -0.05795660614967346, -0.010683010332286358, 0.026505423709750175, 0.0205833837389946, 0.008581643924117088, -0.03650182858109474, 0.02935287542641163, 0.017333971336483955, -0.0012498169671744108, -0.015355379320681095, 0.026624610647559166, 0.03038492612540722, -0.0614665150642395, -0.02498563751578331, -0.001439285697415471, 0.00475434772670269, -0.011193145997822285, -0.032452233135700226, -0.037090085446834564, 0.02291097119450569, -0.028693029657006264, 0.0001257762050954625, 0.04183410108089447, 0.069236934185 ...

# %%
query_engine = RetrieverQueryEngine(retriever=retriever)
result = query_engine.query("Tell me about the worst reviews")
print(f"Result: \n\n{result}")
# Out:
# Result:
#
# The worst reviews are characterized by extremely low ratings, harsh language, and a sense of frustration and disappointment. They often mention poor customer service, unhelpful staff, and a lack of competence. The reviewers express a strong warning to others, advising them to avoid the company at all costs. The tone is consistently negative, with words and phrases like "horrible", "rude", "archaic", "ridiculous", and "wasting your time" being used to describe the experience.

# %% [markdown]
# # Upload Data with Chunking

# %% [markdown]
# ## Upload Documents

# %%
from llama_index.core import Document

df = pd.read_csv("/projects/RAG2/cibc-2/Bootcamp_Dataset_CIBC2.csv")

# Ensure NaN values are replaced with None
df = df.where(pd.notna(df), None)

# Specify metadata fields to include
metadata_fields = ["datePublished", "rating", "topic", "headline","sentiment"]  # Manually specify which columns to use as metadata

# Modify loop to replace None values in metadata with "N/A"
documents = [
    Document(
        text=row['reviewBody'],
        metadata={key: (value if value is not None and value != "" else "N/A") for key, value in row.items() if key in metadata_fields}
    )
    for _, row in df.iterrows()
]

# %%
from llama_index.core.node_parser import SentenceSplitter

parser = SentenceSplitter(chunk_size = 256, chunk_overlap = 32)
nodes = parser.get_nodes_from_documents(documents)

print(f"Created {len(nodes)} nodes from {len(documents)} documents")
# Out:
# Created 795 nodes from 678 documents

# %%
from collections import defaultdict

# Group nodes by datePublished
date_groups = defaultdict(list)

# Loop through all nodes and group them by datePublished
for node in nodes:
    date_published = node.metadata["headline"]  # Assuming it's always present
    date_groups[date_published].append(node)

# Print chunks grouped by datePublished
for date, group in date_groups.items():
    print(f"Head: {date}\n")
    for i, node in enumerate(group):
        print(f"Chunk {i+1}:")
        print("Text:")
        print(node.text)
        print("------------------")
    print("\n")  # Extra space between groups
# Out:
# Head: simplii the ghost bank
#
# Chunk 1:
# Text:
# ... this so called bank is a joke... customer service is nonexistent  when trying to get answers they simply disappear... just let me close my account!...thumbs down...
# ------------------
#
#
# Head:  is a toy bank.
#
# Chunk 1:
# Text:
# is a toy bank.Its not a serious institution in any way. You can keep there a couple hundred dollars on groceries but thats about it. For starters, limit 500 per transaction. I went to pay for my insurance and it just refused to work because the bill was about 1000. Quite inconvenient.Even worse, there is 200 daily withdrawal limit with no possibilities of increasing it more. Thats insane! So, if you need cash, you cannot retrieve it from there unless you go to the local  for multiple days in a row.That said, it could work okay if maybe you dont earn very much, or are looking for a secondary bank. Some people have accounts in more than two banks, that can be convenient my main one is mostly for savings and expensive purchases while  one is more for general shopping  groceries, , bills for phone and internet. In terms of online purchases,  is winning over  which, unfortunately, does not work with majority of online marketplaces.
# ------------------
# Chunk 2:
# Text:
# In terms of online purchases,  is winning over  which, unfortunately, does not work with majority of online marketplaces. Also,  is very active in pushing transgender propaganda on all its clients while  is more respectful in its approach.Im giving  25. There is a lot of room to grow. Wouldnt recommend to anyone who is looking for a bank to hold more than a thousand dollars in the account.
# ------------------
#
#
# Head: Less Than Stellar.
#
# Chunk 1:
# Text:
# made a large payment on my  account to   credit card. Over 2000. The web server was slow and the payment timed out saying incomplete transaction try again later. I dis so and payment transacted as normal. But the first payment was also credited resulting in my account being in the red. Phone  they showed me how to reverse one payment. Did that felt ok with it. Days later my acct is overdue and no payment recieved by capital one. Phones  got the run around. Said the issue was sent to the back office for consideration. They keep saying it will be resolved but end of March now and my 2000 dollars is lost out there in the ether. My account is missing the money and  remains unpaid. I hv incurred credit charges and still have no action by  to fix it. Find the negative reviews very troubling. As a senior living o. Pensions my account is compromised. Will surely be going to another bank ASAP.
# ------------------
#
#
# Head:  is the worst bank I have ever
#
# Chunk 1:
# Text:
# is the worst bank I have ever experienced and I do NOT recommend it. I have just opened both my chequing and savings account this month, August 15, 2019 and I am closing it. It is one problem after another and I felt trapped, could not get my money out to do etransfer for rent because either the online banking is on maintenance or the registration could not work, so I had to telephone a rep as advised on its online web. Not only is the telephone service extremely poor with almost 2 hours of waiting time on August 30, 2019 I tried to put my number for a call back and waited 2 hours for the second time the  machine that swallowed my deposits of over 1,300 never gave me a receipt evidence of my putting money in. Now i am paying my rent late. Do not count on getting your money out in an emergency situation with  and do not rely on its etransfer service.
# ------------------
# Chunk 2:
# Text:
# Do not count on getting your money out in an emergency situation with  and do not rely on its etransfer service. There is always an issue. Avoid . Now I am paying late rent.
# ------------------
#
#
# Head:  is the best!
#
# Chunk 1:
# Text:
# has been absolutely amazing with our new mortgage. Ive used them since they opened and our most recent experience with mortgage specialist  has been seamless from start to finish. He was responsive to all our questions and worked very late on a Friday evening to ensure we met the conditions of our close. Absolutely recommend  for all banking needs!
# ------------------
#
#
# Head:  is a criminal
#
# Chunk 1:
# Text:
# is a criminal organization They are not a member of the  and they have no intention of dealing with any actual customer service issues their clients have. They deal with people who open accounts with them like prey. They are predators who take and give nothing in return
# ------------------
#
#
# Head:  is the worst
#
# Chunk 1:
# Text:
# is the worst bank to deal with. There customer service is horrible, they are rude and frankly they dont know much what happening there. after several bad call experiences I decided to close my account so on friday 9 octobre 2020 at 14h24 I called  and tlked to a manager whose name was  , firstly he wasnt a helpful person, secondly after asking me lots of security questions , when I asked him to close my acount and send me a confirmation email or document to be sure that my acount is closed , he told me that he couldnt provide that and inspite of my explanation he insisted that I hadnt open any acount with them, finally after 20 minutes talk he understood that I have an acount with them. When I asked him to transfer me to his superior he told me that there is no superior than him and I am not able to talk with any one eles.
# ------------------
# Chunk 2:
# Text:
# I highly recommend going else where the costomer service and managers are more helpful and friendly .simpliii is really waisting your time
# ------------------
# Chunk 3:
# Text:
# is the worst bank to deal with. There customer service is horrible, they are rude and frankly they dont know what the hell there doing there. I highly recommend going else where just so you dont get screwed over like I did.
# ------------------
#
#
# Head:  was very helpful
#
# Chunk 1:
# Text:
# was very informative, and patient. He made the process as stress free as possible. I have been with  for 30 years and I have been pleased with the service.
# ------------------
#
#
# Head:  locked my debit card two weeks
#
# Chunk 1:
# Text:
# locked my debit card two weeks ago as fraud prevention. Their verification text message sent to my phone kept responding with  information to my numerous attempts to respond. I have now been on hold for over seven hours waiting to speak to fraud prevention!!! No one ever answers my Calls !!!!! The customer service at  has gotten horrible. Take your business elsewhere like we are going to do if we can ever get a human to answer.
# ------------------
#
#
# Head: N/A
#
# Chunk 1:
# Text:
# Avoid at all Costs !! Terrible Banking ! The Absolute Worst!!They Closed my checking account and other accounts because of too many email transfers, deposits and withdrawals. On top of that they are still holding my direct deposit for over 5500 for over a week now and also holding a direct deposit email transfer. I can not get a hold of anyone and constantly on hold when I call in for anywhere from 30 min to an hour only to finally talk to someone to only be transfer to someone else. Then finally only to be hung up on or transferred to another incompetent employee. DO NOT sign up with this company What is the point of having a bank account if I can not email transfer money, make deposits and take money out of the bank.I had direct deposit from my employer every 2 weeks for over 15 years and I sent a lot of email transfers and spent a lot of cash from withdrawing at bank machine. I was with  for over 15 years with absolutely no issues until  took over.
# ------------------
# Chunk 2:
# Text:
# I was with  for over 15 years with absolutely no issues until  took over. once they closed all my accounts I immediately  over to  I wont mention any names just incase I have issues with them too  However so far way better service and not one single issue.
# ------------------
# Chunk 3:
# Text:
# was very helpful,respectful,and very professional.He provided all the information I needed ,thank you
# ------------------
# Chunk 4:
# Text:
# , the 400 bonus dont count for  payrolls but they wont tell you about this. Customer service is hard to reach.
# ------------------
# Chunk 5:
# Text:
# . Theyre incompetent and they take forever to give you an answer. Nobody is able to do anything. Because of these guys Im about to lose the money for a down payment just for a simple fix that I did with another bank in less than 5 mins.Once I get my draft, Ill close my account with  for good.
# ------------------
# Chunk 6:
# Text:
# 1 person can make a big difference in navigating all things mortgages and moving!  is my rep and he is excellent at what he does, personable, accountable and goes over and above to ensure you understand whats needed, whats happening and even after the fact checking in to ensure all went as planned. Cant go wrong with !
# ------------------
# Chunk 7:
# Text:
# Actually  has provided good friendly service to me for years, except today. I got email to call  relating to a problem l had with transfers. Spoke to  who was the worst customer service personnel ever. He was cold, no enthusiasm, poor attitude, and even hung up on me. I hope management can listen to the recording and judge accordingly. After being a loyal happy customer for years, this bad rotten apple spoilt it all.
# ------------------
# Chunk 8:
# Text:
# Banked with them for 15 years, as far back as them being  and today I closed my account. The customer service received was disgraceful and the stole 180 from me in bogus  fees, telling me they were warranted. I will NEVER bank with them again, and you shouldnt either.
# ------------------
# Chunk 9:
# Text:
# Banking side of it is fine, their credit card gives great cashback on bars and restaurants.The issue that is increasingly annoying me is the 2FA on the web version of their site. There is no way to mark your device as trusted or anything...you have to get sent a text message EVERY SINGLE TIME and this is putting me off using them more
# ------------------
# Chunk 10:
# Text:
# Couldnt even get an account or anything actually its a waste of your time dont bother junk bank
# ------------------
# Chunk 11:
# Text:
# Customer service on the phone is terrible. The wait time generally is close to one hour.
# ------------------
# Chunk 12:
# Text:
# For an online bank they operate about as efficiently as a brick and mortar operation from the 1970s. You cant open an external link without a stamped void cheque from the back room. And if you open a chequing account you need to mail in a copy of one of your utility bills. Fax is also an option cutting edge. Be prepared to be frustrated.
# ------------------
# Chunk 13:
# Text:
# Got on the phone and was told previously it was a simple process to update my ID on file to open an . Turns out I have to travel 30 minutes out of my way and take 45 minutes at the post office to get this done. Was offered email but they only accept 2 types of photo IDs and do not accept any of the IDs plus drivers license. They did offer after an hour to open one manually but told me I would have to go through this gruelling process everytime I wanted to open up an investment! So aggravating! So done! Switching banks and taking my family and friends with me.
# ------------------
# Chunk 14:
# Text:
# I am writing this review the commendable customer service provided by  She was very curious provided detail formation and very patiently answer my questions very happy with standard and quality of the service provided
# ------------------
# Chunk 15:
# Text:
# I have been with this bank over 20 years now and this year has been an absolute disaster. It used to be great, yet now its mismanaged and heading straight to the toilet. For an online bank, they sure dont seem to care much when it comes to supporting their app. I havent been able to sign in on my new android and its clearly a flaw in the app. I have spoken with multiple agents over the past 10 months who assure me it will be fixed yet no updates. The  browser isnt supported either. I will be changing banks .
# ------------------
# Chunk 16:
# Text:
# I would like to preface this by saying I have been banking with  financial for MANY years originally . In terms of general customer service, I have received friendly and helpful customer service agents. I am however, trying to proceed with a mortgage preapprovalapproval. I required an update to my financial details from my original preapproval, which involved a phone call to a mortgage representative. After being transferred from my mortgage broker to a customer service agent?, I received mediocre service which did not fulfill my needs I fail to see why I am unable to receive paperwork regarding my increased mortgage amount, or interest rates. As I am dealing with hundreds of thousands of dollars, I feel as though this would be logical I receive more updates when I order a ten dollar lunch.To follow up my aforementioned phone call, I emailed my mortgage broker to ask more questions, which I have yet to receive a response. It has been four business days.
# ------------------
# Chunk 17:
# Text:
# It has been four business days. As a 28 year old first time home buyer, I must say, this experience has been abysmal. I am currently attempting to make an offer on a property, but am unable to do so confidently as I do not have an accurate preapproval.As a result of my experience and due to the fact it seems  does not take my finances seriously, I am now exploring alternative banking options and will be transferring ALL funds to a new bank.
# ------------------
# Chunk 18:
# Text:
# Just went through a separation, so went to refinance my mortgageit was the worst experience having to deal with these people they wanted me to pay off some credit that I had in my name and only way they would refinance my home if I took out a 15,000 dollar increaseand add to the price of my mortgage, l told them to stick it, they were going to increase my mortgage by 240 dollars a month and charge me 4.25 percent as they are part of cibc so I went into  AND SAID TO CLOSE ALL MY ACCOUNTS I will not be doing businesswith them anymore, said wait lets look into this and see why they are doing this came back to me and did not understand why so they bought out my mortgage and reduced my monthly payments by120 dollars per month from WHAT I was paying told them SIMPLII IS GIVING THEM A BAD NAME they are very dishonest they are not out to for my best interest they are out to screw there clients theres no WAY HELL WOULD I EVER RECOMMEND THEM TO MY WORST ENEMY
# ------------------
# Chunk 19:
# Text:
# Manager personally called me and addressed all my concerns!
# ------------------
# Chunk 20:
# Text:
# My husband and I were trying to get a Secured Line of Credit and the gentleman that we dealt with was . He was a very pleasant and very helpful gentleman in helping us decide on getting our Secured Line of Credit. He was very friendly and helpful.Thanks, , for all of your assistance with the matter we were trying to get.
# ------------------
# Chunk 21:
# Text:
# Parth 1  was extremely pleasant and helpful during my recent business interaction with .
# ------------------
# Chunk 22:
# Text:
# Put order in to transfer money out than I see upcoming transfer on the transfer day nothing happend. Call chat with them they have no clue that the order was in. so if you count on your money dont bank with them.
# ------------------
# Chunk 23:
# Text:
# Seems like a huge scam got a call from Indian number confirming my personal information which i have only provided to . Got the call after 3 to 4 days of a back and forth email fight
# ------------------
# Chunk 24:
# Text:
# Since [] has no physical contact with its customers, there should be no holds for bank drafts and certified cheques that are deposited on the []. These items are already guaranteed by the issuing banks and therefore, do not necessarily require clearance like the regular cheques do. This is my opinion and I hope [] will consider making changes.
# ------------------
# Chunk 25:
# Text:
# Tedious, tedious, tedious... cant even get started with this bank. I open an account, they send me a welcome kit, but they forget the bank card. Gotta wait at least a week to get started there but I think I wont bother. On another existing account, I cannot get the login and password from them to even start online banking they dropped the call which already took thirty minutes of waiting. When I ask for a statement of this account which I need for closing a mortgage, Im presented with so much red tape and back  forth BS that I want to pull my hair out and curse the fact that online banks even exist. I am sure it works for some people, but personally I am never using this bank again.
# ------------------
# Chunk 26:
# Text:
# They can not even check email. !
# ------------------
# Chunk 27:
# Text:
# We moved our banking accounts to  when they began.. I was just so frustrated with our banks endless fees and poor customer appreciation and service. When it changed to  I found things actually got better and I was already happy with . We still had our mortgage at our old bank and it was renewal time and I was not at all happy with the service I was getting so we moved our mortgage to . I was nervous about it being all onlineover the phoneemail but everything went smoothly and it was pretty stress free. So after a while we decided to move our SPs from our old bank to  as well. Our mortgage just renewed and we dealt with  to get started, he was awesome very helpful went over all our options answered my endless questions and always responded quickly. We were passed on to  who went over the final numbers a let us know all the steps that would be taken from here.  was amazing, he responded to my emails in less than an hour, sometimes within minutes, never left me hanging waiting for an answer.
# ------------------
# Chunk 28:
# Text:
# was amazing, he responded to my emails in less than an hour, sometimes within minutes, never left me hanging waiting for an answer. Things didnt go quite as planned but only due to recent job changes on our end that they werent aware of when we started. I was getting nervous that things would not get done in time but  was always calm and reassuring. It did get done in time and my stress level was much lower than it could have been so thanks  and  for making this process so easy and for you constant quick attention, it really was greatly appreciated!
# ------------------
#
#
# Head: Great Experience with a Simplii Mortgage Expert
#
# Chunk 1:
# Text:
# is a great asset to . Very helpful and empathic while maintaining his professionalism. helped me not once but twice in one month to change my mortgage.He was always available to listen and if he was not available right away he always called me back the same day. Great experience with !!! Thank you !! Also, it has been a very good experience with the whole  team..Thank you
# ------------------
#
#
# Head: excellent
#
# Chunk 1:
# Text:
# support specialist from  financial helped me in changing the Title transfer of my home, though it took more time than anticipated to get documents in place  is patient and timely followed up with me in regards to documents required for them to complete the process. I recommend  finance to my family and friends when needed.
# ------------------
#
#
# Head:  was extremely helpful in
#
# Chunk 1:
# Text:
# was extremely helpful in getting my secured line of credit set up. I have been a  customer for several years and would recommend the bank and services they offer to anyone
# ------------------
#
#
# Head: Terrible and leaving
#
# Chunk 1:
# Text:
# has gone down the drain since it was rebranded from . The website and app are constantly broken and I can never get my banking done in the time frame that I need. Tried to call them today about an issue on  etransfers and I was hung up on. Im transferring my money and moving elsewhere. Absolutely ridiculous. Just because you are low fees doesnt give you an excuse to provide crap service. Id rather pay the fees.
# ------------------
#
#
# Head: 0 values, morals, work ethic  Trash
#
# Chunk 1:
# Text:
# is not responsible for fraudsThey wont transfer you to fraud quickly people are not trained. Once you get someone after 1 hour , they will tell you what you want to hear and then change their mind, at the end of the day, the loss will be yours 100 except on credit cards since they can reverse it lets be fair unlike them, they will never take responsibility for anything that costs money. Also, they will tell you that you will get an answer within x days and you will be totally ghosted. The customer service wait time is a joke. This bank is trash and even saying that is not fair to trash. If there was a stock for , I wouldnt buy it for a penny.
# ------------------
#
#
# Head: mortgage renewal and move from another institution
#
# Chunk 1:
# Text:
# representative was clear in her instructions to help us move our mortgage, she was quick to respond to any questions we had and we are very happy with the service she provided... we would be happy to recommend simplii as a banking alternative
# ------------------
#
#
# Head: Mortgage Renewal
#
# Chunk 1:
# Text:
# was very helpful with our concerns. He contacted me very quickly after I left a message and everything was clearly explained and courteously taken care of. I am more than happy with his service and help.
# ------------------
# Chunk 2:
# Text:
# I renewed my Mortgage and had a great experience with  my Mortgage Specialist.  was very helpful with my mortgage needs. He was very professional, thorough and well organized. The process was seamless with no issues. This was the 2nd renewal I had done with , and it was a breeze like the 1st. Thanks so much, ! I would highly recommend working with  for your mortgage needs. I know I will be in the future.
# ------------------
#
#
# Head: 5 stars
#
# Chunk 1:
# Text:
# was excellent she answered all my questions and was very pleasant. Thank you
# ------------------
#
#
# Head:  HORRIBLE
#
# Chunk 1:
# Text:
# ABSOLUTELY HORRIBLE PRODUCT ! THEY SENT THE GIFT CARD WITHOUT  AND  AND THE PERSON CANNOT VIEW AND RECEIVE IT !!!! AFTER CALLING TO CUSTOMER SERVICE AND TALKING FOR 30 MINS NO HELP PROVIDED !!!!!! PROMISED TO PROVIDE THE HELP WITHIN 48 HOURS !!!! ABSOLUTELY DISGUSTING !
# ------------------
#
#
# Head: Huge disappointment
#
# Chunk 1:
# Text:
# advertised an attractive 6  interest rate for 150 days, so I opened an account. I had to wait for them to send a card, then a paper to sign and for a chance to call them. Finally all was set up to transfer funds from another bank, but it was 32 days from first contact, and promo interest was now NOT available!!  reconsidered, then said NO. HUGE DISAPPOINTMENT!
# ------------------
#
#
# Head:  and  working together,  rippoff
#
# Chunk 1:
# Text:
# and  working together, so even your Mortgage is with  the bank in behind is , spending million in advertising, but for missing 4.13 they charge you twice for .  45.00 and  again.In that case I can only say we need much more Covid19, maybe we cab stop the greediness.So if you like to get your Mortgage go better to  or , but not by that organization.Sorry the Evaluation is far to high with one Star, it should be  5 Stars. Sorry is not available. So in the future make sure what ever bank you go that  is not shareholder.
# ------------------
#
#
# Head:  bank in the world
#
# Chunk 1:
# Text:
# bank in the world. I have had so many problems with this bank.. trust me the no banking fees are not worth it.
# ------------------
#
#
# Head: Worst digital bank to deal with!!
#
# Chunk 1:
# Text:
# bank to deal with. They froze my bank account  each day is another excuse why I cant have my funds back. Higher management doesnt care about customers. They lie everyday with more excuses!!. Theyre unprofessional. Dont tell the truth about anything I ask them. Dont return phone calls. Ive been waiting for paperwork from them for 6 weeks to get my account back. But they wont even send me the documents l need to sign  Im still waiting!! Because theyre a digital bank theres no tellers!! That really sucks when you need to do something in person face to face. You cant do that with Simplii financial. Theyre no humans except for the call center  they always tell you to go to  with All your lD to verify you before they will send you a bank card. If youve card is ever lost or stolen, thats a really big hassle in itself to go to  again each time.
# ------------------
# Chunk 2:
# Text:
# If youve card is ever lost or stolen, thats a really big hassle in itself to go to  again each time. Then everything is done my snail mail at .Still never did get paperwork on time. They dont care about customers at all. VERY rude managements who dont know their Job  cant explain what takes so Long to get simple answers from them!! Their security is off the charts. You have to go to  to be verified each  every time!! Nobody cares or wants to help!! They were a good bank when they were PC financial. They had booths in Zehrs  . It was great then!! But not now!
# ------------------
#
#
# Head:  bank
#
# Chunk 1:
# Text:
# bank, I was try to apply a new account, it then asked me to email two IDs photos in email. I did, then they sent me another email asked to email back 3 IDs, what a jokeDate of Birth on ID doesnt match application information Please provide all three acceptable IDs.This is unacceptable and very unprofessional, so everyone please be aware .
# ------------------
# Chunk 2:
# Text:
# bank. 1 month hold on cheques from major US company. 1 month. Just not like the other major banks. Its inconvenient dealing with them tbh. I will be closing all accounts etc.
# ------------------
# Chunk 3:
# Text:
# bank. Have had so many issues with them from not being able to use my card, spend my money, my account was overdrawn for a week. Got paid today Thursday since tomorrow is the holiday and couldnt e transfer or use my funds at all. Called and they blocked ny account since it was overdrawn for a week. They didnt call me or email me at all to discuss why i was overdrawn or anthing. Just straight to blocking my account. They said I have to wait a whole business day before I can Unblock my account cause they said it could go negative again. People have bills to pay. The money is clearly there yet I cant use it. I will be closing my account after this.
# ------------------
#
#
# Head:  customer
#
# Chunk 1:
# Text:
# customer service
# ------------------
#
#
# Head:  ever
#
# Chunk 1:
# Text:
# ever, will not recommend this bank to anyone especially international students. They have an international student line to help students with their  accounts but I have been calling on this line multiple it keeps on disconnecting. And when the line connects the representative on the other side are so unprofessional, she kept me on hold and then disconnected, I experienced the same thing 3 times in a row, this is just unacceptable.For all the students coming to Canada please dont choose  for your  account as they have the worst customer service.
# ------------------
#
#
# Head:  ever.They tell me a cheque
#
# Chunk 1:
# Text:
# ever.They tell me a cheque that I deposited in my account was counterfeit but they wont show me a copy of cheque.The company the cheque was from has been in business for 18 years and has never had a problem like this before.Then they closed my account keeping the 2,200 cheque.
# ------------------
#
#
# Head:  financial is a great bank ifyou are on disability
#
# Chunk 1:
# Text:
# financial is a great bank if your on a low income bracket like myself. Its free of charge and they give you free cheques. Today I was charged a  fee of 45 for accidentally not having enough money in my account. I called an explained my situation and they reversed the fees with no issues. I highly recommend them, great bank.
# ------------------
#
#
# Head: Simplii financial is the worst
#
# Chunk 1:
# Text:
# financial is probably the worst bank in Canada. On January 10th someone took 1000 from my account and than on January 20th they took 500 . I called simplii and reported it for fraud, Today February 4th they called me and said there will be no refund for the money that was taken. They told me there is nothing they can do and I should just open an investigation with my local police. After a few years of being with them now I can see that why dont really care about there customers and they dont really care about peoples money or anything like that. They are a waste of time, and now because of them not being able to help me I have to do a report that could take over a year. They in my eyes are the worst bank in Canada
# ------------------
#
#
# Head:  got simplii cuz of
#
# Chunk 1:
# Text:
# got simplii cuz of their 2 interest rate. Once the month is over I will still get .01  upon calling they told me 2 interest will be given once the promotion is over after 4 months. of this information given prior signing up.Very disappointed folks
# ------------------
#
#
# Head: Simplii Paid my bill twice, and now I HAVE TO WAIT FOR MY MONEY BACK
#
# Chunk 1:
# Text:
# has been having technical issues with my online banking for the past 6 days . At least to my knowledge. I have been chasing them for the past 4 days to correct my online banking, and I have gotten no where other than we are looking into this. I even let them know that I am worried as their whole system was hacked not too long ago, and my card was compromised.  paid my bill twice when I DID NOT PAY IT twice. I have screen shots proving that they are having technical issues. I have even been on the phone with several representatives who have seen the issues happen on my online banking LIVE. The rep added a bill and the other one erased, and vice versa. They agreed that the issue was on their end, and here i am STUCK just waiting for an answer. Not only that, one rep said a manager will call me and they never did.
# ------------------
# Chunk 2:
# Text:
# Not only that, one rep said a manager will call me and they never did. I finally spoke to one who said the same  as the reps on the phone. What i DO NOT get is I have proof of an error made on s PART, I have asked that they take this on an urgent basis as I need to pay the bill i  paid, to not  late fees. They will NOT take this on urgently, and have told me to wait 5 business days. THEY DO NOT have a plan on who will be cover a late payment, nothing  this is absolutely AURD! ANYONE READING THIS. THIS IS A SECURITY ALERT TO ALL OF YOU! YOUR INFORMATION IS NOT SAFE WITH THEM, they will NOT protect your information by any means. IT IS YOUR JOB to continue to chase them to make sure that YOUR information is in good order.
# ------------------
# Chunk 3:
# Text:
# IT IS YOUR JOB to continue to chase them to make sure that YOUR information is in good order. You pay no fees, HENCE WHY you get NO CUSTOMER SERVICE!
# ------------------
#
#
# Head: STAY AWAY with them if you CAN!
#
# Chunk 1:
# Text:
# has screwed me over for so many time since I opened an account with them. First they sold my personal information to a third party called fairstone lending company. I can confirmed that it is really them because I used my maiden name on all my bank accounts records and all the billings except for when I opened my account in simplii, I used my married name for the very first time. Couple months later after my account has been opened, this fairstone lending company has been sending me mails offering a loan using my married name that I only used with Simplii! So unrealiable company right there. CANT BE TRUSTED for sure. Thats not the only problem that I encountered with them, they also lied to me so many times and it comes to the point that Ive just had enough thats why Im writing this review.
# ------------------
#
#
# Head: !!
#
# Chunk 1:
# Text:
# have been with PC banking  Simplii for approximately 23 yrs. I have never experienced any problems with this bank. Agents are polite and very helpful. I highly recommend. No fees. If you use checks there is no charge for them. They do charge  fees but none other that Ive experienced.
# ------------------
#
#
# Head:  have lost their minds
#
# Chunk 1:
# Text:
# have lost their minds coming out with a horrible fluorescent pink and green site and card and new motos that make no sense. After more than 15 years of banking with them I no longer trust this bank and working to close my account ASAP.
# ------------------
#
#
# Head:  is a great asset to
#
# Chunk 1:
# Text:
# is a great asset to  team He was very helpful being prompt, courteous and willing and able to answer all our questions. I just want to congrulate once again for the terrific job, we are forever humble and grateful for his service! We will certainly recommend you guys to anyone I know in the market for a mortgage.. Thank You soo much once again for the terrific job, we are forever humble and grateful for your service, It was a worry free experience as you walked us effortlessly through the transaction and always had an answer for our questions. We will not hesitate in recommending you to our family and friends when they need to renew their mortgage. We will be sure to call on you again
# ------------------
#
#
# Head:  is a joke
#
# Chunk 1:
# Text:
# is a joke Had to make 3 calls and each one gives a different answer. Consistently on hold, talk for 30 secs than 10 min hold I canceled
# ------------------
#
#
# Head:  is a shi.t bank
#
# Chunk 1:
# Text:
# is a shi.t bank. To get someone on the phone it takes more than 50 minutes. Waste pf time. Hopeless customer services. PC financial was way better than this shit bank .
# ------------------
#
#
# Head:  is awesome,from the very
#
# Chunk 1:
# Text:
# is awesome,from the very start till we finished the transaction,and all paper works,and got approve,tnx..
# ------------------
#
#
# Head:  IS SHI.T
#
# Chunk 1:
# Text:
# IS SHI.T , its not actually simplii, its shittiiii, worst bank ever and never answers phones
# ------------------
#
#
# Head:  is the best than ever from your
#
# Chunk 1:
# Text:
# is the best than ever from your bank so really to her and want raise his rank and salary because she is exellent in understanding and describing everything.
# ------------------
#
#
# Head:  is very Nice and Friendly
#
# Chunk 1:
# Text:
# is very Nice and Friendly, Polite and explained clearly,
# ------------------
#
#
# Head:  made it fast and easy to renew
#
# Chunk 1:
# Text:
# made it fast and easy to renew our mortgage rate in order to beat the BOCs hike on March 2nd. The service was fast, prompt, and clear.Thank you so much for all your help!
# ------------------
#
#
# Head:   worst customer service in the world
#
# Chunk 1:
# Text:
# should be a synonym for the worst customer service in the world. Their employee do not know what and how to write an email. They will write the same thing whether your query is  or XYZ. They make fake promises to the customers that the issue will be resolved and then they do nothing for 10 days, even after followups.
# ------------------
#
#
# Head: Simplii Terribly long wait times for
#
# Chunk 1:
# Text:
# Terribly long wait times for anything. All banking issues  have to be dealt with through the phone and they  dont pick up.  terrible. I am writing as many bad reviews as I can find places to put them while I wait for them to answer the phone. If I cant give them heck for making me wait for hours, Ill let them know this way. Dont bother. Find a bricks and mortar bank.
# ------------------
#
#
# Head:  walked me through the
#
# Chunk 1:
# Text:
# walked me through the mortgage process and was in constant contact during that time. If she could not immediately answer my questions, she quickly researched and got back to me within 24 hours. Amazing service!!! Thanks !
# ------------------
#
#
# Head:  was very polite
#
# Chunk 1:
# Text:
# was very polite, dealr efficiently with my issueThanks
# ------------------
#
#
# Head:  and !
#
# Chunk 1:
# Text:
# ecently got a mortgage with  and  went above and beyond multiple times to help me through the transaction. She proactively and effectively communicated and worked tirelessly to complete my mortgage in time. If you need an exceptional , call  x8907
# ------------------
#
#
# Head: Simply took my government check for
#
# Chunk 1:
# Text:
# mply took my government check for 47,000 dollars and wont cash it or send it back. I have a large amount collecting interest on their line of credit while they hold me hostage. This is the most corrupt institution I have ever dealt with. Avoid them at all costs. There are real banks out there who will be happy to have your business. Try . Its a much better bank than mply.
# ------------------
#
#
# Head: 1 is the lowest rating I could give
#
# Chunk 1:
# Text:
# 1 is the lowest rating I could give here unfortunately. Absolutely pathetic service. I signed up and never received a card. I phone them twice any card and everytime they told me the card is on the way. Its been 3 months and havent received anything yet.
# ------------------
#
#
# Head: Simplii simply sucks
#
# Chunk 1:
# Text:
# 15 Days ago I deposited my work cheque with  without being told I would have to undergo some extensive verifications to access my money, let me open the account and then froze my money instantly by locking all means of moving my funds, now telling me I need 2 government photo ids to verify, but the government of Canada says I only need 1! Guess simplii writes the laws here in Canada now. Sent in 3 paystubs 2 identifications, 2 t4 slips and 2 bank account statements from different banks and still they are not letting me get my funds, havent even been able to pay my rent because of this either. I think simplii should be financially compensating me a little here, or is that 2 much to ask? 20 days now
# ------------------
#
#
# Head: 5 stars for
#
# Chunk 1:
# Text:
# 5 stars for . Very professional , knowledgeable and extreemly helpful. I did not have to ask for anything and she provided an amazing client experience and truly made my day. You should have more like her 100 ...thank you much for all your help and offering such amazing service. Above and beyond in my book
# ------------------
#
#
# Head: 500 in  FEES IN 1 WEEK.
#
# Chunk 1:
# Text:
# 500 in  FEES IN 1 WEEK.Sorry, I meant 16 weeks. During a pandemic and I have been with them for six years. Wont be seven. Lol
# ------------------
#
#
# Head: 6 you cant go wrong
#
# Chunk 1:
# Text:
# 6 you cant go wrong. costumer service was good. I didnt use a promo code and missed out on the free 50.Dont forget to join with a link to get the bonus 50.  6Dfjmv
# ------------------
#
#
# Head: Paid 36 000 in taxes I wasnt supposed to pay
#
# Chunk 1:
# Text:
# A bank rep mistakenly filed the wrong form or checked the wrong item on the form, which resulted in me paying roughly 36 000 in taxes I wasnt supposed to pay. Its been 5 months and nothing is done to fix that. I cannot contact the   they seem to be closed for quarantine. Interestingly, the bank itself doesnt seem to have a web page for complaints.
# ------------------
#
#
# Head: Routine inquiry twisted into an OBJECTION!
#
# Chunk 1:
# Text:
# A followup call to their customer care center regarding a bank draft I ordered turned into being transferred to a  who was hesitant to issue the draft based on a large cheque deposit from approximately a week or more ago. The cheque had passed the usual clearinghold time and it was from a reputable large company, not at all a personal cheque or from a small business. It was rather upsetting as I had complete access to all my funds if I wanted to go shopping or gamble them away at a O...but I was being treated as if I was trying to orchestrate a scam over a request for a bank draft. To make it worse the  turned it all around twisting it  she told me that I was placing a complaint and all complaints are recorded and subject to review and that they HAD THE IGHT to record... The only reason I was calling was to find out an  on the bank draft. The  all on her own turned it into some of the poorest service I think Ive had in a very long time.
# ------------------
# Chunk 2:
# Text:
# The  all on her own turned it into some of the poorest service I think Ive had in a very long time. When I called in I was perfectly fine and by the end of the call I was so frustrated I made the decision to cancel the draft. Then when I said I want to cancel and will get the draft through my other bank.. then she went into salvage mode to try to get the draft prepared. It sounds absurd... this was one of the oddest and worst customer service experiences. I dont take it lightly writing negative reviews... this seriously left my head spinning, and is beyond what common sense should guide an employee to say out loud to a client. Combined this with hit or miss loan withdrawal dates not in real time, bill payments lagging up to 4 days, 2 days for a bank draft... My thoughts are to utilize a real bank for everydayprimary needs.
# ------------------
#
#
# Head: A terrible bank
#
# Chunk 1:
# Text:
# A lowlife, deceitful organization that does not care about facts. They cater to their low needs and disguise it as professionalism. Definitely see a more reputable bank, , maybe.
# ------------------
# Chunk 2:
# Text:
# A terrible bank, I had to change my phone number. They made me return to the branch 20 minutes from home. The next day my card would not return from the atm. Another hour on the phone. They are a awful bank.
# ------------------
#
#
# Head: Absolute bullsht bank
#
# Chunk 1:
# Text:
# Absolute bullsht bank. Been trying for 3 weeks to open their high interest savings account and to put money into it. There is always some kind of screw up. Its impossible to navigate this cluster  of an institutionbut they do have the coolest looking debit cards I have ever seen
# ------------------
#
#
# Head: Absolute garbage
#
# Chunk 1:
# Text:
# Absolute garbage, applied for a debit card got approved and they said they were sending it out over a week ago. Tried to get in touch with the customer support, they dont let you talk to a real rep without a debit or credit card number. What if I lost my card how would this work? Way worse than cibc garbage interface
# ------------------
#
#
# Head: Absolute incompetence
#
# Chunk 1:
# Text:
# Absolute incompetence, incapable of providing any customer service at all and nothing but excuses after excuses !! you are better off dealing with anyone else then these people !! Complete waste of time !!
# ------------------
#
#
# Head: Absolute nonsense
#
# Chunk 1:
# Text:
# Absolute nonsense. Better off keeping your money in a piggy bank! I just opened a new account and as per their policy, I have a daily withdrawal limit of 200 for the first SIX MONTHS!! Even after that the  withdrawal is 1000 a day. They  is just trying to make as much money off of your money as humanly possible. I do not recommend this financial institution at all.
# ------------------
#
#
# Head: Absolute worst bank I have ever dealt
#
# Chunk 1:
# Text:
# Absolute worst bank I have ever dealt with. I have been banking with  since the switch over from  but my experiences over the past year with this bank have been terrible. Extremely long hold times, very poor customer service, a terrible system all around. Too many problems with them to get into on this review but felt the need to warn anyone thinking about using them.
# ------------------
#
#
# Head: absolute WORST bank you could choose
#
# Chunk 1:
# Text:
# absolute WORST bank you could choose. they have what seems to be students working the phones and customer service and know absolutely nothing about the company or how to help. they sent me broken debit cards that dont work and refused to even be slightly helpful and said it must be my pin. ive done all they said and still nothing so at this point im changing banks. absolutely useless, do not join this bank no matter what.
# ------------------
#
#
# Head: Absolutely atrocious!!!!!!!!!!
#
# Chunk 1:
# Text:
# Absolutely atrocious!!!!!!!!!!Do not ever go with this bank their customer service is the worst out there I am appalled, waited 8 days for a cheque to clear from work countless hours on the phone and then passed yet again to another department. Dont sign up no matter what!!!!!!
# ------------------
#
#
# Head: Absolutely awful service
#
# Chunk 1:
# Text:
# Absolutely awful service. I sent a money transfer 10 days ago and havent gotten anything. On top of that they have no idea where my money is. Says I will have to wait upto 21 days to get an answer, which is absolutely ridiculous. Will be switching banks as this is unacceptable service.
# ------------------
#
#
# Head: Absolutely brutal customer service.They
#
# Chunk 1:
# Text:
# Absolutely brutal customer service.They will NOT listen.I was a good customer for years, but when my wife deposited a baby bonus cheque endorsed to her by my son,  locked up my bank accounts for 2 weeks and counting! My son cannot buy food for his children. Avoid this bank like this plague.
# ------------------
#
#
# Head: Absolutely fantastic service
#
# Chunk 1:
# Text:
# Absolutely fantastic service. Had a cheque issue and they fixed in a timely manner. Thanks !
# ------------------
#
#
# Head: Absolutely horrible
#
# Chunk 1:
# Text:
# Absolutely horrible! Do not bank with them. They held my check back, would not clear it even though it was exactly the same as other checks I was depositing twice a month for the past 10 months and had no issues with any of them. They did not call or email me, or notify me in anyway that they were holding my check hostage. When my mortgage came out and left our account empty I had to call them to find out why the check was held back. Turns out they will not accept checks made out to our small business of 1 person anymore. They hadnt noticed for 10 months, but suddenly its the end of the world if they cash them. Our business is 1 person, it is not incorporated, but they refuse to allow us to cash these small checks to our account. They said it must be a business account....which they do not offer. So I have to change banks. Wow, what a nice way to say you dont care about keeping my business at all.
# ------------------
# Chunk 2:
# Text:
# So I have to change banks. Wow, what a nice way to say you dont care about keeping my business at all. mplii does not support or care about small businesses at all. We now have to go to another bank, pay huge business account fees, and now pay all our bills from another bank. mplii wouldnt allow us to endorse our checks either, nothing with our business name on it, even if it has our own personal name on it as well. No options whatsoever to continue depositing our income with them. They are absolutely horrible and very difficult to deal with, and wont notify you of anything, you will have to watch your account like a hawk, they want to steal from you every chance they get. I have been banking with them and back when they were pc for the past 20 years and this is how I am treated! I will be closing my accounts asap and never banking with them again.
# ------------------
#
#
# Head: Absolutely infuriating company
#
# Chunk 1:
# Text:
# Absolutely infuriating company. If you ever need to do things quickly, dont use this company. If you are ever looking to make big purchases home etc or anything professional do not use. NOW on top of how big of a headache this company has been without forewarning they have frozen ALL my funds, bc i was putting money into my account from . So now all of my accounts are frozen, they screwed me so badly and gave me no forewarning as i said  i cant wait until i get my unfrozen so i can LEAVE this terrible excuse of a bank lol .
# ------------------
#
#
# Head: Absolutely terrible and incompetent
#
# Chunk 1:
# Text:
# Absolutely terrible and incompetent service. Had a basic account there for over 15 years. Applied for a credit card since they kept sending me promotions. I have A1 credit and earn close to 140k. I was willing to close one of my higher interest cards for . eceived approval, but no information on limit. After waiting on the phone and being transferred multiple times  Yes the agent said I was luck to have a limit of 2k. OMG!! You have to be kidding me, 2k?? When I asked how was this possible, then more transferring and holding, and waiting, until after 1.5 hrs, the clown came back on to say I have to contact . What the hell??No one could answer why, what criteria was used, and further was told I have to build up my credit score to be considered for an increase. What a bunch of fools.
# ------------------
# Chunk 2:
# Text:
# ...
# ------------------
#
#
# Head: Worst bank EVER!!
#
# Chunk 1:
# Text:
# Worst bank EVER!! Long storyshort This bank closed my autistic sons bank account without warning!!! Discrimination against special meeds customers that are on ODSP. After waiting all month for his ODSP income the bank waits for his cheque to be deposited them decides to close his account leaving him with no money, when I called the bank they said they would send a cheque in the mail. No compassion or customer care for clients with disabilities. Simpli trash should be the slogan.
# ------------------
#
#
# Head: Worst bank ever!!
#
# Chunk 1:
# Text:
# Worst bank ever!!! I deposited a check with my married name on it but my account is under my maiden name. They requested I change my name which I then provided all the info and changed it so they could release the cheque I deposited then only to be told later once the name change was done that my certified check will be hold for another 13 business days. They lied to me from the very beginning. It would have been way faster to get the check back by mail and deposit it at another bank.  learned and Ill be changing bank to a real one! Shame on you simplii!!!
# ------------------
#
#
# Head: Worst bank
#
# Chunk 1:
# Text:
# Worst bank EVER. Been banking with themFor 8  years, decided to hold a cheque and have been fighting with them for 7 days now  they also helpMy  FOR NO REASON
# ------------------
#
#
# Head: worst banking experience ever!
#
# Chunk 1:
# Text:
# worst banking experience ever!
# ------------------
#
#
# Head: Worst banking experience of my live
#
# Chunk 1:
# Text:
# Worst banking experience of my lifeIt took me 4 weeks to get my account set up. The people working at the phone are very bad at their job and cant assists you at all. I got the Mail of account verification 3 ! times. Each time 5  7 days in between. They ask you to upload a selfie, but the whole software doesnt work.
# ------------------
#
#
# Head: Worst banking experience
#
# Chunk 1:
# Text:
# Worst banking experience. I tried to contact the centre to ask for assistance but they instead freeze the account. They informed me that I am not authorized to use the account because this is only for my wifes single account. We already applied for the joint account 2 years ago and had some transactions for the past months using this account that it went through. After they talked to my wife, they still freeze the account even after begging them not to freeze it. We have our payment dues this week and have to pay for additional fees because of this.Worst customer service ever!
# ------------------
#
#
# Head: WORST CUSTOMER SERVICE IN THE WORLD
#
# Chunk 1:
# Text:
# WORST CUSTOMER SERVICE IN THE WORLD  I HAVE BEEN TRYING TO CONTACT THEM FOR A MONTH VIA PHONE AND IT MAKES NO DIFFERENCE WHAT TIME OF THE DAY OR NIGHT YOU CALL, YOU GET THE SAME MESSAGE THAT THEY ARE EXPERIENCING A HEAVIER THAN USUAL CALL VOLUME  THE RECORDING SAYS THAT YOUR CALL IS IMPORTANT BUT THE FACT THAT NO ONE EVER ANSWERS ILLUSTRATES THE FACT THAT THEY COULD CARE LESS  IF YOU ARE THINKING ABOUT OPENING AN ACCOUNT WITH  AND FRUSTRATION.
# ------------------
#
#
# Head: worst experience ever
#
# Chunk 1:
# Text:
# worst experience ever. Closed all my accounts the minute I could. Stay away!!
# ------------------
#
#
# Head: Worst experience I applied for credit
#
# Chunk 1:
# Text:
# Worst experience I applied for credit card and it has been 2 month still when I called, I got the answer it is under the process.
# ------------------
#
#
# Head: Worst experience I was waiting on call
#
# Chunk 1:
# Text:
# Worst experience I was waiting on call for almost an hour no one connected and there are so many duplicate amount deductions on visa card if simplii financial account.and no agent will connect on call to communicate about it.please kindly dont take simplii financial from my account 150 cad has been deducted from my account in the name of insta card and berEATS names which are dublicate orders
# ------------------
#
#
# Head: Worst service
#
# Chunk 1:
# Text:
# Worst service possible. Do not use , I opened my  account with , I received my Debit card in a month after landing in Canada, its the third month and I am still waiting for my  card. No responses to emails and an hour long waiting if you want to talk to the customer representative. It is tough when you rely only on  money to survive and you do not even have that. I do not recommend anyone to choose , save your time and efforts and choose  or .
# ------------------
# Chunk 2:
# Text:
# Worst service. Never use  for . They will take ages to resolve a issue.
# ------------------
#
#
# Head: Would give a minus 5 if I could worst
#
# Chunk 1:
# Text:
# Would give a minus 5 if I could worst customer service experience and truly a  started on Thanksgiving day when I called to increase  withdrawal limit to get some urgently needed cash.They found that my husbands previous place of work had used a part of his name we have long names for automatic payroll deposits. By the way it had happened for 12 years they only noticed it as hes in a new company now and their payroll had used parts from the previous and one more name. Simplii is saying that we are using someone elses money for 12 years and they need to protect their bank and this third person. The simple fact that both these are the same person with the same  no is of no use to them. My mortgage and other pre authorized paymets go from this account when asked they say they cant do anything about it.
# ------------------
# Chunk 2:
# Text:
# My mortgage and other pre authorized paymets go from this account when asked they say they cant do anything about it. Its being 4 days and when called the contact center supervisors wont allow it to go beyond them and said if you were driving at 60kmhr on a 50km zone and get a ticket 10 years later its still valid. I told him my car is not impunded.this is you guys blocking our whole livelihood. Too bad was the attitude as they didnt care. They are treating us like criminals. Simply cos my husband have lots of parts in his legal name. There is no customer service nor any ethics or humanity in their dealings.I am shocked beyond words for the treatment and treating us as criminals.
# ------------------
#
#
# Head: Would give zero stars if I could
#
# Chunk 1:
# Text:
# Would give zero stars if I could. I was ripped off 80 at an . The machine gave a 20 instead of the 100 it was supposed to. Immediately contacted  and have been waiting over 4 months for a resolution. At this point, it borders theft. It appears that they are prolonging this in hopes that I just give up and eat the 80 loss.
# ------------------
#
#
# Head: Wouldve given more stars than three
#
# Chunk 1:
# Text:
# Wouldve given more stars than three. But they fall short in some sectors of their services. There general line for clients to call with general banking questions is always a joy with short wait times and friendly customer service representatives to help you out. Unfortunately, during a recent communication with there   card Dispute department, while trying to sort out a recent problem with an online transaction. I was offered no help nor advice besides  Wait and see. from one of their telecommunications agents. I sat on hold for 45 minutes to speak with this department only for this particular agent to ramble on about their credentials and their years of experience in this department and that they knew what they were talking about and take many calls a day. Then, when I was displeased with my services threw money at the problem  15.00 for bad services will be added into your account in 2 days.. I dont want money thrown at me, I want genuine assistance, accurate information and patience.
# ------------------
# Chunk 2:
# Text:
# Instead a received nothing but push back and well a dispute between myself and the agent. This was by far my most negative experience with  yet. Which is really unfortunate. Yes, with online only banking you do not get the same face to face communication and assistance but, this was unacceptable even for over the phone online banking. Extremely displeased with this situation.
# ------------------
#
#
# Head: Wow, not understanding all the negative reviews
#
# Chunk 1:
# Text:
# Wow, not understanding all the negative reviews. We have been  customers since it was , for over 20 years now. We have bank accounts, line of credit, and credit cards with them. We do not have a mortgage so I cannot comment on that product.I do not understand all the comments about fraudulent activity surely they are regulated like every other bank, and actual fraud is not a thing.Holds on deposits are standard practice depending on certain circumstances. In fact, especially as a virtual bank, these practices are there to protect the customer and the bank. I successfully reduced holds on my deposits, over time, as I was instructed to do.I also do not understand all the comments on the long wait times, not commonplace  I rarely have to wait more than a couple of minutes to talk to someone, and their staff are always friendly, courteous, and professional. You will wait longer if calling in the middle of the night, but even then its not too long.
# ------------------
# Chunk 2:
# Text:
# You will wait longer if calling in the middle of the night, but even then its not too long. mobile app and online interfaces are comprehensive and easy to use, much better than a lot of the brick and mortar banks in Canada, trust me, Ive tried most of them.This is not a complaint but a wish list item. I run a business, so my business account is at another bank unfortunately. I hope one day you will offer business accounts!We had a seamless transition from  to  when it happened a few years ago as well. Still super happy not to have to pay monthly banking fees! Thank you ! We continue to recommend you to our friends.
# ------------------
#
#
# Head: Not a real
#
# Chunk 1:
# Text:
# Wrote a note on my account banning me from their products with no explanation... its a bank, you really shouldnt be able to ban someone with no explanation.
# ------------------
#
#
# Head: You cant deposit foreign cheques
#
# Chunk 1:
# Text:
# You cant deposit foreign cheques through the  or edeposit. You have to pay to mail it to them then they take up to eight business days to deposit it into your account BUT then it takes a month and a half for  to release the funds. Im waiting nearly two month for a 95 cheque, pathetic
# ------------------
#
#
# Head: You get what you pay for
#
# Chunk 1:
# Text:
# You get what you pay for. And hopefully you never have to utilize their customer service. There security questions are very hard to answer, and when you fail to answer them correctly they place you on hold multiple times while you wait to speak with a supervisor, who then asks you more difficult questions. And after you fail those they require you to send a written letter stating more personal information about yourself. Keep in mind I had already successfully verified my name, address, last bill payment that came from my account, last etransfer sent, my account number, and my  number. They still required more information. I.e. old address, how long youve banked with them, etc. And when I couldnt provide them with their automated questions I was transferred to someone else.
# ------------------
# Chunk 2:
# Text:
# And when I couldnt provide them with their automated questions I was transferred to someone else. You are given the run around for over half an hour on the phone while they continue transferring your call and placing you on hold while you wait to speak with different supervisors and managers. Whom require you to hang up and have them call you back on your number you provided. Unfortunately I have had to deal with this twice in the last week. The first time I had lost my card and needed a new one sent. The second time I needed my new card number while I waited for it to arrive in the mail so I could access my online banking info. Very simple things, that required a very rigorous screening process. If I didnt already have so many automatic bills and e transfers coming out of that account each month Id find a different company, their customer service is the worst Ive ever had to deal with.
# ------------------
# Chunk 3:
# Text:
# If your time is valuable to you, find a different company.
# ------------------
# Chunk 4:
# Text:
# You get what you pay for. Long story short one day, the bank started to ask me security questions from  5yearold information about my closed account, which I could not recall. I did have my online banking password, phone password on file, my secret code word, and I was calling from a registered phone number on file. I ended up failing my security questions. I asked if I can go anywhere physically and ID myself, but was told it was not an option. I was requested to send my ID, phone bill, address, phone number, date of birth, and order of direction with my signature, which I did. I was told that something does not match. I doublechecked with my online profile which I still had access to, and all the information was correct. So my account was further locked.
# ------------------
# Chunk 5:
# Text:
# I doublechecked with my online profile which I still had access to, and all the information was correct. So my account was further locked. Another week later, I got a call from the  fraud office very shady, as it is not part of , and no instruction was given to me about such a call back from . The guy on the line was quite rude and was asking me to provide him with a credit card number outside of  for confirmation for verification. I declined that, he threatened me if I dont give him this information my account will be blocked  ten days into this mess. I called  again and was told that I could go to  to verify myself personally I was asking for this from the beginning. I was told that the email would arrive in two hours with instructions. I waited until later in the evening and decided to call again.The agent on the phone took all the information back and told me that it takes 24h to receive the email with instructions.
# ------------------
# Chunk 6:
# Text:
# However, as soon as I finished the call, the email arrived right away. Ive yet to go to , but I anticipate that some more complications will come out. My recommendation is to stay away from financial institutions with no physical location. I would never again trust  to hold my money. Ones you give  you pay, you might not be able to get it back in a while. I feel like there is no proper way to complain, and all attempts come back to managers on the phone.0320  paperwork on 0220, the update from  has not been received yet by . Its been over a month without access to account.
# ------------------
#
#
# Head: You have to wait on the line like
#
# Chunk 1:
# Text:
# You have to wait on the line like forever for calling customer service, theres an unusual transaction that took 391 from my account.The blocked my debit card and gave me a new one, i thought they will put it back to my account the money but no they didnt.Life now a days is so hard, for me that amount is big enough to do an investigation but they didnt do anything.Injust want my money back,i never use my debit card for online shopping .I really dont know how it happens, i deposited money that day and didnt check my account then. Then one day decided to deposit money, and noticed the unusual transaction that i never did exactly the same day i deposited money.
# ------------------
#
#
# Head: Zero stars!
#
# Chunk 1:
# Text:
# Zero stars! Customer service is atrocious. Incompetence at all levels. Called repeatedly to clear up a problem related to the opening of a basic account. Spent hours on hold. Problem still not resolved weeks later. Stay away from this company.
# ------------------
#
#
# Head: zero stars!!
#
# Chunk 1:
# Text:
# zero stars!!
# ------------------

# %%
chunk_vector_store = WeaviateVectorStore(
    weaviate_client=client, index_name="Reviews_Chunk", text_key="text"
)
chunk_storage_context = StorageContext.from_defaults(vector_store=chunk_vector_store)
chunk_index = VectorStoreIndex(nodes, storage_context=chunk_storage_context)

# %%
chunk_retriever = chunk_index.as_retriever(similarity_top_k=6)

chunk_query_engine = RetrieverQueryEngine(retriever=chunk_retriever)
result = chunk_query_engine.query("Tell me about the worst reviews")
print(f"Result: \n\n{result}")
# Out:
# Result:
#
# It appears that the bank in question has a history of receiving extremely negative reviews from customers. Many reviewers have expressed frustration with the bank's customer service, citing rude and unhelpful staff, long wait times, and a lack of knowledge or competence. Some reviewers have also reported difficulty in accessing their accounts, and have been left feeling deceived or taken advantage of.
#
# One reviewer described the bank's processes as "archaic" and noted that they can only send withdrawal forms by post. Another reviewer reported being put on hold multiple times and being read the same scripted answer by phone staff.
#
# Several reviewers have also expressed concerns about the bank's management, with one reviewer describing a manager as "not helpful" and another reporting that a manager claimed to be the highest authority and refused to transfer the call to a superior.
#
# Overall, the reviews suggest that the bank has a reputation for poor customer service, unhelpful staff, and outdated processes.

# %% [markdown]
# # RAGAS Eval for Chunking

# %%
from datasets import Dataset

dataset = Dataset.from_pandas(test_set)
answers = np.empty(len(dataset), dtype=object)

for index, row in enumerate(dataset):
    query = row["question"]

    answer = chunk_query_engine.query(query)

    print(f"Result {index}\nQuestion: {query}\nAnswer: {answer}\n")

    # Store the result
    answers[index] = str(answer)
# Out:
# Result 0
# Question: How do the reviewer's experiences with Simplii's systems contribute to their negative sentiment?
#
#
# This question directly addresses the keyphrase "Unreliable systems" within the context of the review, prompting an answer that focuses on the reviewer's frustrations with the systems' failures.
#
# Answer: The reviewer's experiences with Simplii's systems contribute to their negative sentiment by revealing a pattern of failures and inefficiencies. They report being unable to access their funds, experiencing holds on transfers, and encountering issues with their Simplii card, including it stopping work without explanation. These incidents suggest a lack of reliability and trustworthiness in Simplii's systems, leading to frustration and a negative perception of the company.
#
# Result 1
# Question: How long was the reviewer's money held up by the bank?
#
#
#
# Answer: The reviewer's money was held up for 3 weeks and counting, as mentioned in the review dated July 20, 2021.
#
# Result 2
# Question: Why couldn't the customer activate their approved acct?
# Answer: The customer was unable to activate their approved account because the bank's staff failed to send the required documents, including the account opening package, and also failed to follow through with the process, resulting in a delay of over two weeks before the issue was resolved.
#
# Result 3
# Question: What financial service is causing the delay?
# Answer: A loan approval.
#
# Result 4
# Question: What credit product did both reviewers target?
# Answer: A secured line of credit.

# %%
dataset = dataset.add_column("answer", answers)
dataset
# Out:
# Dataset({
#     features: ['question', 'contexts', 'ground_truth', 'evolution_type', 'metadata', 'episode_done', 'answer'],
#     num_rows: 5
# })

# %%
dataset = dataset.map(convert_string_to_list)
dataset.features
# Out:
# Map:   0%|          | 0/5 [00:00<?, ? examples/s]
# {'question': Value(dtype='string', id=None),
#  'contexts': Sequence(feature=Value(dtype='string', id=None), length=-1, id=None),
#  'ground_truth': Value(dtype='string', id=None),
#  'evolution_type': Value(dtype='string', id=None),
#  'metadata': Value(dtype='string', id=None),
#  'episode_done': Value(dtype='bool', id=None),
#  'answer': Value(dtype='string', id=None)}

# %%
from ragas import evaluate
from ragas.metrics import Faithfulness, ContextPrecision, AnswerCorrectness
from datasets import Dataset
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

OPENAI_API_KEY = 'key'
#GENERATOR_MODEL_NAME = "Mistral-7B-Instruct-v0.3"
GENERATOR_MODEL_NAME = "Meta-Llama-3.1-8B-Instruct"
GENERATOR_BASE_URL = "https://kscope.vectorinstitute.ai/v1"
EMBEDDING_MODEL_NAME = "BAAI/bge-base-en-v1.5"

# Define the RAG embeddings model (different than the OpenAI embedding model defined above for test set generation)
model_kwargs = {'device': 'cuda', 'trust_remote_code': True}
encode_kwargs = {'normalize_embeddings': True} # set True to compute cosine similarity

print(f"Setting up the RAG embeddings model...")
embeddings = HuggingFaceEmbeddings(
    model_name="BAAI/bge-base-en-v1.5",
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs,
)

generator_llm = ChatOpenAI(
    #model="Meta-Llama-3.1-8B-Instruct",
    model="gemma-2-9b-it",
    base_url=GENERATOR_BASE_URL,
    api_key=OPENAI_API_KEY,
)

score = evaluate(
    dataset=dataset,
    metrics=[
        Faithfulness(),
        ContextPrecision(),
        AnswerCorrectness(),
    ],
    llm=generator_llm, # Using OpenAI LLM as the evaluator
    embeddings=embeddings,
)
# Out:
# Setting up the RAG embeddings model...
# Evaluating:   0%|          | 0/15 [00:00<?, ?it/s]
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_answer_correctness.py:277: DeprecationWarning: The function ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use single_turn_ascore instead.
#   similarity_score = await self.answer_similarity.ascore(
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_answer_correctness.py:277: DeprecationWarning: The function ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use single_turn_ascore instead.
#   similarity_score = await self.answer_similarity.ascore(
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_answer_correctness.py:277: DeprecationWarning: The function ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use single_turn_ascore instead.
#   similarity_score = await self.answer_similarity.ascore(

# %%
score.to_pandas()
# Out:
#                                           user_input  \
# 0  How do the reviewer's experiences with Simplii...
# 1  How long was the reviewer's money held up by t...
# 2  Why couldn't the customer activate their appro...
# 3       What financial service is causing the delay?
# 4     What credit product did both reviewers target?
#
#                                   retrieved_contexts  \
# 0  [datePublished: 3/14/2024\nheadline: Horrible ...
# 1  [datePublished: 11/1/2024\nheadline: Dont wast...
# 2  [datePublished: 2/6/2020\nheadline: Prejudice ...
# 3  [datePublished: 5/11/2021\nheadline: I overpai...
# 4  [datePublished: 2/6/2024\nheadline: Experience...
#
#                                             response  \
# 0  The reviewer's experiences with Simplii's syst...
# 1  The reviewer's money was held up for 3 weeks a...
# 2  The customer was unable to activate their appr...
# 3                                   A loan approval.
# 4                          A secured line of credit.
#
#                                            reference  faithfulness  \
# 0  The reviewer expresses frustration with Simpli...      0.625000
# 1  The reviewer's money was held up for 14 days, ...      0.333333
# 2  The customer couldn't activate their account b...      0.400000
# 3  The context does not provide information about...      0.000000
# 4                           A secured line of credit      1.000000
#
#    context_precision  answer_correctness
# 0                1.0            0.974735
# 1                1.0            0.408285
# 2                1.0            0.313508
# 3                0.0            0.131695
# 4                1.0            0.994893

# %%
data.to_csv('/path/chunking_scores.csv')

# %% [markdown]
# (chunk_size = 256, chunk_overlap = 32)

# %% [markdown]
# # RAGAS with ReRanker with same chunk sizes (chunk_size = 256, chunk_overlap = 32)

# %% [markdown]
# ## Loading Weaviate DB

# %%
from llama_index.core.postprocessor import LongContextReorder

chunk_vector_store = WeaviateVectorStore(
    weaviate_client=client, index_name="Reviews_Chunk", text_key="text"
)

chunk_retriever = VectorStoreIndex.from_vector_store(chunk_vector_store).as_retriever(
)

reorder = LongContextReorder()

# assemble query engine
chunkrerank_query_engine = RetrieverQueryEngine(
    retriever=chunk_retriever,
    #response_synthesizer=response_synthesizer,
    node_postprocessors=[reorder],
)

# %% [markdown]
# ## Evaluation

# %%
from datasets import Dataset

dataset = Dataset.from_pandas(test_set)
answers = np.empty(len(dataset), dtype=object)

for index, row in enumerate(dataset):
    query = row["question"]

    answer = chunkrerank_query_engine.query(query)

    print(f"Result {index}\nQuestion: {query}\nAnswer: {answer}\n")

    # Store the result
    answers[index] = str(answer)
# Out:
# Result 0
# Question: How do the reviewer's experiences with Simplii's systems contribute to their negative sentiment?
#
#
# This question directly addresses the keyphrase "Unreliable systems" within the context of the review, prompting an answer that focuses on the reviewer's frustrations with the systems' failures.
#
# Answer: The reviewer's experiences with Simplii's systems contribute to their negative sentiment by causing frustration and inconvenience, as evidenced by their inability to access their funds in a timely manner and their repeated failed attempts to resolve the issue through daily calls. This suggests that the systems are unreliable and unable to meet the reviewer's needs, leading to a negative perception of the service.
#
# Result 1
# Question: How long was the reviewer's money held up by the bank?
#
#
#
# Answer: The reviewer's money was held up for a couple of days, and then again for an unspecified period of time, but it was eventually corrected within 24 hours.
#
# Result 2
# Question: Why couldn't the customer activate their approved acct?
# Answer: The customer was unable to activate their account because they were put on hold for an extended period of time, which was deemed unacceptable by the customer.
#
# Result 3
# Question: What financial service is causing the delay?
# Answer: The delay is caused by a lack of response from the customer service department, which is preventing the customer from accessing their account.
#
# Result 4
# Question: What credit product did both reviewers target?
# Answer: The reviewers targeted a financial product offered by a company that provides account access, referrals, and bonuses.

# %%
dataset = dataset.add_column("answer", answers)
dataset
# Out:
# Dataset({
#     features: ['question', 'contexts', 'ground_truth', 'evolution_type', 'metadata', 'episode_done', 'answer'],
#     num_rows: 5
# })

# %%
import ast

# Method 1: Using map
def convert_string_to_list(example):
    example['contexts'] = ast.literal_eval(example['contexts'])
    return example

dataset = dataset.map(convert_string_to_list)
dataset.features
# Out:
# Map:   0%|          | 0/5 [00:00<?, ? examples/s]
# {'question': Value(dtype='string', id=None),
#  'contexts': Sequence(feature=Value(dtype='string', id=None), length=-1, id=None),
#  'ground_truth': Value(dtype='string', id=None),
#  'evolution_type': Value(dtype='string', id=None),
#  'metadata': Value(dtype='string', id=None),
#  'episode_done': Value(dtype='bool', id=None),
#  'answer': Value(dtype='string', id=None)}

# %%
from ragas import evaluate
from ragas.metrics import Faithfulness, ContextPrecision, AnswerCorrectness
from datasets import Dataset
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_huggingface.embeddings import HuggingFaceEmbeddings

OPENAI_API_KEY = 'key'
#GENERATOR_MODEL_NAME = "Mistral-7B-Instruct-v0.3"
GENERATOR_MODEL_NAME = "Meta-Llama-3.1-8B-Instruct"
GENERATOR_BASE_URL = "https://kscope.vectorinstitute.ai/v1"
EMBEDDING_MODEL_NAME = "BAAI/bge-base-en-v1.5"

# Define the RAG embeddings model (different than the OpenAI embedding model defined above for test set generation)
model_kwargs = {'device': 'cuda', 'trust_remote_code': True}
encode_kwargs = {'normalize_embeddings': True} # set True to compute cosine similarity

print(f"Setting up the RAG embeddings model...")
embeddings = HuggingFaceEmbeddings(
    model_name="BAAI/bge-base-en-v1.5",
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs,
)

generator_llm = ChatOpenAI(
    #model="Meta-Llama-3.1-8B-Instruct",
    model="gemma-2-9b-it",
    base_url=GENERATOR_BASE_URL,
    api_key=OPENAI_API_KEY,
)

score = evaluate(
    dataset=dataset,
    metrics=[
        Faithfulness(),
        ContextPrecision(),
        AnswerCorrectness(),
    ],
    llm=generator_llm, # Using OpenAI LLM as the evaluator
    embeddings=embeddings,
)
# Out:
# Setting up the RAG embeddings model...
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/_analytics.py:72: ResourceWarning: unclosed file <_io.TextIOWrapper name='/h/ws_oonyeagwu/.local/share/ragas/uuid.json' mode='r' encoding='ISO-8859-1'>
#   user_id = json.load(open(uuid_filepath))["userid"]
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# Evaluating:   0%|          | 0/15 [00:00<?, ?it/s]
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_answer_correctness.py:277: DeprecationWarning: The function ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use single_turn_ascore instead.
#   similarity_score = await self.answer_similarity.ascore(

# %%
score.to_pandas()
# Out:
#                                           user_input  \
# 0  How do the reviewer's experiences with Simplii...
# 1  How long was the reviewer's money held up by t...
# 2  Why couldn't the customer activate their appro...
# 3       What financial service is causing the delay?
# 4     What credit product did both reviewers target?
#
#                                   retrieved_contexts  \
# 0  [datePublished: 3/14/2024\nheadline: Horrible ...
# 1  [datePublished: 11/1/2024\nheadline: Dont wast...
# 2  [datePublished: 2/6/2020\nheadline: Prejudice ...
# 3  [datePublished: 5/11/2021\nheadline: I overpai...
# 4  [datePublished: 2/6/2024\nheadline: Experience...
#
#                                             response  \
# 0  The reviewer's experiences with Simplii's syst...
# 1  The reviewer's money was held up for a couple ...
# 2  The customer was unable to activate their acco...
# 3  The delay is caused by a lack of response from...
# 4  The reviewers targeted a financial product off...
#
#                                            reference  faithfulness  \
# 0  The reviewer expresses frustration with Simpli...      0.833333
# 1  The reviewer's money was held up for 14 days, ...      0.666667
# 2  The customer couldn't activate their account b...      0.250000
# 3  The context does not provide information about...      0.000000
# 4                           A secured line of credit      0.666667
#
#    context_precision  answer_correctness
# 0                1.0            0.669092
# 1                1.0            0.194264
# 2                1.0            0.357388
# 3                0.0            0.187277
# 4                1.0            0.155886

# %% [markdown]
# # RAG with Semantic Chunking

# %%
from llama_index.core import Document

df = pd.read_csv("/projects/RAG2/cibc-2/Bootcamp_Dataset_CIBC2.csv")

# Ensure NaN values are replaced with None
df = df.where(pd.notna(df), None)

# Specify metadata fields to include
metadata_fields = ["datePublished", "rating", "topic", "headline","sentiment"]  # Manually specify which columns to use as metadata

# Modify loop to replace None values in metadata with "N/A"
documents = [
    Document(
        text=row['reviewBody'],
        metadata={key: (value if value is not None and value != "" else "N/A") for key, value in row.items() if key in metadata_fields}
    )
    for _, row in df.iterrows()
]

# %%
from llama_index.core.node_parser import (
    SentenceSplitter,
    SemanticSplitterNodeParser,
)

from llama_index.core.postprocessor import SimilarityPostprocessor

print(f"Setting up the embeddings model...")
embeddings = HuggingFaceEmbedding(
    model_name=EMBEDDING_MODEL_NAME,
    device='cuda',
    trust_remote_code=True,
)

splitter = SemanticSplitterNodeParser(
    buffer_size=1, breakpoint_percentile_threshold=95, embed_model=embeddings
)

# also baseline splitter
base_splitter = SentenceSplitter(chunk_size=256)

nodes = splitter.get_nodes_from_documents(documents)
# Out:
# Setting up the embeddings model...

# %%
from collections import defaultdict

# Group nodes by datePublished
date_groups = defaultdict(list)

# Loop through all nodes and group them by datePublished
for node in nodes:
    date_published = node.metadata["headline"]  # Assuming it's always present
    date_groups[date_published].append(node)

# Print chunks grouped by datePublished
for date, group in date_groups.items():
    print(f"Head: {date}\n")
    for i, node in enumerate(group):
        print(f"Chunk {i+1}:")
        print("Text:")
        print(node.text)
        print("------------------")
    print("\n")  # Extra space between groups
# Out:
# Head: simplii the ghost bank
#
# Chunk 1:
# Text:
# ... this so called bank is a joke... customer service is nonexistent  when trying to get answers they simply disappear... just let me close my account!...thumbs down...
# ------------------
#
#
# Head:  is a toy bank.
#
# Chunk 1:
# Text:
# is a toy bank.Its not a serious institution in any way. You can keep there a couple hundred dollars on groceries but thats about it. For starters, limit 500 per transaction.
# ------------------
# Chunk 2:
# Text:
# I went to pay for my insurance and it just refused to work because the bill was about 1000. Quite inconvenient.Even worse, there is 200 daily withdrawal limit with no possibilities of increasing it more. Thats insane! So, if you need cash, you cannot retrieve it from there unless you go to the local  for multiple days in a row.That said, it could work okay if maybe you dont earn very much, or are looking for a secondary bank. Some people have accounts in more than two banks, that can be convenient my main one is mostly for savings and expensive purchases while  one is more for general shopping  groceries, , bills for phone and internet. In terms of online purchases,  is winning over  which, unfortunately, does not work with majority of online marketplaces. Also,  is very active in pushing transgender propaganda on all its clients while  is more respectful in its approach.Im giving  25. There is a lot of room to grow. Wouldnt recommend to anyone who is looking for a bank to hold more than a thousand dollars in the account.
# ------------------
#
#
# Head: Less Than Stellar.
#
# Chunk 1:
# Text:
# made a large payment on my  account to   credit card. Over 2000. The web server was slow and the payment timed out saying incomplete transaction try again later. I dis so and payment transacted as normal.
# ------------------
# Chunk 2:
# Text:
# But the first payment was also credited resulting in my account being in the red. Phone  they showed me how to reverse one payment. Did that felt ok with it. Days later my acct is overdue and no payment recieved by capital one. Phones  got the run around. Said the issue was sent to the back office for consideration. They keep saying it will be resolved but end of March now and my 2000 dollars is lost out there in the ether. My account is missing the money and  remains unpaid. I hv incurred credit charges and still have no action by  to fix it. Find the negative reviews very troubling. As a senior living o. Pensions my account is compromised. Will surely be going to another bank ASAP.
# ------------------
#
#
# Head:  is the worst bank I have ever
#
# Chunk 1:
# Text:
# is the worst bank I have ever experienced and I do NOT recommend it. I have just opened both my chequing and savings account this month, August 15, 2019 and I am closing it. It is one problem after another and I felt trapped, could not get my money out to do etransfer for rent because either the online banking is on maintenance or the registration could not work, so I had to telephone a rep as advised on its online web. Not only is the telephone service extremely poor with almost 2 hours of waiting time on August 30, 2019 I tried to put my number for a call back and waited 2 hours for the second time the  machine that swallowed my deposits of over 1,300 never gave me a receipt evidence of my putting money in. Now i am paying my rent late. Do not count on getting your money out in an emergency situation with  and do not rely on its etransfer service. There is always an issue.
# ------------------
# Chunk 2:
# Text:
# Avoid . Now I am paying late rent.
# ------------------
#
#
# Head:  is the best!
#
# Chunk 1:
# Text:
# has been absolutely amazing with our new mortgage. Ive used them since they opened and our most recent experience with mortgage specialist  has been seamless from start to finish. He was responsive to all our questions and worked very late on a Friday evening to ensure we met the conditions of our close.
# ------------------
# Chunk 2:
# Text:
# Absolutely recommend  for all banking needs!
# ------------------
#
#
# Head:  is a criminal
#
# Chunk 1:
# Text:
# is a criminal organization They are not a member of the  and they have no intention of dealing with any actual customer service issues their clients have. They deal with people who open accounts with them like prey.
# ------------------
# Chunk 2:
# Text:
# They are predators who take and give nothing in return
# ------------------
#
#
# Head:  is the worst
#
# Chunk 1:
# Text:
# is the worst bank to deal with. There customer service is horrible, they are rude and frankly they dont know much what happening there. after several bad call experiences I decided to close my account so on friday 9 octobre 2020 at 14h24 I called  and tlked to a manager whose name was  , firstly he wasnt a helpful person, secondly after asking me lots of security questions , when I asked him to close my acount and send me a confirmation email or document to be sure that my acount is closed , he told me that he couldnt provide that and inspite of my explanation he insisted that I hadnt open any acount with them, finally after 20 minutes talk he understood that I have an acount with them. When I asked him to transfer me to his superior he told me that there is no superior than him and I am not able to talk with any one eles.
# ------------------
# Chunk 2:
# Text:
# I highly recommend going else where the costomer service and managers are more helpful and friendly .simpliii is really waisting your time
# ------------------
# Chunk 3:
# Text:
# is the worst bank to deal with. There customer service is horrible, they are rude and frankly they dont know what the hell there doing there.
# ------------------
# Chunk 4:
# Text:
# I highly recommend going else where just so you dont get screwed over like I did.
# ------------------
#
#
# Head:  was very helpful
#
# Chunk 1:
# Text:
# was very informative, and patient.
# ------------------
# Chunk 2:
# Text:
# He made the process as stress free as possible. I have been with  for 30 years and I have been pleased with the service.
# ------------------
#
#
# Head:  locked my debit card two weeks
#
# Chunk 1:
# Text:
# locked my debit card two weeks ago as fraud prevention. Their verification text message sent to my phone kept responding with  information to my numerous attempts to respond. I have now been on hold for over seven hours waiting to speak to fraud prevention!!! No one ever answers my Calls !
# ------------------
# Chunk 2:
# Text:
# !!!! The customer service at  has gotten horrible. Take your business elsewhere like we are going to do if we can ever get a human to answer.
# ------------------
#
#
# Head: N/A
#
# Chunk 1:
# Text:
# Avoid at all Costs !
# ------------------
# Chunk 2:
# Text:
# ! Terrible Banking ! The Absolute Worst!!They Closed my checking account and other accounts because of too many email transfers, deposits and withdrawals. On top of that they are still holding my direct deposit for over 5500 for over a week now and also holding a direct deposit email transfer. I can not get a hold of anyone and constantly on hold when I call in for anywhere from 30 min to an hour only to finally talk to someone to only be transfer to someone else. Then finally only to be hung up on or transferred to another incompetent employee. DO NOT sign up with this company What is the point of having a bank account if I can not email transfer money, make deposits and take money out of the bank.I had direct deposit from my employer every 2 weeks for over 15 years and I sent a lot of email transfers and spent a lot of cash from withdrawing at bank machine. I was with  for over 15 years with absolutely no issues until  took over. once they closed all my accounts I immediately  over to  I wont mention any names just incase I have issues with them too  However so far way better service and not one single issue.
# ------------------
# Chunk 3:
# Text:
# was very helpful,respectful,and very professional.He provided all the information I needed ,thank you
# ------------------
# Chunk 4:
# Text:
# , the 400 bonus dont count for  payrolls but they wont tell you about this. Customer service is hard to reach.
# ------------------
# Chunk 5:
# Text:
# . Theyre incompetent and they take forever to give you an answer.
# ------------------
# Chunk 6:
# Text:
# Nobody is able to do anything. Because of these guys Im about to lose the money for a down payment just for a simple fix that I did with another bank in less than 5 mins.Once I get my draft, Ill close my account with  for good.
# ------------------
# Chunk 7:
# Text:
# 1 person can make a big difference in navigating all things mortgages and moving!  is my rep and he is excellent at what he does, personable, accountable and goes over and above to ensure you understand whats needed, whats happening and even after the fact checking in to ensure all went as planned.
# ------------------
# Chunk 8:
# Text:
# Cant go wrong with !
# ------------------
# Chunk 9:
# Text:
# Actually  has provided good friendly service to me for years, except today. I got email to call  relating to a problem l had with transfers. Spoke to  who was the worst customer service personnel ever.
# ------------------
# Chunk 10:
# Text:
# He was cold, no enthusiasm, poor attitude, and even hung up on me. I hope management can listen to the recording and judge accordingly. After being a loyal happy customer for years, this bad rotten apple spoilt it all.
# ------------------
# Chunk 11:
# Text:
# Banked with them for 15 years, as far back as them being  and today I closed my account. The customer service received was disgraceful and the stole 180 from me in bogus  fees, telling me they were warranted.
# ------------------
# Chunk 12:
# Text:
# I will NEVER bank with them again, and you shouldnt either.
# ------------------
# Chunk 13:
# Text:
# Banking side of it is fine, their credit card gives great cashback on bars and restaurants.The issue that is increasingly annoying me is the 2FA on the web version of their site. There is no way to mark your device as trusted or anything...you have to get sent a text message EVERY SINGLE TIME and this is putting me off using them more
# ------------------
# Chunk 14:
# Text:
# Couldnt even get an account or anything actually its a waste of your time dont bother junk bank
# ------------------
# Chunk 15:
# Text:
# Customer service on the phone is terrible. The wait time generally is close to one hour.
# ------------------
# Chunk 16:
# Text:
# For an online bank they operate about as efficiently as a brick and mortar operation from the 1970s. You cant open an external link without a stamped void cheque from the back room. And if you open a chequing account you need to mail in a copy of one of your utility bills. Fax is also an option cutting edge.
# ------------------
# Chunk 17:
# Text:
# Be prepared to be frustrated.
# ------------------
# Chunk 18:
# Text:
# Got on the phone and was told previously it was a simple process to update my ID on file to open an . Turns out I have to travel 30 minutes out of my way and take 45 minutes at the post office to get this done. Was offered email but they only accept 2 types of photo IDs and do not accept any of the IDs plus drivers license. They did offer after an hour to open one manually but told me I would have to go through this gruelling process everytime I wanted to open up an investment! So aggravating!
# ------------------
# Chunk 19:
# Text:
# So done! Switching banks and taking my family and friends with me.
# ------------------
# Chunk 20:
# Text:
# I am writing this review the commendable customer service provided by  She was very curious provided detail formation and very patiently answer my questions very happy with standard and quality of the service provided
# ------------------
# Chunk 21:
# Text:
# I have been with this bank over 20 years now and this year has been an absolute disaster. It used to be great, yet now its mismanaged and heading straight to the toilet. For an online bank, they sure dont seem to care much when it comes to supporting their app. I havent been able to sign in on my new android and its clearly a flaw in the app. I have spoken with multiple agents over the past 10 months who assure me it will be fixed yet no updates.
# ------------------
# Chunk 22:
# Text:
# The  browser isnt supported either. I will be changing banks .
# ------------------
# Chunk 23:
# Text:
# I would like to preface this by saying I have been banking with  financial for MANY years originally . In terms of general customer service, I have received friendly and helpful customer service agents. I am however, trying to proceed with a mortgage preapprovalapproval. I required an update to my financial details from my original preapproval, which involved a phone call to a mortgage representative. After being transferred from my mortgage broker to a customer service agent?, I received mediocre service which did not fulfill my needs I fail to see why I am unable to receive paperwork regarding my increased mortgage amount, or interest rates. As I am dealing with hundreds of thousands of dollars, I feel as though this would be logical I receive more updates when I order a ten dollar lunch.To follow up my aforementioned phone call, I emailed my mortgage broker to ask more questions, which I have yet to receive a response.
# ------------------
# Chunk 24:
# Text:
# It has been four business days. As a 28 year old first time home buyer, I must say, this experience has been abysmal. I am currently attempting to make an offer on a property, but am unable to do so confidently as I do not have an accurate preapproval.As a result of my experience and due to the fact it seems  does not take my finances seriously, I am now exploring alternative banking options and will be transferring ALL funds to a new bank.
# ------------------
# Chunk 25:
# Text:
# Just went through a separation, so went to refinance my mortgageit was the worst experience having to deal with these people they wanted me to pay off some credit that I had in my name and only way they would refinance my home if I took out a 15,000 dollar increaseand add to the price of my mortgage, l told them to stick it, they were going to increase my mortgage by 240 dollars a month and charge me 4.25 percent as they are part of cibc so I went into  AND SAID TO CLOSE ALL MY ACCOUNTS I will not be doing businesswith them anymore, said wait lets look into this and see why they are doing this came back to me and did not understand why so they bought out my mortgage and reduced my monthly payments by120 dollars per month from WHAT I was paying told them SIMPLII IS GIVING THEM A BAD NAME they are very dishonest they are not out to for my best interest they are out to screw there clients theres no WAY HELL WOULD I EVER RECOMMEND THEM TO MY WORST ENEMY
# ------------------
# Chunk 26:
# Text:
# Manager personally called me and addressed all my concerns!
# ------------------
# Chunk 27:
# Text:
# My husband and I were trying to get a Secured Line of Credit and the gentleman that we dealt with was . He was a very pleasant and very helpful gentleman in helping us decide on getting our Secured Line of Credit.
# ------------------
# Chunk 28:
# Text:
# He was very friendly and helpful.Thanks, , for all of your assistance with the matter we were trying to get.
# ------------------
# Chunk 29:
# Text:
# Parth 1  was extremely pleasant and helpful during my recent business interaction with .
# ------------------
# Chunk 30:
# Text:
# Put order in to transfer money out than I see upcoming transfer on the transfer day nothing happend. Call chat with them they have no clue that the order was in.
# ------------------
# Chunk 31:
# Text:
# so if you count on your money dont bank with them.
# ------------------
# Chunk 32:
# Text:
# Seems like a huge scam got a call from Indian number confirming my personal information which i have only provided to . Got the call after 3 to 4 days of a back and forth email fight
# ------------------
# Chunk 33:
# Text:
# Since [] has no physical contact with its customers, there should be no holds for bank drafts and certified cheques that are deposited on the []. These items are already guaranteed by the issuing banks and therefore, do not necessarily require clearance like the regular cheques do.
# ------------------
# Chunk 34:
# Text:
# This is my opinion and I hope [] will consider making changes.
# ------------------
# Chunk 35:
# Text:
# Tedious, tedious, tedious... cant even get started with this bank. I open an account, they send me a welcome kit, but they forget the bank card.
# ------------------
# Chunk 36:
# Text:
# Gotta wait at least a week to get started there but I think I wont bother. On another existing account, I cannot get the login and password from them to even start online banking they dropped the call which already took thirty minutes of waiting. When I ask for a statement of this account which I need for closing a mortgage, Im presented with so much red tape and back  forth BS that I want to pull my hair out and curse the fact that online banks even exist. I am sure it works for some people, but personally I am never using this bank again.
# ------------------
# Chunk 37:
# Text:
# They can not even check email. !
# ------------------
# Chunk 38:
# Text:
# We moved our banking accounts to  when they began.. I was just so frustrated with our banks endless fees and poor customer appreciation and service. When it changed to  I found things actually got better and I was already happy with . We still had our mortgage at our old bank and it was renewal time and I was not at all happy with the service I was getting so we moved our mortgage to . I was nervous about it being all onlineover the phoneemail but everything went smoothly and it was pretty stress free. So after a while we decided to move our SPs from our old bank to  as well. Our mortgage just renewed and we dealt with  to get started, he was awesome very helpful went over all our options answered my endless questions and always responded quickly. We were passed on to  who went over the final numbers a let us know all the steps that would be taken from here.
# ------------------
# Chunk 39:
# Text:
# was amazing, he responded to my emails in less than an hour, sometimes within minutes, never left me hanging waiting for an answer. Things didnt go quite as planned but only due to recent job changes on our end that they werent aware of when we started. I was getting nervous that things would not get done in time but  was always calm and reassuring. It did get done in time and my stress level was much lower than it could have been so thanks  and  for making this process so easy and for you constant quick attention, it really was greatly appreciated!
# ------------------
#
#
# Head: Great Experience with a Simplii Mortgage Expert
#
# Chunk 1:
# Text:
# is a great asset to . Very helpful and empathic while maintaining his professionalism. helped me not once but twice in one month to change my mortgage.He was always available to listen and if he was not available right away he always called me back the same day. Great experience with !!! Thank you !
# ------------------
# Chunk 2:
# Text:
# ! Also, it has been a very good experience with the whole  team..Thank you
# ------------------
#
#
# Head: excellent
#
# Chunk 1:
# Text:
# support specialist from  financial helped me in changing the Title transfer of my home, though it took more time than anticipated to get documents in place  is patient and timely followed up with me in regards to documents required for them to complete the process. I recommend  finance to my family and friends when needed.
# ------------------
#
#
# Head:  was extremely helpful in
#
# Chunk 1:
# Text:
# was extremely helpful in getting my secured line of credit set up. I have been a  customer for several years and would recommend the bank and services they offer to anyone
# ------------------
#
#
# Head: Terrible and leaving
#
# Chunk 1:
# Text:
# has gone down the drain since it was rebranded from . The website and app are constantly broken and I can never get my banking done in the time frame that I need. Tried to call them today about an issue on  etransfers and I was hung up on. Im transferring my money and moving elsewhere.
# ------------------
# Chunk 2:
# Text:
# Absolutely ridiculous. Just because you are low fees doesnt give you an excuse to provide crap service. Id rather pay the fees.
# ------------------
#
#
# Head: 0 values, morals, work ethic  Trash
#
# Chunk 1:
# Text:
# is not responsible for fraudsThey wont transfer you to fraud quickly people are not trained. Once you get someone after 1 hour , they will tell you what you want to hear and then change their mind, at the end of the day, the loss will be yours 100 except on credit cards since they can reverse it lets be fair unlike them, they will never take responsibility for anything that costs money. Also, they will tell you that you will get an answer within x days and you will be totally ghosted. The customer service wait time is a joke.
# ------------------
# Chunk 2:
# Text:
# This bank is trash and even saying that is not fair to trash. If there was a stock for , I wouldnt buy it for a penny.
# ------------------
#
#
# Head: mortgage renewal and move from another institution
#
# Chunk 1:
# Text:
# representative was clear in her instructions to help us move our mortgage, she was quick to respond to any questions we had and we are very happy with the service she provided... we would be happy to recommend simplii as a banking alternative
# ------------------
#
#
# Head: Mortgage Renewal
#
# Chunk 1:
# Text:
# was very helpful with our concerns.
# ------------------
# Chunk 2:
# Text:
# He contacted me very quickly after I left a message and everything was clearly explained and courteously taken care of. I am more than happy with his service and help.
# ------------------
# Chunk 3:
# Text:
# I renewed my Mortgage and had a great experience with  my Mortgage Specialist.  was very helpful with my mortgage needs. He was very professional, thorough and well organized.
# ------------------
# Chunk 4:
# Text:
# The process was seamless with no issues. This was the 2nd renewal I had done with , and it was a breeze like the 1st. Thanks so much, ! I would highly recommend working with  for your mortgage needs. I know I will be in the future.
# ------------------
#
#
# Head: 5 stars
#
# Chunk 1:
# Text:
# was excellent she answered all my questions and was very pleasant. Thank you
# ------------------
#
#
# Head:  HORRIBLE
#
# Chunk 1:
# Text:
# ABSOLUTELY HORRIBLE PRODUCT ! THEY SENT THE GIFT CARD WITHOUT  AND  AND THE PERSON CANNOT VIEW AND RECEIVE IT !!!!
# ------------------
# Chunk 2:
# Text:
# AFTER CALLING TO CUSTOMER SERVICE AND TALKING FOR 30 MINS NO HELP PROVIDED !!!!!! PROMISED TO PROVIDE THE HELP WITHIN 48 HOURS !!!! ABSOLUTELY DISGUSTING !
# ------------------
#
#
# Head: Huge disappointment
#
# Chunk 1:
# Text:
# advertised an attractive 6  interest rate for 150 days, so I opened an account. I had to wait for them to send a card, then a paper to sign and for a chance to call them. Finally all was set up to transfer funds from another bank, but it was 32 days from first contact, and promo interest was now NOT available!!  reconsidered, then said NO.
# ------------------
# Chunk 2:
# Text:
# HUGE DISAPPOINTMENT!
# ------------------
#
#
# Head:  and  working together,  rippoff
#
# Chunk 1:
# Text:
# and  working together, so even your Mortgage is with  the bank in behind is , spending million in advertising, but for missing 4.13 they charge you twice for .  45.00 and  again.In that case I can only say we need much more Covid19, maybe we cab stop the greediness.So if you like to get your Mortgage go better to  or , but not by that organization.Sorry the Evaluation is far to high with one Star, it should be  5 Stars. Sorry is not available.
# ------------------
# Chunk 2:
# Text:
# So in the future make sure what ever bank you go that  is not shareholder.
# ------------------
#
#
# Head:  bank in the world
#
# Chunk 1:
# Text:
# bank in the world. I have had so many problems with this bank.. trust me the no banking fees are not worth it.
# ------------------
#
#
# Head: Worst digital bank to deal with!!
#
# Chunk 1:
# Text:
# bank to deal with. They froze my bank account  each day is another excuse why I cant have my funds back. Higher management doesnt care about customers. They lie everyday with more excuses!!. Theyre unprofessional. Dont tell the truth about anything I ask them.
# ------------------
# Chunk 2:
# Text:
# Dont return phone calls. Ive been waiting for paperwork from them for 6 weeks to get my account back. But they wont even send me the documents l need to sign  Im still waiting!! Because theyre a digital bank theres no tellers!! That really sucks when you need to do something in person face to face. You cant do that with Simplii financial. Theyre no humans except for the call center  they always tell you to go to  with All your lD to verify you before they will send you a bank card. If youve card is ever lost or stolen, thats a really big hassle in itself to go to  again each time. Then everything is done my snail mail at .Still never did get paperwork on time. They dont care about customers at all. VERY rude managements who dont know their Job  cant explain what takes so Long to get simple answers from them!! Their security is off the charts. You have to go to  to be verified each  every time!! Nobody cares or wants to help!! They were a good bank when they were PC financial. They had booths in Zehrs  .
# ------------------
# Chunk 3:
# Text:
# It was great then!! But not now!
# ------------------
#
#
# Head:  bank
#
# Chunk 1:
# Text:
# bank, I was try to apply a new account, it then asked me to email two IDs photos in email. I did, then they sent me another email asked to email back 3 IDs, what a jokeDate of Birth on ID doesnt match application information Please provide all three acceptable IDs.This is unacceptable and very unprofessional, so everyone please be aware .
# ------------------
# Chunk 2:
# Text:
# bank. 1 month hold on cheques from major US company. 1 month. Just not like the other major banks.
# ------------------
# Chunk 3:
# Text:
# Its inconvenient dealing with them tbh. I will be closing all accounts etc.
# ------------------
# Chunk 4:
# Text:
# bank. Have had so many issues with them from not being able to use my card, spend my money, my account was overdrawn for a week. Got paid today Thursday since tomorrow is the holiday and couldnt e transfer or use my funds at all. Called and they blocked ny account since it was overdrawn for a week. They didnt call me or email me at all to discuss why i was overdrawn or anthing. Just straight to blocking my account. They said I have to wait a whole business day before I can Unblock my account cause they said it could go negative again. People have bills to pay.
# ------------------
# Chunk 5:
# Text:
# The money is clearly there yet I cant use it. I will be closing my account after this.
# ------------------
#
#
# Head:  customer
#
# Chunk 1:
# Text:
# customer service
# ------------------
#
#
# Head:  ever
#
# Chunk 1:
# Text:
# ever, will not recommend this bank to anyone especially international students. They have an international student line to help students with their  accounts but I have been calling on this line multiple it keeps on disconnecting.
# ------------------
# Chunk 2:
# Text:
# And when the line connects the representative on the other side are so unprofessional, she kept me on hold and then disconnected, I experienced the same thing 3 times in a row, this is just unacceptable.For all the students coming to Canada please dont choose  for your  account as they have the worst customer service.
# ------------------
#
#
# Head:  ever.They tell me a cheque
#
# Chunk 1:
# Text:
# ever.They tell me a cheque that I deposited in my account was counterfeit but they wont show me a copy of cheque.The company the cheque was from has been in business for 18 years and has never had a problem like this before.Then they closed my account keeping the 2,200 cheque.
# ------------------
#
#
# Head:  financial is a great bank ifyou are on disability
#
# Chunk 1:
# Text:
# financial is a great bank if your on a low income bracket like myself. Its free of charge and they give you free cheques. Today I was charged a  fee of 45 for accidentally not having enough money in my account.
# ------------------
# Chunk 2:
# Text:
# I called an explained my situation and they reversed the fees with no issues. I highly recommend them, great bank.
# ------------------
#
#
# Head: Simplii financial is the worst
#
# Chunk 1:
# Text:
# financial is probably the worst bank in Canada. On January 10th someone took 1000 from my account and than on January 20th they took 500 . I called simplii and reported it for fraud, Today February 4th they called me and said there will be no refund for the money that was taken. They told me there is nothing they can do and I should just open an investigation with my local police.
# ------------------
# Chunk 2:
# Text:
# After a few years of being with them now I can see that why dont really care about there customers and they dont really care about peoples money or anything like that. They are a waste of time, and now because of them not being able to help me I have to do a report that could take over a year. They in my eyes are the worst bank in Canada
# ------------------
#
#
# Head:  got simplii cuz of
#
# Chunk 1:
# Text:
# got simplii cuz of their 2 interest rate.
# ------------------
# Chunk 2:
# Text:
# Once the month is over I will still get .01  upon calling they told me 2 interest will be given once the promotion is over after 4 months. of this information given prior signing up.Very disappointed folks
# ------------------
#
#
# Head: Simplii Paid my bill twice, and now I HAVE TO WAIT FOR MY MONEY BACK
#
# Chunk 1:
# Text:
# has been having technical issues with my online banking for the past 6 days . At least to my knowledge. I have been chasing them for the past 4 days to correct my online banking, and I have gotten no where other than we are looking into this. I even let them know that I am worried as their whole system was hacked not too long ago, and my card was compromised.  paid my bill twice when I DID NOT PAY IT twice. I have screen shots proving that they are having technical issues. I have even been on the phone with several representatives who have seen the issues happen on my online banking LIVE. The rep added a bill and the other one erased, and vice versa. They agreed that the issue was on their end, and here i am STUCK just waiting for an answer. Not only that, one rep said a manager will call me and they never did. I finally spoke to one who said the same  as the reps on the phone. What i DO NOT get is I have proof of an error made on s PART, I have asked that they take this on an urgent basis as I need to pay the bill i  paid, to not  late fees. They will NOT take this on urgently, and have told me to wait 5 business days. THEY DO NOT have a plan on who will be cover a late payment, nothing  this is absolutely AURD! ANYONE READING THIS.
# ------------------
# Chunk 2:
# Text:
# THIS IS A SECURITY ALERT TO ALL OF YOU! YOUR INFORMATION IS NOT SAFE WITH THEM, they will NOT protect your information by any means. IT IS YOUR JOB to continue to chase them to make sure that YOUR information is in good order. You pay no fees, HENCE WHY you get NO CUSTOMER SERVICE!
# ------------------
#
#
# Head: STAY AWAY with them if you CAN!
#
# Chunk 1:
# Text:
# has screwed me over for so many time since I opened an account with them. First they sold my personal information to a third party called fairstone lending company. I can confirmed that it is really them because I used my maiden name on all my bank accounts records and all the billings except for when I opened my account in simplii, I used my married name for the very first time. Couple months later after my account has been opened, this fairstone lending company has been sending me mails offering a loan using my married name that I only used with Simplii! So unrealiable company right there.
# ------------------
# Chunk 2:
# Text:
# CANT BE TRUSTED for sure. Thats not the only problem that I encountered with them, they also lied to me so many times and it comes to the point that Ive just had enough thats why Im writing this review.
# ------------------
#
#
# Head: !!
#
# Chunk 1:
# Text:
# have been with PC banking  Simplii for approximately 23 yrs. I have never experienced any problems with this bank. Agents are polite and very helpful. I highly recommend.
# ------------------
# Chunk 2:
# Text:
# No fees. If you use checks there is no charge for them. They do charge  fees but none other that Ive experienced.
# ------------------
#
#
# Head:  have lost their minds
#
# Chunk 1:
# Text:
# have lost their minds coming out with a horrible fluorescent pink and green site and card and new motos that make no sense. After more than 15 years of banking with them I no longer trust this bank and working to close my account ASAP.
# ------------------
#
#
# Head:  is a great asset to
#
# Chunk 1:
# Text:
# is a great asset to  team He was very helpful being prompt, courteous and willing and able to answer all our questions. I just want to congrulate once again for the terrific job, we are forever humble and grateful for his service! We will certainly recommend you guys to anyone I know in the market for a mortgage.. Thank You soo much once again for the terrific job, we are forever humble and grateful for your service, It was a worry free experience as you walked us effortlessly through the transaction and always had an answer for our questions. We will not hesitate in recommending you to our family and friends when they need to renew their mortgage.
# ------------------
# Chunk 2:
# Text:
# We will be sure to call on you again
# ------------------
#
#
# Head:  is a joke
#
# Chunk 1:
# Text:
# is a joke Had to make 3 calls and each one gives a different answer. Consistently on hold, talk for 30 secs than 10 min hold I canceled
# ------------------
#
#
# Head:  is a shi.t bank
#
# Chunk 1:
# Text:
# is a shi.t bank. To get someone on the phone it takes more than 50 minutes. Waste pf time.
# ------------------
# Chunk 2:
# Text:
# Hopeless customer services. PC financial was way better than this shit bank .
# ------------------
#
#
# Head:  is awesome,from the very
#
# Chunk 1:
# Text:
# is awesome,from the very start till we finished the transaction,and all paper works,and got approve,tnx..
# ------------------
#
#
# Head:  IS SHI.T
#
# Chunk 1:
# Text:
# IS SHI.T , its not actually simplii, its shittiiii, worst bank ever and never answers phones
# ------------------
#
#
# Head:  is the best than ever from your
#
# Chunk 1:
# Text:
# is the best than ever from your bank so really to her and want raise his rank and salary because she is exellent in understanding and describing everything.
# ------------------
#
#
# Head:  is very Nice and Friendly
#
# Chunk 1:
# Text:
# is very Nice and Friendly, Polite and explained clearly,
# ------------------
#
#
# Head:  made it fast and easy to renew
#
# Chunk 1:
# Text:
# made it fast and easy to renew our mortgage rate in order to beat the BOCs hike on March 2nd. The service was fast, prompt, and clear.Thank you so much for all your help!
# ------------------
#
#
# Head:   worst customer service in the world
#
# Chunk 1:
# Text:
# should be a synonym for the worst customer service in the world. Their employee do not know what and how to write an email.
# ------------------
# Chunk 2:
# Text:
# They will write the same thing whether your query is  or XYZ. They make fake promises to the customers that the issue will be resolved and then they do nothing for 10 days, even after followups.
# ------------------
#
#
# Head: Simplii Terribly long wait times for
#
# Chunk 1:
# Text:
# Terribly long wait times for anything. All banking issues  have to be dealt with through the phone and they  dont pick up.  terrible. I am writing as many bad reviews as I can find places to put them while I wait for them to answer the phone. If I cant give them heck for making me wait for hours, Ill let them know this way. Dont bother.
# ------------------
# Chunk 2:
# Text:
# Find a bricks and mortar bank.
# ------------------
#
#
# Head:  walked me through the
#
# Chunk 1:
# Text:
# walked me through the mortgage process and was in constant contact during that time. If she could not immediately answer my questions, she quickly researched and got back to me within 24 hours. Amazing service!!!
# ------------------
# Chunk 2:
# Text:
# Thanks !
# ------------------
#
#
# Head:  was very polite
#
# Chunk 1:
# Text:
# was very polite, dealr efficiently with my issueThanks
# ------------------
#
#
# Head:  and !
#
# Chunk 1:
# Text:
# ecently got a mortgage with  and  went above and beyond multiple times to help me through the transaction.
# ------------------
# Chunk 2:
# Text:
# She proactively and effectively communicated and worked tirelessly to complete my mortgage in time. If you need an exceptional , call  x8907
# ------------------
#
#
# Head: Simply took my government check for
#
# Chunk 1:
# Text:
# mply took my government check for 47,000 dollars and wont cash it or send it back. I have a large amount collecting interest on their line of credit while they hold me hostage. This is the most corrupt institution I have ever dealt with. Avoid them at all costs. There are real banks out there who will be happy to have your business.
# ------------------
# Chunk 2:
# Text:
# Try . Its a much better bank than mply.
# ------------------
#
#
# Head: 1 is the lowest rating I could give
#
# Chunk 1:
# Text:
# 1 is the lowest rating I could give here unfortunately. Absolutely pathetic service.
# ------------------
# Chunk 2:
# Text:
# I signed up and never received a card. I phone them twice any card and everytime they told me the card is on the way. Its been 3 months and havent received anything yet.
# ------------------
#
#
# Head: Simplii simply sucks
#
# Chunk 1:
# Text:
# 15 Days ago I deposited my work cheque with  without being told I would have to undergo some extensive verifications to access my money, let me open the account and then froze my money instantly by locking all means of moving my funds, now telling me I need 2 government photo ids to verify, but the government of Canada says I only need 1! Guess simplii writes the laws here in Canada now. Sent in 3 paystubs 2 identifications, 2 t4 slips and 2 bank account statements from different banks and still they are not letting me get my funds, havent even been able to pay my rent because of this either. I think simplii should be financially compensating me a little here, or is that 2 much to ask?
# ------------------
# Chunk 2:
# Text:
# 20 days now
# ------------------
#
#
# Head: 5 stars for
#
# Chunk 1:
# Text:
# 5 stars for .
# ------------------
# Chunk 2:
# Text:
# Very professional , knowledgeable and extreemly helpful. I did not have to ask for anything and she provided an amazing client experience and truly made my day. You should have more like her 100 ...thank you much for all your help and offering such amazing service. Above and beyond in my book
# ------------------
#
#
# Head: 500 in  FEES IN 1 WEEK.
#
# Chunk 1:
# Text:
# 500 in  FEES IN 1 WEEK.Sorry, I meant 16 weeks. During a pandemic and I have been with them for six years. Wont be seven.
# ------------------
# Chunk 2:
# Text:
# Lol
# ------------------
#
#
# Head: 6 you cant go wrong
#
# Chunk 1:
# Text:
# 6 you cant go wrong.
# ------------------
# Chunk 2:
# Text:
# costumer service was good. I didnt use a promo code and missed out on the free 50.Dont forget to join with a link to get the bonus 50.  6Dfjmv
# ------------------
#
#
# Head: Paid 36 000 in taxes I wasnt supposed to pay
#
# Chunk 1:
# Text:
# A bank rep mistakenly filed the wrong form or checked the wrong item on the form, which resulted in me paying roughly 36 000 in taxes I wasnt supposed to pay. Its been 5 months and nothing is done to fix that.
# ------------------
# Chunk 2:
# Text:
# I cannot contact the   they seem to be closed for quarantine. Interestingly, the bank itself doesnt seem to have a web page for complaints.
# ------------------
#
#
# Head: Routine inquiry twisted into an OBJECTION!
#
# Chunk 1:
# Text:
# A followup call to their customer care center regarding a bank draft I ordered turned into being transferred to a  who was hesitant to issue the draft based on a large cheque deposit from approximately a week or more ago. The cheque had passed the usual clearinghold time and it was from a reputable large company, not at all a personal cheque or from a small business. It was rather upsetting as I had complete access to all my funds if I wanted to go shopping or gamble them away at a O...but I was being treated as if I was trying to orchestrate a scam over a request for a bank draft. To make it worse the  turned it all around twisting it  she told me that I was placing a complaint and all complaints are recorded and subject to review and that they HAD THE IGHT to record... The only reason I was calling was to find out an  on the bank draft. The  all on her own turned it into some of the poorest service I think Ive had in a very long time. When I called in I was perfectly fine and by the end of the call I was so frustrated I made the decision to cancel the draft. Then when I said I want to cancel and will get the draft through my other bank.. then she went into salvage mode to try to get the draft prepared. It sounds absurd... this was one of the oddest and worst customer service experiences.
# ------------------
# Chunk 2:
# Text:
# I dont take it lightly writing negative reviews... this seriously left my head spinning, and is beyond what common sense should guide an employee to say out loud to a client. Combined this with hit or miss loan withdrawal dates not in real time, bill payments lagging up to 4 days, 2 days for a bank draft... My thoughts are to utilize a real bank for everydayprimary needs.
# ------------------
#
#
# Head: A terrible bank
#
# Chunk 1:
# Text:
# A lowlife, deceitful organization that does not care about facts. They cater to their low needs and disguise it as professionalism.
# ------------------
# Chunk 2:
# Text:
# Definitely see a more reputable bank, , maybe.
# ------------------
# Chunk 3:
# Text:
# A terrible bank, I had to change my phone number. They made me return to the branch 20 minutes from home. The next day my card would not return from the atm. Another hour on the phone.
# ------------------
# Chunk 4:
# Text:
# They are a awful bank.
# ------------------
#
#
# Head: Absolute bullsht bank
#
# Chunk 1:
# Text:
# Absolute bullsht bank. Been trying for 3 weeks to open their high interest savings account and to put money into it. There is always some kind of screw up.
# ------------------
# Chunk 2:
# Text:
# Its impossible to navigate this cluster  of an institutionbut they do have the coolest looking debit cards I have ever seen
# ------------------
#
#
# Head: Absolute garbage
#
# Chunk 1:
# Text:
# Absolute garbage, applied for a debit card got approved and they said they were sending it out over a week ago. Tried to get in touch with the customer support, they dont let you talk to a real rep without a debit or credit card number.
# ------------------
# Chunk 2:
# Text:
# What if I lost my card how would this work? Way worse than cibc garbage interface
# ------------------
#
#
# Head: Absolute incompetence
#
# Chunk 1:
# Text:
# Absolute incompetence, incapable of providing any customer service at all and nothing but excuses after excuses !! you are better off dealing with anyone else then these people !!
# ------------------
# Chunk 2:
# Text:
# Complete waste of time !!
# ------------------
#
#
# Head: Absolute nonsense
#
# Chunk 1:
# Text:
# Absolute nonsense.
# ------------------
# Chunk 2:
# Text:
# Better off keeping your money in a piggy bank! I just opened a new account and as per their policy, I have a daily withdrawal limit of 200 for the first SIX MONTHS!! Even after that the  withdrawal is 1000 a day. They  is just trying to make as much money off of your money as humanly possible. I do not recommend this financial institution at all.
# ------------------
#
#
# Head: Absolute worst bank I have ever dealt
#
# Chunk 1:
# Text:
# Absolute worst bank I have ever dealt with. I have been banking with  since the switch over from  but my experiences over the past year with this bank have been terrible. Extremely long hold times, very poor customer service, a terrible system all around.
# ------------------
# Chunk 2:
# Text:
# Too many problems with them to get into on this review but felt the need to warn anyone thinking about using them.
# ------------------
#
#
# Head: absolute WORST bank you could choose
#
# Chunk 1:
# Text:
# absolute WORST bank you could choose. they have what seems to be students working the phones and customer service and know absolutely nothing about the company or how to help. they sent me broken debit cards that dont work and refused to even be slightly helpful and said it must be my pin.
# ------------------
# Chunk 2:
# Text:
# ive done all they said and still nothing so at this point im changing banks. absolutely useless, do not join this bank no matter what.
# ------------------
#
#
# Head: Absolutely atrocious!!!!!!!!!!
#
# Chunk 1:
# Text:
# Absolutely atrocious!!!!!!!!!!Do not ever go with this bank their customer service is the worst out there I am appalled, waited 8 days for a cheque to clear from work countless hours on the phone and then passed yet again to another department. Dont sign up no matter what!!!!!
# ------------------
# Chunk 2:
# Text:
# !
# ------------------
#
#
# Head: Absolutely awful service
#
# Chunk 1:
# Text:
# Absolutely awful service. I sent a money transfer 10 days ago and havent gotten anything. On top of that they have no idea where my money is.
# ------------------
# Chunk 2:
# Text:
# Says I will have to wait upto 21 days to get an answer, which is absolutely ridiculous. Will be switching banks as this is unacceptable service.
# ------------------
#
#
# Head: Absolutely brutal customer service.They
#
# Chunk 1:
# Text:
# Absolutely brutal customer service.They will NOT listen.I was a good customer for years, but when my wife deposited a baby bonus cheque endorsed to her by my son,  locked up my bank accounts for 2 weeks and counting! My son cannot buy food for his children.
# ------------------
# Chunk 2:
# Text:
# Avoid this bank like this plague.
# ------------------
#
#
# Head: Absolutely fantastic service
#
# Chunk 1:
# Text:
# Absolutely fantastic service. Had a cheque issue and they fixed in a timely manner.
# ------------------
# Chunk 2:
# Text:
# Thanks !
# ------------------
#
#
# Head: Absolutely horrible
#
# Chunk 1:
# Text:
# Absolutely horrible!
# ------------------
# Chunk 2:
# Text:
# Do not bank with them. They held my check back, would not clear it even though it was exactly the same as other checks I was depositing twice a month for the past 10 months and had no issues with any of them. They did not call or email me, or notify me in anyway that they were holding my check hostage. When my mortgage came out and left our account empty I had to call them to find out why the check was held back. Turns out they will not accept checks made out to our small business of 1 person anymore. They hadnt noticed for 10 months, but suddenly its the end of the world if they cash them. Our business is 1 person, it is not incorporated, but they refuse to allow us to cash these small checks to our account. They said it must be a business account....which they do not offer. So I have to change banks. Wow, what a nice way to say you dont care about keeping my business at all. mplii does not support or care about small businesses at all. We now have to go to another bank, pay huge business account fees, and now pay all our bills from another bank. mplii wouldnt allow us to endorse our checks either, nothing with our business name on it, even if it has our own personal name on it as well. No options whatsoever to continue depositing our income with them. They are absolutely horrible and very difficult to deal with, and wont notify you of anything, you will have to watch your account like a hawk, they want to steal from you every chance they get. I have been banking with them and back when they were pc for the past 20 years and this is how I am treated! I will be closing my accounts asap and never banking with them again.
# ------------------
#
#
# Head: Absolutely infuriating company
#
# Chunk 1:
# Text:
# Absolutely infuriating company. If you ever need to do things quickly, dont use this company.
# ------------------
# Chunk 2:
# Text:
# ...
# ------------------
#
#
# Head: Worse bank ever!
#
# Chunk 1:
# Text:
# Worse bank ever! You put your money there and the give you tons of trouble to withdraw your own money! Like you have to wait 6 months on increase your 200 withdrawal limit. They suggested me to E transfer to someone else so they can withdraw the funds for me !
# ------------------
# Chunk 2:
# Text:
# ! What kind if bank this is ?Would not recommend at all.
# ------------------
#
#
# Head: Worst bank EVER!!
#
# Chunk 1:
# Text:
# Worst bank EVER!! Long storyshort This bank closed my autistic sons bank account without warning!!! Discrimination against special meeds customers that are on ODSP. After waiting all month for his ODSP income the bank waits for his cheque to be deposited them decides to close his account leaving him with no money, when I called the bank they said they would send a cheque in the mail. No compassion or customer care for clients with disabilities.
# ------------------
# Chunk 2:
# Text:
# Simpli trash should be the slogan.
# ------------------
#
#
# Head: Worst bank ever!!
#
# Chunk 1:
# Text:
# Worst bank ever!!! I deposited a check with my married name on it but my account is under my maiden name. They requested I change my name which I then provided all the info and changed it so they could release the cheque I deposited then only to be told later once the name change was done that my certified check will be hold for another 13 business days. They lied to me from the very beginning. It would have been way faster to get the check back by mail and deposit it at another bank.  learned and Ill be changing bank to a real one! Shame on you simplii!!
# ------------------
# Chunk 2:
# Text:
# !
# ------------------
#
#
# Head: Worst bank
#
# Chunk 1:
# Text:
# Worst bank EVER. Been banking with themFor 8  years, decided to hold a cheque and have been fighting with them for 7 days now  they also helpMy  FOR NO REASON
# ------------------
#
#
# Head: worst banking experience ever!
#
# Chunk 1:
# Text:
# worst banking experience ever!
# ------------------
#
#
# Head: Worst banking experience of my live
#
# Chunk 1:
# Text:
# Worst banking experience of my lifeIt took me 4 weeks to get my account set up. The people working at the phone are very bad at their job and cant assists you at all. I got the Mail of account verification 3 ! times.
# ------------------
# Chunk 2:
# Text:
# Each time 5  7 days in between. They ask you to upload a selfie, but the whole software doesnt work.
# ------------------
#
#
# Head: Worst banking experience
#
# Chunk 1:
# Text:
# Worst banking experience. I tried to contact the centre to ask for assistance but they instead freeze the account.
# ------------------
# Chunk 2:
# Text:
# They informed me that I am not authorized to use the account because this is only for my wifes single account. We already applied for the joint account 2 years ago and had some transactions for the past months using this account that it went through. After they talked to my wife, they still freeze the account even after begging them not to freeze it. We have our payment dues this week and have to pay for additional fees because of this.Worst customer service ever!
# ------------------
#
#
# Head: WORST CUSTOMER SERVICE IN THE WORLD
#
# Chunk 1:
# Text:
# WORST CUSTOMER SERVICE IN THE WORLD  I HAVE BEEN TRYING TO CONTACT THEM FOR A MONTH VIA PHONE AND IT MAKES NO DIFFERENCE WHAT TIME OF THE DAY OR NIGHT YOU CALL, YOU GET THE SAME MESSAGE THAT THEY ARE EXPERIENCING A HEAVIER THAN USUAL CALL VOLUME  THE RECORDING SAYS THAT YOUR CALL IS IMPORTANT BUT THE FACT THAT NO ONE EVER ANSWERS ILLUSTRATES THE FACT THAT THEY COULD CARE LESS  IF YOU ARE THINKING ABOUT OPENING AN ACCOUNT WITH  AND FRUSTRATION.
# ------------------
#
#
# Head: worst experience ever
#
# Chunk 1:
# Text:
# worst experience ever. Closed all my accounts the minute I could. Stay away!
# ------------------
# Chunk 2:
# Text:
# !
# ------------------
#
#
# Head: Worst experience I applied for credit
#
# Chunk 1:
# Text:
# Worst experience I applied for credit card and it has been 2 month still when I called, I got the answer it is under the process.
# ------------------
#
#
# Head: Worst experience I was waiting on call
#
# Chunk 1:
# Text:
# Worst experience I was waiting on call for almost an hour no one connected and there are so many duplicate amount deductions on visa card if simplii financial account.and no agent will connect on call to communicate about it.please kindly dont take simplii financial from my account 150 cad has been deducted from my account in the name of insta card and berEATS names which are dublicate orders
# ------------------
#
#
# Head: Worst service
#
# Chunk 1:
# Text:
# Worst service possible. Do not use , I opened my  account with , I received my Debit card in a month after landing in Canada, its the third month and I am still waiting for my  card. No responses to emails and an hour long waiting if you want to talk to the customer representative. It is tough when you rely only on  money to survive and you do not even have that.
# ------------------
# Chunk 2:
# Text:
# I do not recommend anyone to choose , save your time and efforts and choose  or .
# ------------------
# Chunk 3:
# Text:
# Worst service. Never use  for .
# ------------------
# Chunk 4:
# Text:
# They will take ages to resolve a issue.
# ------------------
#
#
# Head: Would give a minus 5 if I could worst
#
# Chunk 1:
# Text:
# Would give a minus 5 if I could worst customer service experience and truly a  started on Thanksgiving day when I called to increase  withdrawal limit to get some urgently needed cash.They found that my husbands previous place of work had used a part of his name we have long names for automatic payroll deposits. By the way it had happened for 12 years they only noticed it as hes in a new company now and their payroll had used parts from the previous and one more name.
# ------------------
# Chunk 2:
# Text:
# Simplii is saying that we are using someone elses money for 12 years and they need to protect their bank and this third person. The simple fact that both these are the same person with the same  no is of no use to them. My mortgage and other pre authorized paymets go from this account when asked they say they cant do anything about it. Its being 4 days and when called the contact center supervisors wont allow it to go beyond them and said if you were driving at 60kmhr on a 50km zone and get a ticket 10 years later its still valid. I told him my car is not impunded.this is you guys blocking our whole livelihood. Too bad was the attitude as they didnt care. They are treating us like criminals. Simply cos my husband have lots of parts in his legal name. There is no customer service nor any ethics or humanity in their dealings.I am shocked beyond words for the treatment and treating us as criminals.
# ------------------
#
#
# Head: Would give zero stars if I could
#
# Chunk 1:
# Text:
# Would give zero stars if I could. I was ripped off 80 at an .
# ------------------
# Chunk 2:
# Text:
# The machine gave a 20 instead of the 100 it was supposed to. Immediately contacted  and have been waiting over 4 months for a resolution. At this point, it borders theft. It appears that they are prolonging this in hopes that I just give up and eat the 80 loss.
# ------------------
#
#
# Head: Wouldve given more stars than three
#
# Chunk 1:
# Text:
# Wouldve given more stars than three. But they fall short in some sectors of their services. There general line for clients to call with general banking questions is always a joy with short wait times and friendly customer service representatives to help you out. Unfortunately, during a recent communication with there   card Dispute department, while trying to sort out a recent problem with an online transaction. I was offered no help nor advice besides  Wait and see. from one of their telecommunications agents. I sat on hold for 45 minutes to speak with this department only for this particular agent to ramble on about their credentials and their years of experience in this department and that they knew what they were talking about and take many calls a day. Then, when I was displeased with my services threw money at the problem  15.00 for bad services will be added into your account in 2 days.. I dont want money thrown at me, I want genuine assistance, accurate information and patience. Instead a received nothing but push back and well a dispute between myself and the agent. This was by far my most negative experience with  yet.
# ------------------
# Chunk 2:
# Text:
# Which is really unfortunate. Yes, with online only banking you do not get the same face to face communication and assistance but, this was unacceptable even for over the phone online banking. Extremely displeased with this situation.
# ------------------
#
#
# Head: Wow, not understanding all the negative reviews
#
# Chunk 1:
# Text:
# Wow, not understanding all the negative reviews. We have been  customers since it was , for over 20 years now. We have bank accounts, line of credit, and credit cards with them. We do not have a mortgage so I cannot comment on that product.I do not understand all the comments about fraudulent activity surely they are regulated like every other bank, and actual fraud is not a thing.Holds on deposits are standard practice depending on certain circumstances. In fact, especially as a virtual bank, these practices are there to protect the customer and the bank. I successfully reduced holds on my deposits, over time, as I was instructed to do.I also do not understand all the comments on the long wait times, not commonplace  I rarely have to wait more than a couple of minutes to talk to someone, and their staff are always friendly, courteous, and professional. You will wait longer if calling in the middle of the night, but even then its not too long. mobile app and online interfaces are comprehensive and easy to use, much better than a lot of the brick and mortar banks in Canada, trust me, Ive tried most of them.This is not a complaint but a wish list item. I run a business, so my business account is at another bank unfortunately. I hope one day you will offer business accounts!We had a seamless transition from  to  when it happened a few years ago as well. Still super happy not to have to pay monthly banking fees! Thank you !
# ------------------
# Chunk 2:
# Text:
# We continue to recommend you to our friends.
# ------------------
#
#
# Head: Not a real
#
# Chunk 1:
# Text:
# Wrote a note on my account banning me from their products with no explanation... its a bank, you really shouldnt be able to ban someone with no explanation.
# ------------------
#
#
# Head: You cant deposit foreign cheques
#
# Chunk 1:
# Text:
# You cant deposit foreign cheques through the  or edeposit. You have to pay to mail it to them then they take up to eight business days to deposit it into your account BUT then it takes a month and a half for  to release the funds.
# ------------------
# Chunk 2:
# Text:
# Im waiting nearly two month for a 95 cheque, pathetic
# ------------------
#
#
# Head: You get what you pay for
#
# Chunk 1:
# Text:
# You get what you pay for. And hopefully you never have to utilize their customer service. There security questions are very hard to answer, and when you fail to answer them correctly they place you on hold multiple times while you wait to speak with a supervisor, who then asks you more difficult questions. And after you fail those they require you to send a written letter stating more personal information about yourself. Keep in mind I had already successfully verified my name, address, last bill payment that came from my account, last etransfer sent, my account number, and my  number. They still required more information.
# ------------------
# Chunk 2:
# Text:
# I.e. old address, how long youve banked with them, etc. And when I couldnt provide them with their automated questions I was transferred to someone else. You are given the run around for over half an hour on the phone while they continue transferring your call and placing you on hold while you wait to speak with different supervisors and managers. Whom require you to hang up and have them call you back on your number you provided. Unfortunately I have had to deal with this twice in the last week. The first time I had lost my card and needed a new one sent. The second time I needed my new card number while I waited for it to arrive in the mail so I could access my online banking info. Very simple things, that required a very rigorous screening process. If I didnt already have so many automatic bills and e transfers coming out of that account each month Id find a different company, their customer service is the worst Ive ever had to deal with. If your time is valuable to you, find a different company.
# ------------------
# Chunk 3:
# Text:
# You get what you pay for. Long story short one day, the bank started to ask me security questions from  5yearold information about my closed account, which I could not recall. I did have my online banking password, phone password on file, my secret code word, and I was calling from a registered phone number on file. I ended up failing my security questions. I asked if I can go anywhere physically and ID myself, but was told it was not an option. I was requested to send my ID, phone bill, address, phone number, date of birth, and order of direction with my signature, which I did. I was told that something does not match. I doublechecked with my online profile which I still had access to, and all the information was correct. So my account was further locked. Another week later, I got a call from the  fraud office very shady, as it is not part of , and no instruction was given to me about such a call back from . The guy on the line was quite rude and was asking me to provide him with a credit card number outside of  for confirmation for verification. I declined that, he threatened me if I dont give him this information my account will be blocked  ten days into this mess. I called  again and was told that I could go to  to verify myself personally I was asking for this from the beginning. I was told that the email would arrive in two hours with instructions. I waited until later in the evening and decided to call again.The agent on the phone took all the information back and told me that it takes 24h to receive the email with instructions. However, as soon as I finished the call, the email arrived right away. Ive yet to go to , but I anticipate that some more complications will come out. My recommendation is to stay away from financial institutions with no physical location. I would never again trust  to hold my money.
# ------------------
# Chunk 4:
# Text:
# Ones you give  you pay, you might not be able to get it back in a while. I feel like there is no proper way to complain, and all attempts come back to managers on the phone.0320  paperwork on 0220, the update from  has not been received yet by . Its been over a month without access to account.
# ------------------
#
#
# Head: You have to wait on the line like
#
# Chunk 1:
# Text:
# You have to wait on the line like forever for calling customer service, theres an unusual transaction that took 391 from my account.The blocked my debit card and gave me a new one, i thought they will put it back to my account the money but no they didnt.Life now a days is so hard, for me that amount is big enough to do an investigation but they didnt do anything.Injust want my money back,i never use my debit card for online shopping .I really dont know how it happens, i deposited money that day and didnt check my account then. Then one day decided to deposit money, and noticed the unusual transaction that i never did exactly the same day i deposited money.
# ------------------
#
#
# Head: Zero stars!
#
# Chunk 1:
# Text:
# Zero stars! Customer service is atrocious. Incompetence at all levels. Called repeatedly to clear up a problem related to the opening of a basic account. Spent hours on hold.
# ------------------
# Chunk 2:
# Text:
# Problem still not resolved weeks later. Stay away from this company.
# ------------------
#
#
# Head: zero stars!!
#
# Chunk 1:
# Text:
# zero stars!!
# ------------------

# %%
chunk_vector_store = WeaviateVectorStore(
    weaviate_client=client, index_name="Reviews_SemChunk256", text_key="text"
)

chunk_storage_context = StorageContext.from_defaults(vector_store=chunk_vector_store)
chunk_index = VectorStoreIndex(nodes, storage_context=chunk_storage_context)

chunk_retriever = chunk_index.as_retriever(similarity_top_k=6)

chunk_query_engine = RetrieverQueryEngine(retriever=chunk_retriever)
result = chunk_query_engine.query("Tell me about the worst reviews")
print(f"Result: \n\n{result}")
# Out:
# Result:
#
# It appears that several individuals have had extremely poor experiences with a particular bank. They have reported being treated rudely, having difficulty accessing their accounts, and being unimpressed with the bank's customer service. Some have even gone so far as to close their accounts and warn others to stay away. The bank's processes and policies have also been criticized as being outdated and inefficient. Overall, it seems that this bank has a long way to go in terms of improving its reputation and customer satisfaction.

# %%
from llama_index.core.postprocessor import SimilarityPostprocessor
from llama_index.core.postprocessor import LongContextReorder

reorder = LongContextReorder()

chunk_retriever = chunk_index.as_retriever()

processor = SimilarityPostprocessor(similarity_cutoff=0.75)

chunk_query_engine = RetrieverQueryEngine(retriever=chunk_retriever, node_postprocessors=[processor, reorder],)

# %% [markdown]
# ## Eval

# %%
from datasets import Dataset

dataset = Dataset.from_pandas(test_set)
answers = np.empty(len(dataset), dtype=object)

for index, row in enumerate(dataset):
    query = row["question"]

    answer = chunk_query_engine.query(query)

    print(f"Result {index}\nQuestion: {query}\nAnswer: {answer}\n")

    # Store the result
    answers[index] = str(answer)
# Out:
# Result 0
# Question: How do the reviewer's experiences with Simplii's systems contribute to their negative sentiment?
#
#
# This question directly addresses the keyphrase "Unreliable systems" within the context of the review, prompting an answer that focuses on the reviewer's frustrations with the systems' failures.
#
# Answer: The reviewer's experiences with Simplii's systems have been marred by difficulties and failures, leading to a sense of frustration and disappointment. This has resulted in a negative perception of the company's ability to provide reliable and efficient services, ultimately contributing to their overall negative sentiment.
#
# Result 1
# Question: How long was the reviewer's money held up by the bank?
#
#
#
# Answer: The reviewer's money was held up for a week, and then an additional holding extension was added, making it even longer.
#
# Result 2
# Question: Why couldn't the customer activate their approved acct?
# Answer: The customer was unable to activate their approved account because they were put on hold for an unacceptable amount of time, which made them lose patience and decide not to proceed with activating the card.
#
# Result 3
# Question: What financial service is causing the delay?
# Answer: Account access.
#
# Result 4
# Question: What credit product did both reviewers target?
# Answer: The credit product in question is a loan or credit application.

# %%
dataset = dataset.add_column("answer", answers)
dataset
# Out:
# Dataset({
#     features: ['question', 'contexts', 'ground_truth', 'evolution_type', 'metadata', 'episode_done', 'answer'],
#     num_rows: 5
# })

# %%
import ast
from ragas import evaluate
from ragas.metrics import Faithfulness, ContextPrecision, AnswerCorrectness
from datasets import Dataset
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

# Method 1: Using map
def convert_string_to_list(example):
    example['contexts'] = ast.literal_eval(example['contexts'])
    return example

dataset = dataset.map(convert_string_to_list)
# Out:
# Map:   0%|          | 0/5 [00:00<?, ? examples/s]

# %%
OPENAI_API_KEY = 'key'
#GENERATOR_MODEL_NAME = "Mistral-7B-Instruct-v0.3"
GENERATOR_MODEL_NAME = "Meta-Llama-3.1-8B-Instruct"
GENERATOR_BASE_URL = "https://kscope.vectorinstitute.ai/v1"
EMBEDDING_MODEL_NAME = "BAAI/bge-base-en-v1.5"

# Define the RAG embeddings model (different than the OpenAI embedding model defined above for test set generation)
model_kwargs = {'device': 'cuda', 'trust_remote_code': True}
encode_kwargs = {'normalize_embeddings': True} # set True to compute cosine similarity

print(f"Setting up the RAG embeddings model...")
embeddings = HuggingFaceEmbeddings(
    model_name="BAAI/bge-base-en-v1.5",
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs,
)

generator_llm = ChatOpenAI(
    model="Meta-Llama-3.1-8B-Instruct",
    #model="gemma-2-9b-it",
    base_url=GENERATOR_BASE_URL,
    api_key=OPENAI_API_KEY,
)

score = evaluate(
    dataset=dataset,
    metrics=[
        Faithfulness(),
        ContextPrecision(),
        AnswerCorrectness(),
    ],
    llm=generator_llm, # Using OpenAI LLM as the evaluator
    embeddings=embeddings,
)
# Out:
# Setting up the RAG embeddings model...
# Evaluating:   0%|          | 0/15 [00:00<?, ?it/s]
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_answer_correctness.py:277: DeprecationWarning: The function ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use single_turn_ascore instead.
#   similarity_score = await self.answer_similarity.ascore(
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_answer_correctness.py:277: DeprecationWarning: The function ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use single_turn_ascore instead.
#   similarity_score = await self.answer_similarity.ascore(

# %%
score.to_pandas()
# Out:
#                                           user_input  \
# 0  How do the reviewer's experiences with Simplii...
# 1  How long was the reviewer's money held up by t...
# 2  Why couldn't the customer activate their appro...
# 3       What financial service is causing the delay?
# 4     What credit product did both reviewers target?
#
#                                   retrieved_contexts  \
# 0  [datePublished: 3/14/2024\nheadline: Horrible ...
# 1  [datePublished: 11/1/2024\nheadline: Dont wast...
# 2  [datePublished: 2/6/2020\nheadline: Prejudice ...
# 3  [datePublished: 5/11/2021\nheadline: I overpai...
# 4  [datePublished: 2/6/2024\nheadline: Experience...
#
#                                             response  \
# 0  The reviewer's experiences with Simplii's syst...
# 1  The reviewer's money was held up for a week, a...
# 2  The customer was unable to activate their appr...
# 3                                    Account access.
# 4  The credit product in question is a loan or cr...
#
#                                            reference  faithfulness  \
# 0  The reviewer expresses frustration with Simpli...      1.000000
# 1  The reviewer's money was held up for 14 days, ...      0.333333
# 2  The customer couldn't activate their account b...      0.250000
# 3  The context does not provide information about...      0.000000
# 4                           A secured line of credit      0.500000
#
#    context_precision  answer_correctness
# 0                1.0            0.719939
# 1                1.0            0.433811
# 2                1.0            0.336159
# 3                0.0            0.139817
# 4                1.0            0.192114

# %% [markdown]
# # RAG 256 Chunking with LLM Rank

# %%
from llama_index.core.postprocessor import LongContextReorder
from llama_index.core import PromptTemplate
from llama_index.core import get_response_synthesizer

chunk_vector_store = WeaviateVectorStore(
    weaviate_client=client, index_name="Reviews_Chunk", text_key="text"
)

retriever = VectorStoreIndex.from_vector_store(chunk_vector_store).as_retriever(similarity_top_k=5,
)

qa_prompt_tmpl = (
    "Context information is customer review data for the Simplii bank.\n"
    "---------------------\n"
    "{context_str}\n"
    "---------------------\n"
    "Given the context information and not prior knowledge, "
    "answer the query.\n"
    "When answering please reference which specific reviews led you to your answer using their datepublished and headline "
)

qa_prompt = PromptTemplate(qa_prompt_tmpl)
response_synthesizer = get_response_synthesizer(text_qa_template=qa_prompt)

chunk_retriever = VectorStoreIndex.from_vector_store(chunk_vector_store)

chat_engine = chunk_retriever.as_chat_engine(chat_mode="react", llm=llm, response_synthesizer=response_synthesizer, verbose=True)

# assemble query engine
chunkrerank_query_engine = RetrieverQueryEngine(
    retriever=retriever,
    response_synthesizer=response_synthesizer,
)

# %%
response = chat_engine.chat(
    "Tell me about customers' experience withdrawing money"
)
# Out:
# > Running step 78030cb1-6820-4dc3-bfcd-84896a2cf07c. Step input: Tell me about customers' experience withdrawing money
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: query_engine_tool
# Action Input: {'input': 'Simplii App customer reviews withdrawing money', 'num_beams': 5}
# Observation: Based on the provided reviews, it appears that Simplii Financial has a history of holding onto customers' money without releasing it, and in some cases, even taking away a portion of it as a penalty for requesting a refund. This suggests that Simplii Financial may have a policy of withholding funds from customers, which can be frustrating and time-consuming to resolve.
#
# Specifically, the review from 3/27/2023, "Beware of Simplii", mentions that the author deposited two checks and had to wait for 3 weeks for them to be released, and even after multiple calls, the money was still not available to withdraw. This review suggests that Simplii Financial may have a tendency to hold onto customers' money for an extended period of time.
#
# Additionally, the review from 10/8/2022, "Simplii financial is a fraud", mentions that Simplii Financial takes away a portion of the customer's money as a penalty for requesting a refund, which further supports the idea that Simplii Financial may have a policy of withholding funds from customers.
#
# Overall, based on these reviews, it appears that Simplii Financial may have a history of withholding funds from customers, which can be a significant issue for those who rely on their services.
# > Running step 9f907911-4bcb-41a1-a072-7ca3ca9b1121. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: Based on the reviews, it appears that Simplii Financial has a history of holding onto customers' money without releasing it, and in some cases, even taking away a portion of it as a penalty for requesting a refund. This suggests that Simplii Financial may have a policy of withholding funds from customers, which can be frustrating and time-consuming to resolve.

# %%
print(chunkrerank_query_engine.query("What are the main areas the clients commend in positive customer reviews?"))
# Out:
# Based on the provided context information, it appears that the Simplii bank has a strong focus on customer service and satisfaction. The reviews suggest that the bank's staff are knowledgeable, professional, and helpful in resolving customer issues and providing information.
#
# One review in particular highlights the bank's commitment to customer satisfaction, stating that the reviewer has been with the bank for 30 years and has been pleased with the service (datePublished: 10/23/2024, headline: was very helpful). This suggests that the bank has a long-term relationship with its customers and is dedicated to providing consistent and high-quality service.
#
# Another review mentions that the bank's staff are willing to go above and beyond to help customers, even in difficult situations (datePublished: 9/26/2024, headline: Best help ever!). This suggests that the bank values its customers and is committed to providing exceptional service.
#
# Overall, based on the reviews, it appears that the Simplii bank prioritizes customer satisfaction and has a strong focus on providing high-quality service to its customers.

# %%
from datasets import Dataset
import pandas as pd

test_set = pd.read_csv('/path/new_testset.csv')
test_set = test_set.iloc[: , 1:]

# %%
dataset = dataset.add_column("answer", answers)
dataset
# Out:
# Dataset({
#     features: ['question', 'contexts', 'ground_truth', 'evolution_type', 'metadata', 'episode_done', 'answer'],
#     num_rows: 5
# })

# %%
import ast
from ragas import evaluate
from ragas.metrics import Faithfulness, ContextPrecision, AnswerCorrectness
from datasets import Dataset

# Method 1: Using map
def convert_string_to_list(example):
    example['contexts'] = ast.literal_eval(example['contexts'])
    return example

dataset = dataset.map(convert_string_to_list)
# Out:
# Map:   0%|          | 0/5 [00:00<?, ? examples/s]

# %%
from ragas import evaluate
from ragas.metrics import Faithfulness, ContextPrecision, AnswerCorrectness
from datasets import Dataset
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_huggingface.embeddings import HuggingFaceEmbeddings

OPENAI_API_KEY = 'key'
#GENERATOR_MODEL_NAME = "Mistral-7B-Instruct-v0.3"
GENERATOR_MODEL_NAME = "Meta-Llama-3.1-8B-Instruct"
GENERATOR_BASE_URL = "https://kscope.vectorinstitute.ai/v1"
EMBEDDING_MODEL_NAME = "BAAI/bge-base-en-v1.5"

# Define the RAG embeddings model (different than the OpenAI embedding model defined above for test set generation)
model_kwargs = {'device': 'cuda', 'trust_remote_code': True}
encode_kwargs = {'normalize_embeddings': True} # set True to compute cosine similarity

print(f"Setting up the RAG embeddings model...")
embeddings = HuggingFaceEmbeddings(
    model_name="BAAI/bge-base-en-v1.5",
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs,
)

generator_llm = ChatOpenAI(
    model="Meta-Llama-3.1-8B-Instruct",
    #model="gemma-2-9b-it",
    base_url=GENERATOR_BASE_URL,
    api_key=OPENAI_API_KEY,
)

score = evaluate(
    dataset=dataset,
    metrics=[
        Faithfulness(),
        ContextPrecision(),
        AnswerCorrectness(),
    ],
    llm=generator_llm, # Using OpenAI LLM as the evaluator
    embeddings=embeddings,
)
# Out:
# Setting up the RAG embeddings model...
# Evaluating:   0%|          | 0/15 [00:00<?, ?it/s]
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_answer_correctness.py:277: DeprecationWarning: The function ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use single_turn_ascore instead.
#   similarity_score = await self.answer_similarity.ascore(
# Exception raised in Job[14]: AttributeError('StringIO' object has no attribute 'sentences')
# Exception raised in Job[12]: AttributeError('StringIO' object has no attribute 'sentences')
# Exception raised in Job[5]: LLMDidNotFinishException(The LLM generation was not completed. Please increase try increasing the max_tokens and try again.)
# Exception raised in Job[2]: BadRequestError(Error code: 400 - {'detail': {'object': 'error', 'message': "This model's maximum context length is 4096 tokens. However, you requested 4385 tokens in the messages, Please reduce the length of the messages.", 'type': 'BadRequestError', 'param': None, 'code': 400}})

# %%
score.to_pandas()
# Out:
#                                           user_input  \
# 0  How do the reviewer's experiences with Simplii...
# 1  How long was the reviewer's money held up by t...
# 2  Why couldn't the customer activate their appro...
# 3       What financial service is causing the delay?
# 4     What credit product did both reviewers target?
#
#                                   retrieved_contexts  \
# 0  [datePublished: 3/14/2024\nheadline: Horrible ...
# 1  [datePublished: 11/1/2024\nheadline: Dont wast...
# 2  [datePublished: 2/6/2020\nheadline: Prejudice ...
# 3  [datePublished: 5/11/2021\nheadline: I overpai...
# 4  [datePublished: 2/6/2024\nheadline: Experience...
#
#                                             response  \
# 0  Based on the provided reviews, the reviewer's ...
# 1  According to the reviews, the reviewer's money...
# 2  Based on the provided reviews, it appears that...
# 3  Based on the provided reviews, it appears that...
# 4  Unfortunately, the provided information does n...
#
#                                            reference  faithfulness  \
# 0  The reviewer expresses frustration with Simpli...      0.545455
# 1  The reviewer's money was held up for 14 days, ...      0.000000
# 2  The customer couldn't activate their account b...      0.181818
# 3  The context does not provide information about...      0.333333
# 4                           A secured line of credit           NaN
#
#    context_precision  answer_correctness
# 0                1.0                 NaN
# 1                1.0                 NaN
# 2                1.0            0.339935
# 3                0.0            0.188307
# 4                1.0                 NaN

# %% [markdown]
# # RAGAS with Vanilla Decoupled RAG

# %%
from langchain_openai import ChatOpenAI

OPENAI_API_KEY = 'key'
GENERATOR_MODEL_NAME = "Meta-Llama-3.1-8B-Instruct"
GENERATOR_BASE_URL = "https://kscope.vectorinstitute.ai/v1"

van_llm = ChatOpenAI(
    model=GENERATOR_MODEL_NAME,
    temperature=0,
    max_tokens=None,
    base_url=GENERATOR_BASE_URL,
    api_key=OPENAI_API_KEY
)
message = [
    ("human", "what's up"),
]
try:
    result = van_llm.invoke(message)
    print(f"Result: \n\n{result.content}")
except Exception as err:
    if "Error code: 503" in err.message:
        print(f"The model {GENERATOR_MODEL_NAME} is not ready yet.")
    else:
        raise
# Out:
# Result:
#
# Not much! It's nice to chat with you. Is there something on your mind that you'd like to talk about, or are you just looking for some casual conversation?

# %%
EMBEDDING_MODEL_NAME = "BAAI/bge-base-en-v1.5"

print(f"Setting up the embeddings model...")
van_embeddings = HuggingFaceEmbedding(
    model_name=EMBEDDING_MODEL_NAME,
    device='cuda',
    trust_remote_code=True,
)

collection = client.collections.get("Reviews")

def get_embeddings(text):
    embed_out = van_embeddings.get_text_embedding(text)
    return embed_out

# Parse the string into a datetime object
def convert_date(date):
    datetime_obj = datetime.fromisoformat(date)

    # Extract the date part
    date_only = datetime_obj.date()
    return date_only

def retrieve_docs(query):
    answer=""
    query_vector = get_embeddings(query)

    # Perform query
    response = collection.query.hybrid(
        query=query,  # For BM25 part of the hybrid search
        vector=query_vector,  # For vector part of the hybrid search
        limit=6,
        return_metadata=wq.MetadataQuery(score=True),
    )

    for i, o in enumerate(response.objects, start=1):
        return "\n".join([f"Title: {o.properties['headline']}, Date: {convert_date(str(o.properties['datePublished']))}\n{o.properties['reviewBody']}\n" for i, o in enumerate(response.objects, start=1)])
        #return "\n".join([f"Title: {o.properties['headline']}, Date: {o.properties['datePublished']}\n{o.properties['reviewBody']}\n" for i, o in enumerate(response.objects, start=1)])

def RAG(query):
    context = retrieve_docs(query)
    formatted_prompt = f"Context:\n{context}\n\nQuery:\n{query}\n\nYou are an assistant supposed to provide insights about customer reviews. Take the query and context and answer the query. If you're referencing specific reviews, make sure you use their title and date. If the review has no headline, account for that too:"

    result = van_llm.invoke(formatted_prompt)
    return result
    print(f"Result: \n\n{result.content}")
# Out:
# Setting up the embeddings model...

# %%
RAG("whats the worst review?")
# Out:
# AIMessage(content='After analyzing the customer reviews, I would say that the worst review is:\n\n**"The absolute worst, Date: 2019-11-04"**\n\nThis review stands out for several reasons:\n\n1. **Length and detail**: This review is one of the longest, providing a detailed account of the reviewer\'s negative experience with the bank.\n2. **Emotional tone**: The reviewer uses strong language, such as "archaic," "can\'t do anything," "constantly put you on hold," and "completely different experience." This suggests a high level of frustration and disappointment.\n3. **Specific examples**: The reviewer provides specific examples of the bank\'s poor processes, such as only being able to send forms for withdrawal by post, which adds to the credibility of their complaint.\n4. **Warning to others**: The reviewer explicitly warns others to "STAY AWAY," which suggests that they feel strongly about sharing their negative experience to prevent others from going through the same issues.\n\nOverall, this review is a scathing critique of the bank\'s services, and its emotional tone and specific examples make it a compelling example of a worst review.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 232, 'prompt_tokens': 659, 'total_tokens': 891, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'Meta-Llama-3.1-8B-Instruct', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-b2db0ad9-0826-4c25-b143-3c204d6749e2-0', usage_metadata={'input_tokens': 659, 'output_tokens': 232, 'total_tokens': 891, 'input_token_details': {}, 'output_token_details': {}})

# %% [markdown]
# ## Evalutation

# %%
from datasets import Dataset
import pandas as pd

test_set = pd.read_csv('/path/new_testset.csv')
test_set = test_set.iloc[: , 1:]

dataset = Dataset.from_pandas(test_set)
answers = np.empty(len(dataset), dtype=object)

for index, row in enumerate(dataset):
    query = row["question"]

    answer = RAG(query)

    print(f"Result {index}\nQuestion: {query}\nAnswer: {answer}\n")

    # Store the result
    answers[index] = answer.content
# Out:
# Result 0
# Question: How do the reviewer's experiences with Simplii's systems contribute to their negative sentiment?
#
#
# This question directly addresses the keyphrase "Unreliable systems" within the context of the review, prompting an answer that focuses on the reviewer's frustrations with the systems' failures.
#
# Answer: content="The reviewer's experiences with Simplii's systems contribute to their negative sentiment in several ways:\n\n1. **Failed card validation**: The reviewer's Simplii card stopped working after a few days, and they had to call to validate it, which didn't work. This led to a month-long struggle to get a new barcode, which couldn't be sent to them. (Title: Simplii card, Date: 2022-07-23)\n2. **Inability to cancel the card**: The reviewer was unable to cancel the card before validation, which added to their frustration. (Title: Simplii card, Date: 2022-07-23)\n3. **ATM transaction errors**: The reviewer experienced an ATM transaction error, where they were charged twice for a single transaction. Customer service was unhelpful, and the company blamed the reviewer for the issue. (Title: I used my Simplii financial  card, Date: 2019-11-09)\n4. **Recurring payment issues**: The reviewer had their recurring vehicle payment bounced, despite having sufficient funds in their account. Customer service promised to issue a credit for NSF fees but failed to do so. This was the second time the reviewer experienced this issue. (Title: they bounced my reoccurring vehicle, Date: 2024-11-02)\n5. **Poor customer service**: Several reviewers experienced poor customer service, including unhelpful representatives, fake promises, and a lack of enthusiasm. (Title: worst customer service in the world, Date: 2022-06-22 and Title: NaN, Date: 2022-07-20)\n\nThese experiences demonstrate that Simplii's systems are unreliable, and their customer service is often unhelpful, leading to a negative sentiment among reviewers." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 365, 'prompt_tokens': 675, 'total_tokens': 1040, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'Meta-Llama-3.1-8B-Instruct', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-26a54c7a-f515-4722-a065-8939bbe8a112-0' usage_metadata={'input_tokens': 675, 'output_tokens': 365, 'total_tokens': 1040, 'input_token_details': {}, 'output_token_details': {}}
#
# Result 1
# Question: How long was the reviewer's money held up by the bank?
#
#
#
# Answer: content='According to the reviews, the reviewer\'s money was held up by the bank for varying lengths of time. Here are the specific instances mentioned:\n\n* In the review "Still waiting for MY MONEY!!" (2021-07-20), the reviewer\'s account was frozen for 3 weeks and counting, with the funds being held for 3 weeks.\n* In the review "With held my check for 12 days after" (2023-08-19), the reviewer\'s check was held for 12 days.\n* In the review "They hold deposits far longer than they are allowed" (2024-03-15), the reviewer\'s funds were held for 8 business days, but then an extra 2-day extension was added, and then another 2-day extension, making it a total of 12 business days.\n\nIt\'s worth noting that the reviewer in "They hold deposits far longer than they are allowed" (2024-03-15) mentions that this is not the first time they\'ve experienced issues with their account being frozen, and that they\'ve had to wait for 12 business days on multiple occasions.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 231, 'prompt_tokens': 1455, 'total_tokens': 1686, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'Meta-Llama-3.1-8B-Instruct', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-2dc3b439-559a-466b-8d20-5f1522ee7bf3-0' usage_metadata={'input_tokens': 1455, 'output_tokens': 231, 'total_tokens': 1686, 'input_token_details': {}, 'output_token_details': {}}
#
# Result 2
# Question: Why couldn't the customer activate their approved acct?
# Answer: content='Based on the provided context, it appears that customers have experienced difficulties in activating their approved accounts due to various reasons. Here are some possible reasons:\n\n1. **Long wait times and cumbersome procedures**: In the review "No IT support and very cumbersome system procedures for resolving problems." (Date: 2023-08-30), the customer mentions that they spent over two and a half hours trying to register for secure messaging, which is a necessary step to access their account. This suggests that the activation process is not only time-consuming but also frustrating.\n2. **Inability to speak to a manager or resolve issues**: In the same review, the customer notes that they were unable to speak to a manager directly and had to wait in a queue, which further delayed the resolution of their issue.\n3. **Security measures**: In the review "I called to activate my card and was, Date: 2022-10-26", the customer suggests that the bank\'s security measures may be the reason for the long wait times. However, they also propose that customers should be provided with a phone number to speak to someone immediately to activate their card.\n4. **Inconsistent and unhelpful customer service**: In the review "Takes forever to open an account, Date: 2020-01-21", the customer mentions that they received inconsistent answers from multiple customer service representatives, which made it difficult for them to resolve their issue.\n5. **Lack of communication**: In the review "No concept of customer service, Date: 2019-01-02", the customer notes that they were unable to open an account despite receiving email approval confirmations, and no one contacted them to explain or ask for additional details.\n\nOverall, it seems that customers have experienced difficulties in activating their approved accounts due to a combination of long wait times, cumbersome procedures, security measures, inconsistent customer service, and a lack of communication.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 389, 'prompt_tokens': 976, 'total_tokens': 1365, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'Meta-Llama-3.1-8B-Instruct', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-4712bf3e-1903-4484-a14f-9d68d26e2436-0' usage_metadata={'input_tokens': 976, 'output_tokens': 389, 'total_tokens': 1365, 'input_token_details': {}, 'output_token_details': {}}
#
# Result 3
# Question: What financial service is causing the delay?
# Answer: content="Based on the context, it appears that the financial service causing the delay is a bank or financial institution, specifically Simplii Financial. The customer is experiencing delays in obtaining a second mortgage secured line of credit, which is causing issues with a real estate purchase.\n\nThe customer mentions that they have been waiting for over a week for the documents to be processed, and the bank's excuses for the delay are not acceptable. This is similar to the experience of another customer, who had to wait for 14 days for a cheque to clear (Title: I am a former customer of  financial, Date: 2018-09-22).\n\nAdditionally, the customer mentions that they have been on hold for a long time, which is consistent with the experience of another customer who had to wait for 3 hours on the phone to get their card replaced (Title: Prepare for long wait times if you need to call them, Date: 2022-08-02).\n\nOverall, it appears that Simplii Financial is the financial service causing the delay, and the customer is experiencing poor service and long wait times." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 222, 'prompt_tokens': 721, 'total_tokens': 943, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'Meta-Llama-3.1-8B-Instruct', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-46d310cf-6fc3-46af-85fe-69ab203f8ade-0' usage_metadata={'input_tokens': 721, 'output_tokens': 222, 'total_tokens': 943, 'input_token_details': {}, 'output_token_details': {}}
#
# Result 4
# Question: What credit product did both reviewers target?
# Answer: content='Based on the provided context, it appears that both reviewers targeted a secured line of credit. \n\nOne reviewer, "Made an account, Date: 2024-06-20", mentioned that they applied for a secured account, and another reviewer, "My wife and I have had accounts at, Date: 2022-02-08", mentioned that they applied for a secured line of credit.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 82, 'prompt_tokens': 980, 'total_tokens': 1062, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'Meta-Llama-3.1-8B-Instruct', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-07ca9040-50e0-4fa5-9791-f09d2b5806a6-0' usage_metadata={'input_tokens': 980, 'output_tokens': 82, 'total_tokens': 1062, 'input_token_details': {}, 'output_token_details': {}}

# %%
dataset = dataset.add_column("answer", answers)

# %%
import ast

# Method 1: Using map
def convert_string_to_list(example):
    example['contexts'] = ast.literal_eval(example['contexts'])
    return example

dataset = dataset.map(convert_string_to_list)
dataset.features
# Out:
# Map:   0%|          | 0/5 [00:00<?, ? examples/s]
# {'question': Value(dtype='string', id=None),
#  'contexts': Sequence(feature=Value(dtype='string', id=None), length=-1, id=None),
#  'ground_truth': Value(dtype='string', id=None),
#  'evolution_type': Value(dtype='string', id=None),
#  'metadata': Value(dtype='string', id=None),
#  'episode_done': Value(dtype='bool', id=None),
#  'answer': Value(dtype='string', id=None)}

# %%
from ragas import evaluate
from ragas.metrics import Faithfulness, ContextPrecision, AnswerCorrectness
from datasets import Dataset
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

OPENAI_API_KEY = 'key'
#GENERATOR_MODEL_NAME = "Mistral-7B-Instruct-v0.3"
GENERATOR_MODEL_NAME = "Meta-Llama-3.1-8B-Instruct"
GENERATOR_BASE_URL = "https://kscope.vectorinstitute.ai/v1"
EMBEDDING_MODEL_NAME = "BAAI/bge-base-en-v1.5"

# Define the RAG embeddings model (different than the OpenAI embedding model defined above for test set generation)
model_kwargs = {'device': 'cuda', 'trust_remote_code': True}
encode_kwargs = {'normalize_embeddings': True} # set True to compute cosine similarity

print(f"Setting up the RAG embeddings model...")
embeddings = HuggingFaceEmbeddings(
    model_name="BAAI/bge-base-en-v1.5",
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs,
)

generator_llm = ChatOpenAI(
    #model="Meta-Llama-3.1-8B-Instruct",
    model="gemma-2-9b-it",
    base_url=GENERATOR_BASE_URL,
    api_key=OPENAI_API_KEY,
)

score = evaluate(
    dataset=dataset,
    metrics=[
        Faithfulness(),
        ContextPrecision(),
        AnswerCorrectness(),
    ],
    llm=generator_llm, # Using OpenAI LLM as the evaluator
    embeddings=embeddings,
)
# Out:
# Setting up the RAG embeddings model...
# Evaluating:   0%|          | 0/15 [00:00<?, ?it/s]
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_answer_correctness.py:277: DeprecationWarning: The function ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use single_turn_ascore instead.
#   similarity_score = await self.answer_similarity.ascore(
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_answer_correctness.py:277: DeprecationWarning: The function ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use single_turn_ascore instead.
#   similarity_score = await self.answer_similarity.ascore(

# %%
score.to_pandas()
# Out:
#                                           user_input  \
# 0  How do the reviewer's experiences with Simplii...
# 1  How long was the reviewer's money held up by t...
# 2  Why couldn't the customer activate their appro...
# 3       What financial service is causing the delay?
# 4     What credit product did both reviewers target?
#
#                                   retrieved_contexts  \
# 0  [datePublished: 3/14/2024\nheadline: Horrible ...
# 1  [datePublished: 11/1/2024\nheadline: Dont wast...
# 2  [datePublished: 2/6/2020\nheadline: Prejudice ...
# 3  [datePublished: 5/11/2021\nheadline: I overpai...
# 4  [datePublished: 2/6/2024\nheadline: Experience...
#
#                                             response  \
# 0  The reviewer's experiences with Simplii's syst...
# 1  According to the reviews, the reviewer's money...
# 2  Based on the provided context, it appears that...
# 3  Based on the context, it appears that the fina...
# 4  Based on the provided context, it appears that...
#
#                                            reference  faithfulness  \
# 0  The reviewer expresses frustration with Simpli...      0.217391
# 1  The reviewer's money was held up for 14 days, ...      0.181818
# 2  The customer couldn't activate their account b...      0.300000
# 3  The context does not provide information about...      0.083333
# 4                           A secured line of credit      0.666667
#
#    context_precision  answer_correctness
# 0                1.0            0.341715
# 1                1.0            0.368305
# 2                1.0            0.262063
# 3                0.0            0.182126
# 4                1.0            0.485777

# %% [markdown]
# # RAGAS Evaluation for No Chunking RAG

# %% [markdown]
# Read existing Weaviate DB

# %%
no_chunk_vector_store = WeaviateVectorStore(
    weaviate_client=client, index_name="Reviews_Llamaindex", text_key="text"
)

no_chunk_retriever = VectorStoreIndex.from_vector_store(no_chunk_vector_store).as_retriever(
    similarity_top_k=8
)

no_chunk_query_engine = RetrieverQueryEngine(retriever=no_chunk_retriever)

# %%
import pandas as pd

test_set = pd.read_csv('/path/new_testset.csv')
test_set = test_set.iloc[: , 1:]
test_set
# Out:
#                                             question  \
# 0  How do the reviewer's experiences with Simplii...
# 1  How long was the reviewer's money held up by t...
# 2  Why couldn't the customer activate their appro...
# 3       What financial service is causing the delay?
# 4     What credit product did both reviewers target?
#
#                                             contexts  \
# 0  ['datePublished: 3/14/2024\nheadline: Horrible...
# 1  ['datePublished: 11/1/2024\nheadline: Dont was...
# 2  ['datePublished: 2/6/2020\nheadline: Prejudice...
# 3  ['datePublished: 5/11/2021\nheadline: I overpa...
# 4  ['datePublished: 2/6/2024\nheadline: Experienc...
#
#                                         ground_truth evolution_type  \
# 0  The reviewer expresses frustration with Simpli...         simple
# 1  The reviewer's money was held up for 14 days, ...         simple
# 2  The customer couldn't activate their account b...      reasoning
# 3  The context does not provide information about...      reasoning
# 4                           A secured line of credit  multi_context
#
#                                             metadata  episode_done
# 0  [{'source': '/projects/RAG2/cibc-2/Bootcamp_Da...          True
# 1  [{'source': '/projects/RAG2/cibc-2/Bootcamp_Da...          True
# 2  [{'source': '/projects/RAG2/cibc-2/Bootcamp_Da...          True
# 3  [{'source': '/projects/RAG2/cibc-2/Bootcamp_Da...          True
# 4  [{'source': '/projects/RAG2/cibc-2/Bootcamp_Da...          True

# %%
from datasets import Dataset

dataset = Dataset.from_pandas(test_set)
answers = np.empty(len(dataset), dtype=object)

for index, row in enumerate(dataset):
    query = row["question"]

    answer = no_chunk_query_engine.query(query)

    print(f"Result {index}\nQuestion: {query}\nAnswer: {answer}\n")

    # Store the result
    answers[index] = str(answer)
# Out:
# Result 0
# Question: How do the reviewer's experiences with Simplii's systems contribute to their negative sentiment?
#
#
# This question directly addresses the keyphrase "Unreliable systems" within the context of the review, prompting an answer that focuses on the reviewer's frustrations with the systems' failures.
#
# Answer: The reviewer's experiences with Simplii's systems are marred by frequent failures and inefficiencies. They often find themselves unable to access their funds, with holds being placed on their accounts for extended periods of time. This is evident in the numerous complaints about delayed or stuck transactions, including transfers between Simplii accounts. The reviewer's frustration with these issues is compounded by the lack of effective communication and resolution from Simplii's customer service team. As a result, the reviewer feels that their money is "stuck in limbo" and that they are unable to use it when they need to. This consistent pattern of system failures and poor customer service contributes significantly to the reviewer's overwhelmingly negative sentiment towards Simplii.
#
# Result 1
# Question: How long was the reviewer's money held up by the bank?
#
#
#
# Answer: The reviewer's money was held up for 12 business days.
#
# Result 2
# Question: Why couldn't the customer activate their approved acct?
# Answer: It seems that the bank's process for account activation is overly complicated and time-consuming, leading to frustration for customers. The bank's automated system requires customers to wait for an extended period of time, in some cases up to 47 minutes, before being able to speak to a representative. This is not only inconvenient but also unacceptable, especially when compared to other banks that allow customers to activate their cards over the phone with a simple process.
#
# Result 3
# Question: What financial service is causing the delay?
# Answer: A second mortgage secured line of credit.
#
# Result 4
# Question: What credit product did both reviewers target?
# Answer: Secured line of credit.

# %%
dataset = dataset.add_column("answer", answers)
dataset
# Out:
# Dataset({
#     features: ['question', 'contexts', 'ground_truth', 'evolution_type', 'metadata', 'episode_done', 'answer'],
#     num_rows: 5
# })

# %%
dataset.features
# Out:
# {'question': Value(dtype='string', id=None),
#  'contexts': Value(dtype='string', id=None),
#  'ground_truth': Value(dtype='string', id=None),
#  'evolution_type': Value(dtype='string', id=None),
#  'metadata': Value(dtype='string', id=None),
#  'episode_done': Value(dtype='bool', id=None),
#  'answer': Value(dtype='string', id=None)}

# %%
import ast

# Method 1: Using map
def convert_string_to_list(example):
    example['contexts'] = ast.literal_eval(example['contexts'])
    return example

dataset = dataset.map(convert_string_to_list)
dataset.features
# Out:
# Map:   0%|          | 0/5 [00:00<?, ? examples/s]
# {'question': Value(dtype='string', id=None),
#  'contexts': Sequence(feature=Value(dtype='string', id=None), length=-1, id=None),
#  'ground_truth': Value(dtype='string', id=None),
#  'evolution_type': Value(dtype='string', id=None),
#  'metadata': Value(dtype='string', id=None),
#  'episode_done': Value(dtype='bool', id=None),
#  'answer': Value(dtype='string', id=None)}

# %%
from ragas import evaluate
from ragas.metrics import Faithfulness, ContextPrecision, AnswerCorrectness
from datasets import Dataset
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

OPENAI_API_KEY = 'pkey'
#GENERATOR_MODEL_NAME = "Mistral-7B-Instruct-v0.3"
GENERATOR_MODEL_NAME = "Meta-Llama-3.1-8B-Instruct"
GENERATOR_BASE_URL = "https://kscope.vectorinstitute.ai/v1"
EMBEDDING_MODEL_NAME = "BAAI/bge-base-en-v1.5"

# Define the RAG embeddings model (different than the OpenAI embedding model defined above for test set generation)
model_kwargs = {'device': 'cuda', 'trust_remote_code': True}
encode_kwargs = {'normalize_embeddings': True} # set True to compute cosine similarity

print(f"Setting up the RAG embeddings model...")
embeddings = HuggingFaceEmbeddings(
    model_name="BAAI/bge-base-en-v1.5",
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs,
)

generator_llm = ChatOpenAI(
    #model="Meta-Llama-3.1-8B-Instruct",
    model="gemma-2-9b-it",
    base_url=GENERATOR_BASE_URL,
    api_key=OPENAI_API_KEY,
)

score = evaluate(
    dataset=dataset,
    metrics=[
        Faithfulness(),
        ContextPrecision(),
        AnswerCorrectness(),
    ],
    llm=generator_llm, # Using OpenAI LLM as the evaluator
    embeddings=embeddings,
)
# Out:
# Setting up the RAG embeddings model...
# Evaluating:   0%|          | 0/15 [00:00<?, ?it/s]
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_context_precision.py:150: DeprecationWarning: The function _ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use LLMContextPrecisionWithReference instead.
#   return await self._ascore(row, callbacks)
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_answer_correctness.py:277: DeprecationWarning: The function ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use single_turn_ascore instead.
#   similarity_score = await self.answer_similarity.ascore(
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_answer_correctness.py:277: DeprecationWarning: The function ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use single_turn_ascore instead.
#   similarity_score = await self.answer_similarity.ascore(
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/ragas/metrics/_answer_correctness.py:277: DeprecationWarning: The function ascore was deprecated in 0.2, and will be removed in the 0.3 release. Use single_turn_ascore instead.
#   similarity_score = await self.answer_similarity.ascore(
# Exception raised in Job[2]: BadRequestError(Error code: 400 - {'detail': {'object': 'error', 'message': "This model's maximum context length is 4096 tokens. However, you requested 4175 tokens in the messages, Please reduce the length of the messages.", 'type': 'BadRequestError', 'param': None, 'code': 400}})

# %%
score.to_pandas()
# Out:
#                                           user_input  \
# 0  How do the reviewer's experiences with Simplii...
# 1  How long was the reviewer's money held up by t...
# 2  Why couldn't the customer activate their appro...
# 3       What financial service is causing the delay?
# 4     What credit product did both reviewers target?
#
#                                   retrieved_contexts  \
# 0  [datePublished: 3/14/2024\nheadline: Horrible ...
# 1  [datePublished: 11/1/2024\nheadline: Dont wast...
# 2  [datePublished: 2/6/2020\nheadline: Prejudice ...
# 3  [datePublished: 5/11/2021\nheadline: I overpai...
# 4  [datePublished: 2/6/2024\nheadline: Experience...
#
#                                             response  \
# 0  The reviewer's experiences with Simplii's syst...
# 1  The reviewer's money was held up for 12 busine...
# 2  It seems that the bank's process for account a...
# 3          A second mortgage secured line of credit.
# 4                            Secured line of credit.
#
#                                            reference  faithfulness  \
# 0  The reviewer expresses frustration with Simpli...      0.500000
# 1  The reviewer's money was held up for 14 days, ...      0.500000
# 2  The customer couldn't activate their account b...      0.111111
# 3  The context does not provide information about...      0.000000
# 4                           A secured line of credit      1.000000
#
#    context_precision  answer_correctness
# 0                1.0                 NaN
# 1                1.0            0.628838
# 2                1.0            0.174177
# 3                0.0            0.119559
# 4                1.0            0.991390
